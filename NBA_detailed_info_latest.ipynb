# %%
from itertools import chain
from pathlib import Path
from time import sleep
from datetime import datetime

# %%
import requests
from tqdm import tqdm
tqdm.monitor_interval = 0

# %%
import numpy as np
import pandas as pd
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %%
import csv
from collections import Counter, namedtuple
from pathlib import Path

# %%
PARENT_DIR = Path.cwd().parent
OUTPUTS_DIR = PARENT_DIR / 'output'
OUTPUTS_DIR.mkdir(exist_ok=True, parents=True)
IMAGES_DIR = PARENT_DIR / 'images'

# %%
PROJECT_DIR = Path.cwd().parent 
DATA_DIR = PROJECT_DIR / 'data' / 'scraped' / 'teamgamelogs'
DATA_DIR.mkdir(exist_ok=True, parents=True)
OUTPUT_DIR = PROJECT_DIR / 'data' / 'prepared'
OUTPUT_DIR.mkdir(exist_ok=True, parents=True)

# %%
url = 'https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2019/scores/pbp/0021900100_full_pbp.json'
headers = {
    'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.42 Safari/537.36',
    'x-nba-stats-origin': 'stats',
}

r=requests.get(url,headers=headers)

# %%
textjson = r.json()
textjson['g']['pd'][0]['pla'][0]
# Out:
# {'evt': 2,
#  'cl': '12:00',
#  'de': 'Start Period',
#  'locX': 0,
#  'locY': -80,
#  'opt1': 0,
#  'opt2': 0,
#  'mtype': 0,
#  'etype': 12,
#  'opid': '',
#  'tid': 0,
#  'pid': 0,
#  'hs': 0,
#  'vs': 0,
#  'epid': '',
#  'oftid': 0,
#  'ord': 20000}

# %%
print(len(textjson['g']['pd']),len(textjson['g']['pd'][0]['pla']))
# Out:
# 5 129

# %%
DtailedinfoNBA = namedtuple('DtailedinfoNBA', ['evt', 'cl', 'de'])

# %%
def get_nba_detailed_info(i, j):
    evt = textjson['g']['pd'][i]['pla'][j]['evt']
    cl = textjson['g']['pd'][i]['pla'][j]['cl']
    de = textjson['g']['pd'][i]['pla'][j]['de']
    
    return DtailedinfoNBA(evt=evt,cl=cl,de=de)

# %%
def scrap_nba_detailed_info():
    results = []
    try:
        for i in range(0, len(textjson['g']['pd'])):
            for j in range(0, len(textjson['g']['pd'][i]['pla'])):
                results.append(DtailedinfoNBA._asdict(get_nba_detailed_info(i, j)))
    except:
        results = None
    return results

# %%
def scrap_multi_web():
    scrap_data_list = []
    
    for i in range(0, 10):
        if i>999:
            gameid = str(i)
        elif i>99:
            gameid = '0'+str(i)
        elif i>9:
            gameid = '00'+str(i)
        else:
            gameid = '000'+str(i)
        url = 'https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2019/scores/pbp/002190{}_full_pbp.json'.format(gameid)
        headers = {
            'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.42 Safari/537.36',
            'x-nba-stats-origin': 'stats',
        }
        r=requests.get(url,headers=headers)
        textjson = r.json()
        scrap_data = scrap_nba_detailed_info()
        scrap_data_list.append(scrap_data)
        
    return scrap_data_list

# %%
scrap_data_list = []
    
for i in range(0, 10):
    if i>999:
        gameid = str(i)
    elif i>99:
        gameid = '0'+str(i)
    elif i>9:
        gameid = '00'+str(i)
    else:
        gameid = '000'+str(i)
    url = 'https://data.nba.com/data/10s/v2015/json/mobile_teams/nba/2019/scores/pbp/002190{}_full_pbp.json'.format(gameid)
    headers = {
        'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.42 Safari/537.36',
        'x-nba-stats-origin': 'stats',
    }
    r=requests.get(url,headers=headers)
    textjson = r.json()
    scrap_data = scrap_nba_detailed_info()
    scrap_data_list.append(scrap_data)

# %%
scrap_data_list[4]
# Out:
# [OrderedDict([('evt', 2), ('cl', '12:00'), ('de', 'Start Period')]),
#  OrderedDict([('evt', 4),
#               ('cl', '11:58'),
#               ('de',
#                'Jump Ball Drummond vs Turner (Mark Morris gains possession)')]),
#  OrderedDict([('evt', 7),
#               ('cl', '11:44'),
#               ('de', '[DET] Brown Driving Layup Shot: Missed')]),
#  OrderedDict([('evt', 8),
#               ('cl', '11:41'),
#               ('de', '[IND] Lamb Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 9),
#               ('cl', '11:36'),
#               ('de', '[IND] Lamb 3pt Shot: Missed')]),
#  OrderedDict([('evt', 10),
#               ('cl', '11:33'),
#               ('de', '[DET] Jackson Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 11),
#               ('cl', '11:19'),
#               ('de', '[DET] Mark Morris Turnaround Jump Shot: Missed')]),
#  OrderedDict([('evt', 12),
#               ('cl', '11:17'),
#               ('de', '[IND] Sabonis Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 13),
#               ('cl', '11:03'),
#               ('de', '[IND] Lamb Foul: Offensive (1 PF)')]),
#  OrderedDict([('evt', 15),
#               ('cl', '11:03'),
#               ('de', '[IND] Lamb Turnover : Offensive Foul Turnover (1 TO)')]),
#  OrderedDict([('evt', 16),
#               ('cl', '10:52'),
#               ('de', '[DET] Mark Morris 3pt Shot: Missed')]),
#  OrderedDict([('evt', 17),
#               ('cl', '10:49'),
#               ('de', '[IND] Turner Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 18),
#               ('cl', '10:33'),
#               ('de', '[IND] Brogdon Floating Jump shot: Missed')]),
#  OrderedDict([('evt', 19), ('cl', '10:31'), ('de', '[DET] Team Rebound')]),
#  OrderedDict([('evt', 20),
#               ('cl', '10:31'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 21),
#               ('cl', '10:25'),
#               ('de', '[DET] Drummond Turnover : Traveling (1 TO)')]),
#  OrderedDict([('evt', 22),
#               ('cl', '10:15'),
#               ('de', '[IND] Warren 3pt Shot: Missed')]),
#  OrderedDict([('evt', 23),
#               ('cl', '10:10'),
#               ('de', '[DET] Drummond Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 24),
#               ('cl', '10:04'),
#               ('de', '[DET] Drummond Driving Layup Shot: Missed')]),
#  OrderedDict([('evt', 26),
#               ('cl', '10:02'),
#               ('de', '[IND] Sabonis Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 27),
#               ('cl', '09:54'),
#               ('de',
#                '[IND] Lamb Turnover : Bad Pass (2 TO) Steal:Mark Morris (1 ST)')]),
#  OrderedDict([('evt', 29),
#               ('cl', '09:41'),
#               ('de', '[DET] Mark Morris Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 30),
#               ('cl', '09:38'),
#               ('de', '[IND] Sabonis Rebound (Off:0 Def:3)')]),
#  OrderedDict([('evt', 31),
#               ('cl', '09:27'),
#               ('de',
#                '[IND] Brogdon Turnover : Lost Ball (1 TO) Steal:Drummond (1 ST)')]),
#  OrderedDict([('evt', 33),
#               ('cl', '09:15'),
#               ('de', '[DET 2-0] Jackson Pullup Jump shot: Made (2 PTS)')]),
#  OrderedDict([('evt', 34),
#               ('cl', '08:57'),
#               ('de', '[IND] Turner Turnaround Jump Shot: Missed')]),
#  OrderedDict([('evt', 35),
#               ('cl', '08:55'),
#               ('de', '[DET] Drummond Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 36),
#               ('cl', '08:44'),
#               ('de',
#                '[DET 4-0] Drummond Alley Oop Dunk Shot: Made (2 PTS) Assist: Brown (1 AST)')]),
#  OrderedDict([('evt', 38),
#               ('cl', '08:19'),
#               ('de', '[IND] Lamb 3pt Shot: Missed')]),
#  OrderedDict([('evt', 39),
#               ('cl', '08:16'),
#               ('de', '[DET] Snell Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 40),
#               ('cl', '08:12'),
#               ('de',
#                '[DET 6-0] Drummond Layup Shot: Made (4 PTS) Assist: Jackson (1 AST)')]),
#  OrderedDict([('evt', 42),
#               ('cl', '08:04'),
#               ('de', '[IND] Team Timeout : Regular')]),
#  OrderedDict([('evt', 43),
#               ('cl', '07:56'),
#               ('de',
#                '[IND 2-6] Sabonis Finger Roll Layup Shot: Made (2 PTS)')]),
#  OrderedDict([('evt', 44),
#               ('cl', '07:36'),
#               ('de', '[DET] Mark Morris Turnover : Traveling (1 TO)')]),
#  OrderedDict([('evt', 45),
#               ('cl', '07:18'),
#               ('de',
#                '[IND 4-6] Warren Floating Jump shot: Made (2 PTS) Assist: Lamb (1 AST)')]),
#  OrderedDict([('evt', 49),
#               ('cl', '07:06'),
#               ('de', '[DET] Brown Driving Finger Roll Layup Shot: Missed')]),
#  OrderedDict([('evt', 50), ('cl', '07:04'), ('de', '[IND] Team Rebound')]),
#  OrderedDict([('evt', 51),
#               ('cl', '07:04'),
#               ('de', '[DET] Drummond Foul: Loose Ball (1 PF) (B Nansel)')]),
#  OrderedDict([('evt', 53),
#               ('cl', '06:52'),
#               ('de',
#                '[IND 6-6] Warren Floating Jump shot: Made (4 PTS) Assist: Lamb (2 AST)')]),
#  OrderedDict([('evt', 55),
#               ('cl', '06:38'),
#               ('de',
#                '[DET 9-6] Jackson 3pt Shot: Made (5 PTS) Assist: Mark Morris (1 AST)')]),
#  OrderedDict([('evt', 57),
#               ('cl', '06:17'),
#               ('de', '[IND] Brogdon Driving Finger Roll Layup Shot: Missed')]),
#  OrderedDict([('evt', 58),
#               ('cl', '06:15'),
#               ('de', '[DET] Drummond Rebound (Off:0 Def:3)')]),
#  OrderedDict([('evt', 59),
#               ('cl', '06:07'),
#               ('de', '[IND] Lamb Foul: Personal (2 PF) (M Davis)')]),
#  OrderedDict([('evt', 61),
#               ('cl', '06:07'),
#               ('de', '[IND] Lamb Substitution replaced by Sumner')]),
#  OrderedDict([('evt', 63),
#               ('cl', '06:07'),
#               ('de', '[DET] Brown Substitution replaced by Kennard')]),
#  OrderedDict([('evt', 65),
#               ('cl', '06:00'),
#               ('de', '[DET] Snell 3pt Shot: Missed')]),
#  OrderedDict([('evt', 66), ('cl', '05:57'), ('de', '[DET] Team Rebound')]),
#  OrderedDict([('evt', 67),
#               ('cl', '05:57'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 68),
#               ('cl', '05:53'),
#               ('de',
#                '[DET 11-6] Drummond Hook Shot: Made (6 PTS) Assist: Mark Morris (2 AST)')]),
#  OrderedDict([('evt', 70),
#               ('cl', '05:37'),
#               ('de', '[IND] Turner Turnover : Traveling (1 TO)')]),
#  OrderedDict([('evt', 71),
#               ('cl', '05:37'),
#               ('de', '[DET] Jackson Substitution replaced by Rose')]),
#  OrderedDict([('evt', 72),
#               ('cl', '05:37'),
#               ('de', '[DET] Mark Morris Substitution replaced by Maker')]),
#  OrderedDict([('evt', 75),
#               ('cl', '05:26'),
#               ('de', '[DET] Kennard 3pt Shot: Missed')]),
#  OrderedDict([('evt', 76),
#               ('cl', '05:21'),
#               ('de', '[DET] Drummond Rebound (Off:1 Def:3)')]),
#  OrderedDict([('evt', 77),
#               ('cl', '05:18'),
#               ('de', '[DET 13-6] Drummond Layup Shot: Made (8 PTS)')]),
#  OrderedDict([('evt', 78),
#               ('cl', '05:17'),
#               ('de', '[DET] Drummond Technical (1 FTA) (B Taylor)')]),
#  OrderedDict([('evt', 79),
#               ('cl', '05:17'),
#               ('de', '[IND 7-13] Brogdon Free Throw Technical (1 PTS)')]),
#  OrderedDict([('evt', 80),
#               ('cl', '05:03'),
#               ('de', '[DET] Snell Foul: Shooting (1 PF) (2 FTA) (B Taylor)')]),
#  OrderedDict([('evt', 82),
#               ('cl', '05:03'),
#               ('de', '[IND] Warren Free Throw 1 of 2 Missed')]),
#  OrderedDict([('evt', 83), ('cl', '05:03'), ('de', '[IND] Team Rebound')]),
#  OrderedDict([('evt', 84),
#               ('cl', '05:03'),
#               ('de', '[IND] Warren Free Throw 2 of 2 Missed')]),
#  OrderedDict([('evt', 85),
#               ('cl', '05:01'),
#               ('de', '[DET] Drummond Rebound (Off:1 Def:4)')]),
#  OrderedDict([('evt', 86),
#               ('cl', '04:51'),
#               ('de',
#                '[DET] Snell Turnover : Lost Ball (1 TO) Steal:Sumner (1 ST)')]),
#  OrderedDict([('evt', 88),
#               ('cl', '04:48'),
#               ('de', '[IND 9-13] Sumner Running Dunk Shot: Made (2 PTS)')]),
#  OrderedDict([('evt', 89),
#               ('cl', '04:40'),
#               ('de',
#                '[DET] Rose Turnover : Bad Pass (1 TO) Steal:Sumner (2 ST)')]),
#  OrderedDict([('evt', 91),
#               ('cl', '04:29'),
#               ('de', '[IND 11-13] Sabonis Driving Layup Shot: Made (4 PTS)')]),
#  OrderedDict([('evt', 92),
#               ('cl', '04:22'),
#               ('de', '[DET] Team Timeout : Regular')]),
#  OrderedDict([('evt', 93),
#               ('cl', '04:22'),
#               ('de', '[IND] Sabonis Substitution replaced by Holiday')]),
#  OrderedDict([('evt', 94),
#               ('cl', '04:22'),
#               ('de', '[DET] Snell Substitution replaced by Galloway')]),
#  OrderedDict([('evt', 97),
#               ('cl', '04:13'),
#               ('de', '[DET] Kennard Driving Finger Roll Layup Shot: Missed')]),
#  OrderedDict([('evt', 98),
#               ('cl', '04:12'),
#               ('de', '[IND] Turner Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 99),
#               ('cl', '04:03'),
#               ('de', '[IND] Brogdon 3pt Shot: Missed')]),
#  OrderedDict([('evt', 100),
#               ('cl', '04:01'),
#               ('de', '[DET] Kennard Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 101),
#               ('cl', '03:50'),
#               ('de', '[IND] Sumner Foul: Shooting (1 PF) (2 FTA) (M Davis)')]),
#  OrderedDict([('evt', 103),
#               ('cl', '03:50'),
#               ('de', '[DET 14-11] Rose Free Throw 1 of 2 (1 PTS)')]),
#  OrderedDict([('evt', 104),
#               ('cl', '03:50'),
#               ('de', '[DET] Drummond Substitution replaced by Wood')]),
#  OrderedDict([('evt', 106),
#               ('cl', '03:50'),
#               ('de', '[DET 15-11] Rose Free Throw 2 of 2 (2 PTS)')]),
#  OrderedDict([('evt', 107),
#               ('cl', '03:34'),
#               ('de',
#                '[IND 13-15] Brogdon Driving Floating Jump Shot: Made (3 PTS)')]),
#  OrderedDict([('evt', 108),
#               ('cl', '03:25'),
#               ('de', '[DET 17-13] Rose Driving Layup Shot: Made (4 PTS)')]),
#  OrderedDict([('evt', 109),
#               ('cl', '03:09'),
#               ('de', '[DET] Maker Violation:Kicked Ball (M Davis)')]),
#  OrderedDict([('evt', 110),
#               ('cl', '03:05'),
#               ('de',
#                '[IND 15-17] Warren Turnaround Jump Shot: Made (6 PTS) Assist: Holiday (1 AST)')]),
#  OrderedDict([('evt', 112),
#               ('cl', '02:46'),
#               ('de',
#                '[DET 19-15] Galloway Driving Finger Roll Layup Shot: Made (2 PTS)')]),
#  OrderedDict([('evt', 113),
#               ('cl', '02:31'),
#               ('de',
#                '[IND 17-19] Turner Cutting Dunk Shot: Made (2 PTS) Assist: Sumner (1 AST)')]),
#  OrderedDict([('evt', 115),
#               ('cl', '02:22'),
#               ('de', '[IND] Holiday Foul: Personal (1 PF) (B Taylor)')]),
#  OrderedDict([('evt', 117),
#               ('cl', '02:22'),
#               ('de', '[IND] Warren Substitution replaced by Holiday')]),
#  OrderedDict([('evt', 118),
#               ('cl', '02:22'),
#               ('de', '[IND] Brogdon Substitution replaced by Sabonis')]),
#  OrderedDict([('evt', 119),
#               ('cl', '02:22'),
#               ('de', '[IND] Turner Substitution replaced by McDermott')]),
#  OrderedDict([('evt', 120),
#               ('cl', '02:22'),
#               ('de', '[DET] Maker Substitution replaced by Drummond')]),
#  OrderedDict([('evt', 125),
#               ('cl', '02:12'),
#               ('de',
#                '[DET 22-17] Kennard 3pt Shot: Made (3 PTS) Assist: Rose (1 AST)')]),
#  OrderedDict([('evt', 127),
#               ('cl', '02:05'),
#               ('de',
#                '[IND 19-22] Sumner Driving Finger Roll Layup Shot: Made (4 PTS) Assist: Holiday (1 AST)')]),
#  OrderedDict([('evt', 128),
#               ('cl', '02:05'),
#               ('de',
#                '[DET] Drummond Violation:Defensive Goaltending (B Nansel)')]),
#  OrderedDict([('evt', 129),
#               ('cl', '01:53'),
#               ('de', '[DET] Galloway Floating Jump shot: Missed')]),
#  OrderedDict([('evt', 130),
#               ('cl', '01:50'),
#               ('de', '[DET] Drummond Rebound (Off:2 Def:4)')]),
#  OrderedDict([('evt', 131),
#               ('cl', '01:50'),
#               ('de', '[DET 24-19] Drummond Tip Layup Shot: Made (10 PTS)')]),
#  OrderedDict([('evt', 132),
#               ('cl', '01:41'),
#               ('de', '[IND] McDermott Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 133),
#               ('cl', '01:38'),
#               ('de', '[DET] Kennard Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 134),
#               ('cl', '01:31'),
#               ('de',
#                '[IND] Holiday Foul: Shooting (1 PF) (2 FTA) (M Davis)')]),
#  OrderedDict([('evt', 136),
#               ('cl', '01:31'),
#               ('de', '[DET 25-19] Rose Free Throw 1 of 2 (5 PTS)')]),
#  OrderedDict([('evt', 137),
#               ('cl', '01:31'),
#               ('de', '[DET 26-19] Rose Free Throw 2 of 2 (6 PTS)')]),
#  OrderedDict([('evt', 138),
#               ('cl', '01:21'),
#               ('de',
#                '[IND] Sumner Turnover : Out of Bounds Lost Ball Turnover (1 TO)')]),
#  OrderedDict([('evt', 139),
#               ('cl', '01:09'),
#               ('de',
#                '[IND] Holiday Foul: Personal (2 PF) (2 FTA) (M Davis)')]),
#  OrderedDict([('evt', 141),
#               ('cl', '01:09'),
#               ('de', '[DET] Rose Free Throw 1 of 2 Missed')]),
#  OrderedDict([('evt', 142), ('cl', '01:09'), ('de', '[DET] Team Rebound')]),
#  OrderedDict([('evt', 143),
#               ('cl', '01:09'),
#               ('de', '[DET 27-19] Rose Free Throw 2 of 2 (7 PTS)')]),
#  OrderedDict([('evt', 144),
#               ('cl', '00:57.3'),
#               ('de',
#                '[IND 22-27] McDermott 3pt Shot: Made (3 PTS) Assist: Holiday (2 AST)')]),
#  OrderedDict([('evt', 146),
#               ('cl', '00:45.5'),
#               ('de',
#                '[DET] Rose Turnover : Bad Pass (2 TO) Steal:Sumner (3 ST)')]),
#  OrderedDict([('evt', 148),
#               ('cl', '00:41.5'),
#               ('de',
#                '[IND 24-27] Sumner Running Finger Roll Layup Shot: Made (6 PTS)')]),
#  OrderedDict([('evt', 149),
#               ('cl', '00:32.8'),
#               ('de',
#                '[DET] Rose Turnover : Out of Bounds Lost Ball Turnover (3 TO)')]),
#  OrderedDict([('evt', 150),
#               ('cl', '00:23.4'),
#               ('de', '[IND] Holiday Driving Dunk Shot: Missed')]),
#  OrderedDict([('evt', 152),
#               ('cl', '00:20.2'),
#               ('de', '[IND] Sumner Rebound (Off:1 Def:0)')]),
#  OrderedDict([('evt', 153),
#               ('cl', '00:12.8'),
#               ('de', '[IND] Holiday 3pt Shot: Missed')]),
#  OrderedDict([('evt', 154),
#               ('cl', '00:09.3'),
#               ('de', '[IND] Sabonis Rebound (Off:1 Def:3)')]),
#  OrderedDict([('evt', 155),
#               ('cl', '00:05.6'),
#               ('de', '[IND] Holiday Driving Reverse Layup Shot: Missed')]),
#  OrderedDict([('evt', 156),
#               ('cl', '00:03.6'),
#               ('de', '[DET] Drummond Rebound (Off:2 Def:5)')]),
#  OrderedDict([('evt', 157),
#               ('cl', '00:00.2'),
#               ('de', '[DET] Wood Turnover : Traveling (1 TO)')]),
#  OrderedDict([('evt', 158), ('cl', '00:00.0'), ('de', 'End Period')]),
#  OrderedDict([('evt', 163), ('cl', '12:00'), ('de', 'Start Period')]),
#  OrderedDict([('evt', 164),
#               ('cl', '11:39'),
#               ('de',
#                '[IND 26-27] Sabonis Hook Shot: Made (6 PTS) Assist: McDermott (1 AST)')]),
#  OrderedDict([('evt', 166),
#               ('cl', '11:22'),
#               ('de',
#                '[DET 29-26] Kennard Step Back Jump shot: Made (5 PTS)')]),
#  OrderedDict([('evt', 167),
#               ('cl', '11:10'),
#               ('de', '[IND] Holiday Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 168),
#               ('cl', '11:08'),
#               ('de', '[DET] Mark Morris Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 169),
#               ('cl', '11:06'),
#               ('de',
#                '[DET] Mark Morris Turnover : Bad Pass (2 TO) Steal:Holiday (1 ST)')]),
#  OrderedDict([('evt', 171),
#               ('cl', '10:59'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 172),
#               ('cl', '10:51'),
#               ('de', '[IND] Holiday Driving Finger Roll Layup Shot: Missed')]),
#  OrderedDict([('evt', 173),
#               ('cl', '10:49'),
#               ('de', '[IND] Sabonis Rebound (Off:2 Def:3)')]),
#  OrderedDict([('evt', 174),
#               ('cl', '10:49'),
#               ('de', '[IND 28-29] Sabonis Tip Layup Shot: Made (8 PTS)')]),
#  OrderedDict([('evt', 175),
#               ('cl', '10:36'),
#               ('de',
#                '[DET 32-28] Galloway 3pt Shot: Made (5 PTS) Assist: Drummond (1 AST)')]),
#  OrderedDict([('evt', 177),
#               ('cl', '10:25'),
#               ('de',
#                '[IND 31-32] McDermott 3pt Shot: Made (6 PTS) Assist: Sabonis (1 AST)')]),
#  OrderedDict([('evt', 179),
#               ('cl', '10:11'),
#               ('de',
#                '[IND] Holiday Foul: Shooting (2 PF) (2 FTA) (M Davis)')]),
#  OrderedDict([('evt', 181),
#               ('cl', '10:11'),
#               ('de', '[DET] Drummond Free Throw 1 of 2 Missed')]),
#  OrderedDict([('evt', 191), ('cl', '10:11'), ('de', '[DET] Team Rebound')]),
#  OrderedDict([('evt', 182),
#               ('cl', '10:11'),
#               ('de', '[IND] Holiday Substitution replaced by Leaf')]),
#  OrderedDict([('evt', 184),
#               ('cl', '10:11'),
#               ('de', '[DET] Drummond Free Throw 2 of 2 Missed')]),
#  OrderedDict([('evt', 186),
#               ('cl', '10:11'),
#               ('de', '[IND] Holiday Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 187),
#               ('cl', '09:58'),
#               ('de',
#                '[IND] Holiday Turnover : Bad Pass (1 TO) Steal:Galloway (1 ST)')]),
#  OrderedDict([('evt', 189),
#               ('cl', '09:52'),
#               ('de',
#                '[DET] Galloway Turnover : Bad Pass (1 TO) Steal:Holiday (1 ST)')]),
#  OrderedDict([('evt', 192),
#               ('cl', '09:49'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 193),
#               ('cl', '09:32'),
#               ('de', '[IND] Leaf Driving Floating Jump Shot: Missed')]),
#  OrderedDict([('evt', 195),
#               ('cl', '09:29'),
#               ('de', '[DET] Mark Morris Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 196),
#               ('cl', '09:17'),
#               ('de',
#                '[IND] Sumner Foul: Shooting (2 PF) (2 FTA) (B Nansel)')]),
#  OrderedDict([('evt', 198),
#               ('cl', '09:17'),
#               ('de', '[DET 33-31] Kennard Free Throw 1 of 2 (6 PTS)')]),
#  OrderedDict([('evt', 199),
#               ('cl', '09:17'),
#               ('de', '[IND] Sumner Substitution replaced by Warren')]),
#  OrderedDict([('evt', 200),
#               ('cl', '09:17'),
#               ('de', '[IND] McDermott Substitution replaced by Lamb')]),
#  OrderedDict([('evt', 203),
#               ('cl', '09:17'),
#               ('de', '[DET 34-31] Kennard Free Throw 2 of 2 (7 PTS)')]),
#  OrderedDict([('evt', 205),
#               ('cl', '09:17'),
#               ('de', '[DET] Mark Morris Foul: Loose Ball (1 PF) (M Davis)')]),
#  OrderedDict([('evt', 227),
#               ('cl', '09:17'),
#               ('de', '[DET] Kennard Substitution replaced by Brown')]),
#  OrderedDict([('evt', 207),
#               ('cl', '09:01'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 208),
#               ('cl', '08:56'),
#               ('de', '[IND] Holiday Driving Layup Shot: Missed')]),
#  OrderedDict([('evt', 209),
#               ('cl', '08:50'),
#               ('de', '[DET] Mark Morris Rebound (Off:0 Def:3)')]),
#  OrderedDict([('evt', 210),
#               ('cl', '08:45'),
#               ('de', '[DET] Jackson 3pt Shot: Missed')]),
#  OrderedDict([('evt', 211),
#               ('cl', '08:43'),
#               ('de', '[IND] Leaf Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 212),
#               ('cl', '08:34'),
#               ('de', '[IND] Lamb Driving Layup Shot: Missed')]),
#  OrderedDict([('evt', 214),
#               ('cl', '08:31'),
#               ('de', '[IND] Lamb Rebound (Off:1 Def:1)')]),
#  OrderedDict([('evt', 215),
#               ('cl', '08:31'),
#               ('de', '[IND 33-34] Lamb Putback Layup Shot: Made (2 PTS)')]),
#  OrderedDict([('evt', 216),
#               ('cl', '08:18'),
#               ('de', '[DET] Mark Morris 3pt Shot: Missed')]),
#  OrderedDict([('evt', 217),
#               ('cl', '08:16'),
#               ('de', '[IND] Sabonis Rebound (Off:2 Def:4)')]),
#  OrderedDict([('evt', 218),
#               ('cl', '08:11'),
#               ('de', '[IND] Warren Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 219),
#               ('cl', '08:09'),
#               ('de', '[DET] Drummond Rebound (Off:2 Def:6)')]),
#  OrderedDict([('evt', 220),
#               ('cl', '07:58'),
#               ('de',
#                '[DET] Jackson Turnover : Bad Pass (1 TO) Steal:Lamb (1 ST)')]),
#  OrderedDict([('evt', 222),
#               ('cl', '07:53'),
#               ('de', '[IND] Lamb Jump Shot: Missed')]),
#  OrderedDict([('evt', 223),
#               ('cl', '07:50'),
#               ('de', '[DET] Drummond Rebound (Off:2 Def:7)')]),
#  OrderedDict([('evt', 224),
#               ('cl', '07:44'),
#               ('de',
#                '[DET 36-33] Brown Finger Roll Layup Shot: Made (2 PTS) Assist: Jackson (2 AST)')]),
#  OrderedDict([('evt', 226),
#               ('cl', '07:38'),
#               ('de', '[IND] Team Timeout : Regular')]),
#  OrderedDict([('evt', 229),
#               ('cl', '07:38'),
#               ('de', '[IND] Holiday Substitution replaced by McConnell')]),
#  OrderedDict([('evt', 230),
#               ('cl', '07:38'),
#               ('de', '[IND] Sabonis Substitution replaced by Brogdon')]),
#  OrderedDict([('evt', 231),
#               ('cl', '07:38'),
#               ('de', '[IND] Leaf Substitution replaced by Turner')]),
#  OrderedDict([('evt', 232),
#               ('cl', '07:38'),
#               ('de', '[DET] Jackson Substitution replaced by Rose')]),
#  OrderedDict([('evt', 233),
#               ('cl', '07:38'),
#               ('de', '[DET] Galloway Substitution replaced by Snell')]),
#  OrderedDict([('evt', 239),
#               ('cl', '07:23'),
#               ('de',
#                '[IND 35-36] Turner Jump Shot: Made (4 PTS) Assist: Brogdon (1 AST)')]),
#  OrderedDict([('evt', 241),
#               ('cl', '07:03'),
#               ('de',
#                '[DET 38-35] Brown Driving Layup Shot: Made (4 PTS) Assist: Drummond (2 AST)')]),
#  OrderedDict([('evt', 243),
#               ('cl', '06:41'),
#               ('de',
#                '[IND 37-38] Brogdon Driving Finger Roll Layup Shot: Made (5 PTS)')]),
#  OrderedDict([('evt', 244),
#               ('cl', '06:26'),
#               ('de', '[IND] Lamb Foul: Personal (3 PF) (M Davis)')]),
#  OrderedDict([('evt', 246),
#               ('cl', '06:26'),
#               ('de', '[DET] Drummond Substitution replaced by Maker')]),
#  OrderedDict([('evt', 248),
#               ('cl', '06:18'),
#               ('de',
#                '[DET 40-37] Rose Driving Layup Shot: Made (9 PTS) Assist: Brown (2 AST)')]),
#  OrderedDict([('evt', 250),
#               ('cl', '06:07'),
#               ('de', '[IND] Turner Finger Roll Layup Shot: Missed')]),
#  OrderedDict([('evt', 251),
#               ('cl', '06:04'),
#               ('de', '[DET] Brown Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 252),
#               ('cl', '05:57'),
#               ('de',
#                '[DET 42-37] Mark Morris Turnaround Fadeaway Bank Jump Shot: Made (2 PTS) Assist: Brown (3 AST)')]),
#  OrderedDict([('evt', 254),
#               ('cl', '05:35'),
#               ('de',
#                '[IND 40-42] Turner 3pt Shot: Made (7 PTS) Assist: Lamb (3 AST)')]),
#  OrderedDict([('evt', 256),
#               ('cl', '05:19'),
#               ('de', '[DET 44-40] Rose Pullup Jump shot: Made (11 PTS)')]),
#  OrderedDict([('evt', 257),
#               ('cl', '05:05'),
#               ('de', '[IND] Lamb Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 258),
#               ('cl', '05:03'),
#               ('de', '[DET] Maker Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 259),
#               ('cl', '04:54'),
#               ('de',
#                '[DET 46-40] Mark Morris Turnaround Fadeaway Bank Jump Shot: Made (4 PTS) Assist: Brown (4 AST)')]),
#  OrderedDict([('evt', 261),
#               ('cl', '04:43'),
#               ('de', '[DET] Snell Foul: Personal (2 PF) (B Taylor)')]),
#  OrderedDict([('evt', 263),
#               ('cl', '04:43'),
#               ('de', '[IND] Lamb Substitution replaced by Sabonis')]),
#  OrderedDict([('evt', 264),
#               ('cl', '04:43'),
#               ('de', '[DET] Maker Substitution replaced by Drummond')]),
#  OrderedDict([('evt', 267),
#               ('cl', '04:38'),
#               ('de',
#                '[IND] Turner Turnover : Bad Pass (2 TO) Steal:Drummond (2 ST)')]),
#  OrderedDict([('evt', 269),
#               ('cl', '04:34'),
#               ('de', '[DET] Mark Morris 3pt Shot: Missed')]),
#  OrderedDict([('evt', 270),
#               ('cl', '04:30'),
#               ('de', '[DET] Brown Rebound (Off:1 Def:1)')]),
#  OrderedDict([('evt', 271),
#               ('cl', '04:30'),
#               ('de', '[DET] Brown Tip Layup Shot: Missed')]),
#  OrderedDict([('evt', 272), ('cl', '04:30'), ('de', '[IND] Team Rebound')]),
#  OrderedDict([('evt', 273),
#               ('cl', '04:30'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 274),
#               ('cl', '04:30'),
#               ('de', '[DET] Team Timeout : Regular')]),
#  OrderedDict([('evt', 275),
#               ('cl', '04:10'),
#               ('de', '[IND] Turner 3pt Shot: Missed')]),
#  OrderedDict([('evt', 276),
#               ('cl', '04:07'),
#               ('de', '[DET] Drummond Rebound (Off:2 Def:8)')]),
#  OrderedDict([('evt', 277),
#               ('cl', '03:51'),
#               ('de', '[DET] Mark Morris Jump Shot: Missed')]),
#  OrderedDict([('evt', 278),
#               ('cl', '03:48'),
#               ('de', '[IND] McConnell Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 279),
#               ('cl', '03:44'),
#               ('de',
#                '[IND 42-46] McConnell Running Finger Roll Layup Shot: Made (2 PTS)')]),
#  OrderedDict([('evt', 280),
#               ('cl', '03:18'),
#               ('de',
#                '[DET] Brown Turnover : Bad Pass (1 TO) Steal:Turner (1 ST)')]),
#  OrderedDict([('evt', 282),
#               ('cl', '03:13'),
#               ('de', '[IND] Brogdon Running Finger Roll Layup Shot: Missed')]),
#  OrderedDict([('evt', 283),
#               ('cl', '03:09'),
#               ('de', '[IND] Warren Rebound (Off:1 Def:0)')]),
#  OrderedDict([('evt', 284),
#               ('cl', '03:09'),
#               ('de', '[IND 44-46] Warren Tip Layup Shot: Made (8 PTS)')]),
#  OrderedDict([('evt', 285),
#               ('cl', '03:01'),
#               ('de', '[DET 48-44] Rose Pullup Jump shot: Made (13 PTS)')]),
#  OrderedDict([('evt', 286),
#               ('cl', '02:48'),
#               ('de', '[IND] Brogdon Layup Shot: Missed')]),
#  OrderedDict([('evt', 288),
#               ('cl', '02:45'),
#               ('de', '[DET] Rose Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 289),
#               ('cl', '02:42'),
#               ('de',
#                '[DET 50-44] Brown Cutting Layup Shot: Made (6 PTS) Assist: Rose (2 AST)')]),
#  OrderedDict([('evt', 291),
#               ('cl', '02:24'),
#               ('de',
#                '[IND 47-50] Turner 3pt Shot: Made (10 PTS) Assist: McConnell (1 AST)')]),
#  OrderedDict([('evt', 293),
#               ('cl', '01:59'),
#               ('de', '[DET] Drummond Jump Shot: Missed')]),
#  OrderedDict([('evt', 295),
#               ('cl', '01:57'),
#               ('de', '[IND] McConnell Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 296),
#               ('cl', '01:50'),
#               ('de',
#                '[IND 49-50] Sabonis Cutting Finger Roll Layup Shot: Made (10 PTS) Assist: Brogdon (2 AST)')]),
#  OrderedDict([('evt', 298),
#               ('cl', '01:25'),
#               ('de', '[IND] Turner Foul: Personal (1 PF) (B Taylor)')]),
#  OrderedDict([('evt', 300),
#               ('cl', '01:25'),
#               ('de', '[DET] Brown Substitution replaced by Maker')]),
#  OrderedDict([('evt', 301),
#               ('cl', '01:25'),
#               ('de', '[DET] Mark Morris Substitution replaced by Kennard')]),
#  OrderedDict([('evt', 304),
#               ('cl', '01:18'),
#               ('de',
#                '[DET 52-49] Rose Driving Floating Jump Shot: Made (15 PTS)')]),
#  OrderedDict([('evt', 305),
#               ('cl', '01:04'),
#               ('de',
#                '[IND 51-52] Brogdon Floating Jump shot: Made (7 PTS) Assist: Sabonis (2 AST)')]),
#  OrderedDict([('evt', 307),
#               ('cl', '00:52.9'),
#               ('de', '[DET] Kennard Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 308),
#               ('cl', '00:50.0'),
#               ('de', '[DET] Drummond Rebound (Off:3 Def:8)')]),
#  OrderedDict([('evt', 309),
#               ('cl', '00:50.0'),
#               ('de', '[DET] Drummond Tip Layup Shot: Missed')]),
#  OrderedDict([('evt', 310),
#               ('cl', '00:49.2'),
#               ('de', '[IND] Sabonis Rebound (Off:2 Def:5)')]),
#  OrderedDict([('evt', 311),
#               ('cl', '00:43.5'),
#               ('de',
#                '[IND] McConnell Driving Finger Roll Layup Shot: Missed')]),
#  OrderedDict([('evt', 312),
#               ('cl', '00:42.9'),
#               ('de', '[IND] Turner Rebound (Off:1 Def:2)')]),
#  OrderedDict([('evt', 313),
#               ('cl', '00:42.9'),
#               ('de', '[IND 53-52] Turner Tip Dunk Shot: Made (12 PTS)')]),
#  OrderedDict([('evt', 314),
#               ('cl', '00:17.5'),
#               ('de',
#                '[DET 54-53] Snell Pullup Jump shot: Made (2 PTS) Assist: Rose (3 AST)')]),
#  OrderedDict([('evt', 316),
#               ('cl', '00:03.7'),
#               ('de', '[DET] Maker Foul: Shooting (1 PF) (2 FTA) (B Taylor)')]),
#  OrderedDict([('evt', 318),
#               ('cl', '00:03.7'),
#               ('de', '[IND 54-54] Brogdon Free Throw 1 of 2 (8 PTS)')]),
#  OrderedDict([('evt', 319),
#               ('cl', '00:03.7'),
#               ('de', '[IND] Sabonis Substitution replaced by Holiday')]),
#  OrderedDict([('evt', 321),
#               ('cl', '00:03.7'),
#               ('de', '[IND 55-54] Brogdon Free Throw 2 of 2 (9 PTS)')]),
#  OrderedDict([('evt', 322),
#               ('cl', '00:00.5'),
#               ('de', '[DET] Drummond 3pt Shot: Missed')]),
#  OrderedDict([('evt', 324),
#               ('cl', '00:00.5'),
#               ('de', '[IND] Turner Rebound (Off:1 Def:3)')]),
#  OrderedDict([('evt', 325), ('cl', '00:00.0'), ('de', 'End Period')]),
#  OrderedDict([('evt', 336), ('cl', '12:00'), ('de', 'Start Period')]),
#  OrderedDict([('evt', 337),
#               ('cl', '11:41'),
#               ('de', '[IND 58-54] Brogdon 3pt Shot: Made (12 PTS)')]),
#  OrderedDict([('evt', 338),
#               ('cl', '11:18'),
#               ('de',
#                '[DET 56-58] Drummond Reverse Layup Shot: Made (12 PTS) Assist: Jackson (3 AST)')]),
#  OrderedDict([('evt', 340),
#               ('cl', '11:03'),
#               ('de', '[IND] Warren Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 341),
#               ('cl', '11:01'),
#               ('de', '[DET] Drummond Rebound (Off:3 Def:9)')]),
#  OrderedDict([('evt', 342),
#               ('cl', '10:53'),
#               ('de',
#                '[DET 59-58] Mark Morris 3pt Shot: Made (7 PTS) Assist: Jackson (4 AST)')]),
#  OrderedDict([('evt', 344),
#               ('cl', '10:38'),
#               ('de', '[IND] Lamb Driving Floating Bank Jump Shot: Missed')]),
#  OrderedDict([('evt', 345),
#               ('cl', '10:34'),
#               ('de', '[DET] Drummond Rebound (Off:3 Def:10)')]),
#  OrderedDict([('evt', 346),
#               ('cl', '10:32'),
#               ('de', '[IND] Turner Foul: Shooting (2 PF) (2 FTA) (M Davis)')]),
#  OrderedDict([('evt', 348),
#               ('cl', '10:32'),
#               ('de', '[DET 60-58] Drummond Free Throw 1 of 2 (13 PTS)')]),
#  OrderedDict([('evt', 349),
#               ('cl', '10:32'),
#               ('de', '[DET 61-58] Drummond Free Throw 2 of 2 (14 PTS)')]),
#  OrderedDict([('evt', 350),
#               ('cl', '10:19'),
#               ('de', '[IND] Team Timeout : Regular')]),
#  OrderedDict([('evt', 351),
#               ('cl', '10:12'),
#               ('de',
#                '[IND 60-61] Warren Pullup Jump shot: Made (10 PTS) Assist: Brogdon (3 AST)')]),
#  OrderedDict([('evt', 353),
#               ('cl', '09:50'),
#               ('de',
#                '[IND] Sabonis Foul: Shooting (1 PF) (2 FTA) (B Nansel)')]),
#  OrderedDict([('evt', 355),
#               ('cl', '09:50'),
#               ('de', '[DET] Mark Morris Free Throw 1 of 2 Missed')]),
#  OrderedDict([('evt', 356), ('cl', '09:50'), ('de', '[DET] Team Rebound')]),
#  OrderedDict([('evt', 357),
#               ('cl', '09:50'),
#               ('de', '[DET 62-60] Mark Morris Free Throw 2 of 2 (8 PTS)')]),
#  OrderedDict([('evt', 358),
#               ('cl', '09:35'),
#               ('de', '[IND] Warren Driving Layup Shot: Missed')]),
#  OrderedDict([('evt', 359),
#               ('cl', '09:33'),
#               ('de', '[DET] Drummond Rebound (Off:3 Def:11)')]),
#  OrderedDict([('evt', 360),
#               ('cl', '09:25'),
#               ('de',
#                '[DET 64-60] Drummond Driving Reverse Layup Shot: Made (16 PTS)')]),
#  OrderedDict([('evt', 361),
#               ('cl', '09:14'),
#               ('de',
#                '[IND 63-64] Turner 3pt Shot: Made (15 PTS) Assist: Brogdon (4 AST)')]),
#  OrderedDict([('evt', 363),
#               ('cl', '08:51'),
#               ('de', '[DET] Brown Foul: Offensive (1 PF)')]),
#  OrderedDict([('evt', 365),
#               ('cl', '08:51'),
#               ('de',
#                '[DET] Brown Turnover : Offensive Foul Turnover (2 TO)')]),
#  OrderedDict([('evt', 366),
#               ('cl', '08:45'),
#               ('de', '[IND] Brogdon Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 367),
#               ('cl', '08:41'),
#               ('de', '[IND] Sabonis Rebound (Off:3 Def:5)')]),
#  OrderedDict([('evt', 368),
#               ('cl', '08:41'),
#               ('de', '[IND 65-64] Sabonis Tip Layup Shot: Made (12 PTS)')]),
#  OrderedDict([('evt', 369),
#               ('cl', '08:27'),
#               ('de', '[IND] Sabonis Foul: Personal (2 PF) (B Taylor)')]),
#  OrderedDict([('evt', 371),
#               ('cl', '08:15'),
#               ('de',
#                '[DET] Mark Morris Driving Finger Roll Layup Shot: Missed')]),
#  OrderedDict([('evt', 372),
#               ('cl', '08:13'),
#               ('de', '[IND] Sabonis Rebound (Off:3 Def:6)')]),
#  OrderedDict([('evt', 373),
#               ('cl', '08:04'),
#               ('de', '[IND] Warren 3pt Shot: Missed')]),
#  OrderedDict([('evt', 374),
#               ('cl', '08:02'),
#               ('de', '[IND] Sabonis Rebound (Off:4 Def:6)')]),
#  OrderedDict([('evt', 375),
#               ('cl', '07:58'),
#               ('de', '[DET] Drummond Foul: Personal (3 PF) (B Taylor)')]),
#  OrderedDict([('evt', 377),
#               ('cl', '07:53'),
#               ('de',
#                '[DET] Drummond Foul: Shooting (4 PF) (2 FTA) (M Davis)')]),
#  OrderedDict([('evt', 379),
#               ('cl', '07:53'),
#               ('de', '[IND 66-64] Brogdon Free Throw 1 of 2 (13 PTS)')]),
#  OrderedDict([('evt', 380),
#               ('cl', '07:53'),
#               ('de', '[IND] Brogdon Free Throw 2 of 2 Missed')]),
#  OrderedDict([('evt', 381),
#               ('cl', '07:51'),
#               ('de', '[DET] Drummond Rebound (Off:3 Def:12)')]),
#  OrderedDict([('evt', 382),
#               ('cl', '07:32'),
#               ('de', '[DET] Mark Morris Step Back Jump shot: Missed')]),
#  OrderedDict([('evt', 384),
#               ('cl', '07:30'),
#               ('de', '[IND] Brogdon Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 385),
#               ('cl', '07:27'),
#               ('de', '[IND] Warren Turnaround Jump Shot: Missed')]),
#  OrderedDict([('evt', 386),
#               ('cl', '07:25'),
#               ('de', '[IND] Sabonis Rebound (Off:5 Def:6)')]),
#  OrderedDict([('evt', 387),
#               ('cl', '07:25'),
#               ('de', '[DET] Brown Foul: Shooting (2 PF) (2 FTA) (B Nansel)')]),
#  OrderedDict([('evt', 389),
#               ('cl', '07:25'),
#               ('de', '[IND 67-64] Sabonis Free Throw 1 of 2 (13 PTS)')]),
#  OrderedDict([('evt', 390),
#               ('cl', '07:25'),
#               ('de', '[DET] Drummond Substitution replaced by Maker')]),
#  OrderedDict([('evt', 392),
#               ('cl', '07:25'),
#               ('de', '[IND 68-64] Sabonis Free Throw 2 of 2 (14 PTS)')]),
#  OrderedDict([('evt', 393),
#               ('cl', '07:08'),
#               ('de', '[DET] Snell Jump Shot: Missed')]),
#  OrderedDict([('evt', 394),
#               ('cl', '07:05'),
#               ('de', '[IND] Sabonis Rebound (Off:5 Def:7)')]),
#  OrderedDict([('evt', 395),
#               ('cl', '07:00'),
#               ('de', '[DET] Snell Foul: Personal (3 PF) (M Davis)')]),
#  OrderedDict([('evt', 397),
#               ('cl', '07:00'),
#               ('de', '[DET] Snell Substitution replaced by Kennard')]),
#  OrderedDict([('evt', 399),
#               ('cl', '06:48'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 400),
#               ('cl', '06:45'),
#               ('de',
#                '[DET] Jackson Foul: Shooting (1 PF) (2 FTA) (B Taylor)')]),
#  OrderedDict([('evt', 402),
#               ('cl', '06:45'),
#               ('de', '[IND 69-64] Turner Free Throw 1 of 2 (16 PTS)')]),
#  OrderedDict([('evt', 403),
#               ('cl', '06:45'),
#               ('de', '[IND 70-64] Turner Free Throw 2 of 2 (17 PTS)')]),
#  OrderedDict([('evt', 404),
#               ('cl', '06:38'),
#               ('de', '[DET] Kennard Foul: Offensive (1 PF) (M Davis)')]),
#  OrderedDict([('evt', 406),
#               ('cl', '06:38'),
#               ('de',
#                '[DET] Kennard Turnover : Offensive Foul Turnover (1 TO)')]),
#  OrderedDict([('evt', 407),
#               ('cl', '06:26'),
#               ('de', '[IND] Sabonis Turnaround Hook Shot: Missed')]),
#  OrderedDict([('evt', 408), ('cl', '06:25'), ('de', '[IND] Team Rebound')]),
#  OrderedDict([('evt', 409),
#               ('cl', '06:25'),
#               ('de',
#                '[DET] Kennard Foul: Loose Ball (2 PF) (2 FTA) (B Taylor)')]),
#  OrderedDict([('evt', 411),
#               ('cl', '06:25'),
#               ('de', '[IND] Lamb Free Throw 1 of 2 Missed')]),
#  OrderedDict([('evt', 412), ('cl', '06:25'), ('de', '[IND] Team Rebound')]),
#  OrderedDict([('evt', 413),
#               ('cl', '06:25'),
#               ('de', '[IND 71-64] Lamb Free Throw 2 of 2 (3 PTS)')]),
#  OrderedDict([('evt', 414),
#               ('cl', '06:22'),
#               ('de', '[DET] Team Timeout : Regular')]),
#  OrderedDict([('evt', 415),
#               ('cl', '06:22'),
#               ('de', '[DET] Jackson Substitution replaced by Drummond')]),
#  OrderedDict([('evt', 416),
#               ('cl', '06:22'),
#               ('de', '[DET] Mark Morris Substitution replaced by Rose')]),
#  OrderedDict([('evt', 427),
#               ('cl', '06:22'),
#               ('de', '[DET] Brown Substitution replaced by Galloway')]),
#  OrderedDict([('evt', 419),
#               ('cl', '06:18'),
#               ('de', '[IND] Warren Foul: Personal (1 PF) (B Taylor)')]),
#  OrderedDict([('evt', 421),
#               ('cl', '06:09'),
#               ('de', '[DET] Maker 3pt Shot: Missed')]),
#  OrderedDict([('evt', 422),
#               ('cl', '06:06'),
#               ('de', '[IND] Brogdon Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 423),
#               ('cl', '06:04'),
#               ('de',
#                '[DET] Galloway Foul: Personal (1 PF) (2 FTA) (B Taylor)')]),
#  OrderedDict([('evt', 425),
#               ('cl', '06:04'),
#               ('de', '[IND 72-64] Sabonis Free Throw 1 of 2 (15 PTS)')]),
#  OrderedDict([('evt', 426),
#               ('cl', '06:04'),
#               ('de', '[IND 73-64] Sabonis Free Throw 2 of 2 (16 PTS)')]),
#  OrderedDict([('evt', 429),
#               ('cl', '05:48'),
#               ('de',
#                '[DET] Rose Turnover : Out of Bounds - Bad Pass Turnover (4 TO)')]),
#  OrderedDict([('evt', 430),
#               ('cl', '05:40'),
#               ('de', '[IND] Turner Turnover : Traveling (3 TO)')]),
#  OrderedDict([('evt', 431),
#               ('cl', '05:24'),
#               ('de', '[DET] Kennard 3pt Shot: Missed')]),
#  OrderedDict([('evt', 432),
#               ('cl', '05:19'),
#               ('de', '[IND] Turner Rebound (Off:1 Def:4)')]),
#  OrderedDict([('evt', 433),
#               ('cl', '05:06'),
#               ('de',
#                '[IND] Sabonis Turnover : Out of Bounds - Bad Pass Turnover (1 TO)')]),
#  OrderedDict([('evt', 466),
#               ('cl', '04:57'),
#               ('de',
#                '[DET] Drummond Turnover : Out of Bounds Lost Ball Turnover (2 TO)')]),
#  OrderedDict([('evt', 435),
#               ('cl', '04:44'),
#               ('de', '[IND] Warren Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 436),
#               ('cl', '04:42'),
#               ('de', '[DET] Maker Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 437),
#               ('cl', '04:36'),
#               ('de',
#                '[DET 66-73] Rose Driving Floating Jump Shot: Made (17 PTS)')]),
#  OrderedDict([('evt', 438),
#               ('cl', '04:36'),
#               ('de',
#                '[IND] Warren Foul: Shooting (2 PF) (1 FTA) (B Taylor)')]),
#  OrderedDict([('evt', 440),
#               ('cl', '04:36'),
#               ('de', '[IND] Sabonis Substitution replaced by Leaf')]),
#  OrderedDict([('evt', 442),
#               ('cl', '04:36'),
#               ('de', '[DET 67-73] Rose Free Throw 1 of 1 (18 PTS)')]),
#  OrderedDict([('evt', 443),
#               ('cl', '04:24'),
#               ('de',
#                '[IND 75-67] Lamb Jump Shot: Made (5 PTS) Assist: Brogdon (5 AST)')]),
#  OrderedDict([('evt', 445),
#               ('cl', '04:15'),
#               ('de', '[IND] Turner Violation:Kicked Ball (B Taylor)')]),
#  OrderedDict([('evt', 446),
#               ('cl', '04:15'),
#               ('de', '[IND] Lamb Substitution replaced by Sumner')]),
#  OrderedDict([('evt', 447),
#               ('cl', '04:15'),
#               ('de', '[DET] Drummond Substitution replaced by Snell')]),
#  OrderedDict([('evt', 450),
#               ('cl', '04:04'),
#               ('de',
#                '[DET 70-75] Snell 3pt Shot: Made (5 PTS) Assist: Rose (4 AST)')]),
#  OrderedDict([('evt', 452),
#               ('cl', '03:47'),
#               ('de',
#                '[IND 77-70] Turner Cutting Layup Shot: Made (19 PTS) Assist: Brogdon (6 AST)')]),
#  OrderedDict([('evt', 454),
#               ('cl', '03:47'),
#               ('de', '[DET] Maker Foul: Shooting (2 PF) (1 FTA) (M Davis)')]),
#  OrderedDict([('evt', 456),
#               ('cl', '03:47'),
#               ('de', '[IND] Leaf Substitution replaced by Holiday')]),
#  OrderedDict([('evt', 458),
#               ('cl', '03:47'),
#               ('de', '[IND 78-70] Turner Free Throw 1 of 1 (20 PTS)')]),
#  OrderedDict([('evt', 459),
#               ('cl', '03:25'),
#               ('de',
#                '[DET 72-78] Maker Step Back Jump shot: Made (2 PTS) Assist: Kennard (1 AST)')]),
#  OrderedDict([('evt', 461),
#               ('cl', '03:12'),
#               ('de', '[DET] Snell Foul: Personal (4 PF) (2 FTA) (B Nansel)')]),
#  OrderedDict([('evt', 463),
#               ('cl', '03:12'),
#               ('de', '[IND 79-72] Brogdon Free Throw 1 of 2 (14 PTS)')]),
#  OrderedDict([('evt', 464),
#               ('cl', '03:12'),
#               ('de', '[IND 80-72] Brogdon Free Throw 2 of 2 (15 PTS)')]),
#  OrderedDict([('evt', 465),
#               ('cl', '02:58'),
#               ('de',
#                '[DET 75-80] Kennard 3pt Shot: Made (10 PTS) Assist: Snell (1 AST)')]),
#  OrderedDict([('evt', 467),
#               ('cl', '02:43'),
#               ('de', '[IND] Sumner Finger Roll Layup Shot: Missed')]),
#  OrderedDict([('evt', 468),
#               ('cl', '02:43'),
#               ('de', '[DET] Galloway Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 469),
#               ('cl', '02:18'),
#               ('de',
#                '[DET 77-80] Snell Driving Floating Bank Jump Shot: Made (7 PTS) Assist: Kennard (2 AST)')]),
#  OrderedDict([('evt', 472),
#               ('cl', '02:02'),
#               ('de', '[IND] Turner 3pt Shot: Missed')]),
#  OrderedDict([('evt', 473),
#               ('cl', '01:58'),
#               ('de', '[DET] Rose Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 474),
#               ('cl', '01:50'),
#               ('de', '[DET] Rose Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 475),
#               ('cl', '01:48'),
#               ('de', '[IND] Turner Rebound (Off:1 Def:5)')]),
#  OrderedDict([('evt', 476),
#               ('cl', '01:39'),
#               ('de', '[DET] Maker Foul: Personal (3 PF) (2 FTA) (M Davis)')]),
#  OrderedDict([('evt', 478),
#               ('cl', '01:39'),
#               ('de', '[IND 81-77] Brogdon Free Throw 1 of 2 (16 PTS)')]),
#  OrderedDict([('evt', 479),
#               ('cl', '01:39'),
#               ('de', '[IND] Warren Substitution replaced by Sabonis')]),
#  OrderedDict([('evt', 480),
#               ('cl', '01:39'),
#               ('de', '[IND] Turner Substitution replaced by McDermott')]),
#  OrderedDict([('evt', 481),
#               ('cl', '01:39'),
#               ('de', '[DET] Snell Substitution replaced by Drummond')]),
#  OrderedDict([('evt', 485),
#               ('cl', '01:39'),
#               ('de', '[IND 82-77] Brogdon Free Throw 2 of 2 (17 PTS)')]),
#  OrderedDict([('evt', 486),
#               ('cl', '01:27'),
#               ('de', '[IND] Sumner Foul: Shooting (3 PF) (2 FTA) (M Davis)')]),
#  OrderedDict([('evt', 488),
#               ('cl', '01:27'),
#               ('de', '[DET] Kennard Free Throw 1 of 2 Missed')]),
#  OrderedDict([('evt', 489), ('cl', '01:27'), ('de', '[DET] Team Rebound')]),
#  OrderedDict([('evt', 490),
#               ('cl', '01:27'),
#               ('de', '[IND] Brogdon Substitution replaced by McConnell')]),
#  OrderedDict([('evt', 492),
#               ('cl', '01:27'),
#               ('de', '[DET 78-82] Kennard Free Throw 2 of 2 (11 PTS)')]),
#  OrderedDict([('evt', 493),
#               ('cl', '01:12'),
#               ('de',
#                '[IND 84-78] Sabonis Layup Shot: Made (18 PTS) Assist: Holiday (2 AST)')]),
#  OrderedDict([('evt', 495),
#               ('cl', '00:45.9'),
#               ('de', '[DET] Maker 3pt Shot: Missed')]),
#  OrderedDict([('evt', 496),
#               ('cl', '00:43.8'),
#               ('de', '[IND] McConnell Rebound (Off:0 Def:3)')]),
#  OrderedDict([('evt', 497),
#               ('cl', '00:37.0'),
#               ('de', '[IND] Holiday Driving Dunk Shot: Missed')]),
#  OrderedDict([('evt', 498),
#               ('cl', '00:34.7'),
#               ('de', '[DET] Drummond Rebound (Off:3 Def:13)')]),
#  OrderedDict([('evt', 499),
#               ('cl', '00:30.4'),
#               ('de',
#                '[IND] McConnell Foul: Shooting (1 PF) (2 FTA) (B Nansel)')]),
#  OrderedDict([('evt', 501),
#               ('cl', '00:30.4'),
#               ('de', '[DET 79-84] Drummond Free Throw 1 of 2 (17 PTS)')]),
#  OrderedDict([('evt', 502),
#               ('cl', '00:30.4'),
#               ('de', '[DET] Maker Substitution replaced by Brown')]),
#  OrderedDict([('evt', 504),
#               ('cl', '00:30.4'),
#               ('de', '[DET 80-84] Drummond Free Throw 2 of 2 (18 PTS)')]),
#  OrderedDict([('evt', 505),
#               ('cl', '00:20.9'),
#               ('de', '[IND] Sumner Jump Shot: Missed')]),
#  OrderedDict([('evt', 506), ('cl', '00:16.3'), ('de', '[IND] Team Rebound')]),
#  OrderedDict([('evt', 510),
#               ('cl', '00:16.3'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 511),
#               ('cl', '00:08.3'),
#               ('de',
#                '[IND 86-80] Sabonis Jump Shot: Made (20 PTS) Assist: McConnell (2 AST)')]),
#  OrderedDict([('evt', 513),
#               ('cl', '00:01.3'),
#               ('de', '[DET 83-86] Kennard 3pt Shot: Made (14 PTS)')]),
#  OrderedDict([('evt', 514),
#               ('cl', '00:01.0'),
#               ('de',
#                '[IND] McDermott Turnover : Bad Pass (1 TO) Steal:Drummond (3 ST)')]),
#  OrderedDict([('evt', 516), ('cl', '00:00.0'), ('de', 'End Period')]),
#  OrderedDict([('evt', 519), ('cl', '12:00'), ('de', 'Start Period')]),
# ...
#               ('de', '[DET] Snell 3pt Shot: Missed')]),
#  OrderedDict([('evt', 550),
#               ('cl', '09:30'),
#               ('de', '[DET] Drummond Rebound (Off:4 Def:13)')]),
#  OrderedDict([('evt', 551),
#               ('cl', '09:29'),
#               ('de',
#                '[DET 89-91] Drummond Driving Dunk Shot: Made (24 PTS)')]),
#  OrderedDict([('evt', 555),
#               ('cl', '09:19'),
#               ('de', '[IND] Turner Foul: Offensive (3 PF) (B Taylor)')]),
#  OrderedDict([('evt', 557),
#               ('cl', '09:19'),
#               ('de',
#                '[IND] Turner Turnover : Offensive Foul Turnover (4 TO)')]),
#  OrderedDict([('evt', 558),
#               ('cl', '09:19'),
#               ('de', '[DET] Team Timeout : Regular')]),
#  OrderedDict([('evt', 560),
#               ('cl', '09:09'),
#               ('de', '[DET] Drummond Cutting Dunk Shot: Missed')]),
#  OrderedDict([('evt', 562),
#               ('cl', '09:06'),
#               ('de', '[DET] Drummond Rebound (Off:5 Def:13)')]),
#  OrderedDict([('evt', 563),
#               ('cl', '09:04'),
#               ('de',
#                '[DET 91-91] Drummond Driving Layup Shot: Made (26 PTS)')]),
#  OrderedDict([('evt', 564),
#               ('cl', '08:49'),
#               ('de', '[IND] McConnell Turnaround Jump Shot: Missed')]),
#  OrderedDict([('evt', 565),
#               ('cl', '08:47'),
#               ('de', '[DET] Drummond Rebound (Off:5 Def:14)')]),
#  OrderedDict([('evt', 566),
#               ('cl', '08:41'),
#               ('de', '[DET] Drummond Jump Shot: Missed')]),
#  OrderedDict([('evt', 568),
#               ('cl', '08:37'),
#               ('de', '[IND] Turner Rebound (Off:1 Def:6)')]),
#  OrderedDict([('evt', 570),
#               ('cl', '08:25'),
#               ('de',
#                '[IND 93-91] Turner Layup Shot: Made (25 PTS) Assist: Sumner (2 AST)')]),
#  OrderedDict([('evt', 572),
#               ('cl', '08:02'),
#               ('de',
#                '[IND] Holiday Foul: Shooting (3 PF) (2 FTA) (B Taylor)')]),
#  OrderedDict([('evt', 574),
#               ('cl', '08:02'),
#               ('de', '[DET 92-93] Kennard Free Throw 1 of 2 (15 PTS)')]),
#  OrderedDict([('evt', 575),
#               ('cl', '08:02'),
#               ('de', '[IND] Holiday Substitution replaced by Brogdon')]),
#  OrderedDict([('evt', 576),
#               ('cl', '08:02'),
#               ('de', '[IND] McDermott Substitution replaced by Warren')]),
#  OrderedDict([('evt', 577),
#               ('cl', '08:02'),
#               ('de', '[DET] Drummond Substitution replaced by Maker')]),
#  OrderedDict([('evt', 578),
#               ('cl', '08:02'),
#               ('de', '[DET] Jackson Substitution replaced by Frazier')]),
#  OrderedDict([('evt', 583),
#               ('cl', '08:02'),
#               ('de', '[DET 93-93] Kennard Free Throw 2 of 2 (16 PTS)')]),
#  OrderedDict([('evt', 584),
#               ('cl', '07:49'),
#               ('de', '[IND] Sumner Floating Jump shot: Missed')]),
#  OrderedDict([('evt', 585),
#               ('cl', '07:47'),
#               ('de', '[DET] Snell Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 586),
#               ('cl', '07:41'),
#               ('de',
#                '[DET 95-93] Kennard Step Back Jump shot: Made (18 PTS) Assist: Snell (2 AST)')]),
#  OrderedDict([('evt', 587),
#               ('cl', '07:40'),
#               ('de', '[IND] Team Timeout : Regular')]),
#  OrderedDict([('evt', 588),
#               ('cl', '07:40'),
#               ('de', '[IND] Sumner Substitution replaced by Sabonis')]),
#  OrderedDict([('evt', 589),
#               ('cl', '07:40'),
#               ('de', '[IND] McConnell Substitution replaced by Lamb')]),
#  OrderedDict([('evt', 590),
#               ('cl', '07:40'),
#               ('de', '[DET] Galloway Substitution replaced by Brown')]),
#  OrderedDict([('evt', 591),
#               ('cl', '07:40'),
#               ('de', '[DET] Snell Substitution replaced by Drummond')]),
#  OrderedDict([('evt', 596),
#               ('cl', '07:28'),
#               ('de', '[DET] Drummond Foul: Personal (5 PF) (B Nansel)')]),
#  OrderedDict([('evt', 598),
#               ('cl', '07:21'),
#               ('de',
#                '[DET] Kennard Foul: Shooting (3 PF) (2 FTA) (M Davis)')]),
#  OrderedDict([('evt', 600),
#               ('cl', '07:21'),
#               ('de', '[IND 94-95] Brogdon Free Throw 1 of 2 (18 PTS)')]),
#  OrderedDict([('evt', 601),
#               ('cl', '07:21'),
#               ('de', '[IND 95-95] Brogdon Free Throw 2 of 2 (19 PTS)')]),
#  OrderedDict([('evt', 602),
#               ('cl', '07:07'),
#               ('de', '[DET] Frazier Turnaround Jump Shot: Missed')]),
#  OrderedDict([('evt', 604),
#               ('cl', '07:04'),
#               ('de', '[DET] Drummond Rebound (Off:6 Def:14)')]),
#  OrderedDict([('evt', 605),
#               ('cl', '06:58'),
#               ('de',
#                '[IND] Sabonis Foul: Shooting (5 PF) (2 FTA) (B Nansel)')]),
#  OrderedDict([('evt', 607),
#               ('cl', '06:58'),
#               ('de', '[DET 96-95] Maker Free Throw 1 of 2 (3 PTS)')]),
#  OrderedDict([('evt', 608),
#               ('cl', '06:58'),
#               ('de', '[DET] Frazier Substitution replaced by Rose')]),
#  OrderedDict([('evt', 610),
#               ('cl', '06:58'),
#               ('de', '[DET 97-95] Maker Free Throw 2 of 2 (4 PTS)')]),
#  OrderedDict([('evt', 611),
#               ('cl', '06:47'),
#               ('de',
#                '[IND 97-97] Sabonis Layup Shot: Made (22 PTS) Assist: Brogdon (7 AST)')]),
#  OrderedDict([('evt', 613),
#               ('cl', '06:47'),
#               ('de', '[DET] Rose Foul: Shooting (1 PF) (1 FTA) (B Nansel)')]),
#  OrderedDict([('evt', 615),
#               ('cl', '06:47'),
#               ('de', '[IND 98-97] Sabonis Free Throw 1 of 1 (23 PTS)')]),
#  OrderedDict([('evt', 616),
#               ('cl', '06:31'),
#               ('de', '[DET] Kennard 3pt Shot: Missed')]),
#  OrderedDict([('evt', 617),
#               ('cl', '06:27'),
#               ('de', '[IND] Brogdon Rebound (Off:0 Def:3)')]),
#  OrderedDict([('evt', 618),
#               ('cl', '06:14'),
#               ('de', '[IND] Sabonis Cutting Layup Shot: Missed')]),
#  OrderedDict([('evt', 620), ('cl', '06:13'), ('de', '[IND] Team Rebound')]),
#  OrderedDict([('evt', 621),
#               ('cl', '06:13'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 622),
#               ('cl', '06:13'),
#               ('de', '[IND] Sabonis Substitution replaced by Sumner')]),
#  OrderedDict([('evt', 624),
#               ('cl', '06:13'),
#               ('de', '[DET] Maker Substitution replaced by Snell')]),
#  OrderedDict([('evt', 626),
#               ('cl', '06:09'),
#               ('de',
#                '[IND 100-97] Lamb Jump Shot: Made (7 PTS) Assist: Brogdon (8 AST)')]),
#  OrderedDict([('evt', 628),
#               ('cl', '06:09'),
#               ('de', '[DET] Brown Foul: Shooting (3 PF) (1 FTA) (B Taylor)')]),
#  OrderedDict([('evt', 630),
#               ('cl', '06:09'),
#               ('de', '[IND 101-97] Lamb Free Throw 1 of 1 (8 PTS)')]),
#  OrderedDict([('evt', 631),
#               ('cl', '05:56'),
#               ('de', '[DET] Rose Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 632),
#               ('cl', '05:52'),
#               ('de', '[DET] Drummond Rebound (Off:7 Def:14)')]),
#  OrderedDict([('evt', 633),
#               ('cl', '05:52'),
#               ('de', '[DET 99-101] Drummond Tip Layup Shot: Made (28 PTS)')]),
#  OrderedDict([('evt', 634),
#               ('cl', '05:40'),
#               ('de',
#                '[IND] Brogdon Turnover : Out of Bounds Lost Ball Turnover (2 TO)')]),
#  OrderedDict([('evt', 635),
#               ('cl', '05:27'),
#               ('de',
#                '[DET 102-101] Kennard 3pt Shot: Made (21 PTS) Assist: Rose (5 AST)')]),
#  OrderedDict([('evt', 637),
#               ('cl', '05:03'),
#               ('de', '[IND] Lamb Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 638),
#               ('cl', '05:01'),
#               ('de', '[DET] Drummond Rebound (Off:7 Def:15)')]),
#  OrderedDict([('evt', 639),
#               ('cl', '04:45'),
#               ('de', '[DET] Rose Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 640),
#               ('cl', '04:42'),
#               ('de', '[DET] Rose Rebound (Off:1 Def:2)')]),
#  OrderedDict([('evt', 641),
#               ('cl', '04:40'),
#               ('de',
#                '[DET 105-101] Kennard 3pt Shot: Made (24 PTS) Assist: Rose (6 AST)')]),
#  OrderedDict([('evt', 643),
#               ('cl', '04:38'),
#               ('de', '[IND] Team Timeout : Regular')]),
#  OrderedDict([('evt', 645),
#               ('cl', '04:38'),
#               ('de', '[IND] Sumner Substitution replaced by Sabonis')]),
#  OrderedDict([('evt', 649),
#               ('cl', '04:38'),
#               ('de', '[DET] Kennard Substitution replaced by Maker')]),
#  OrderedDict([('evt', 650),
#               ('cl', '04:21'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 651),
#               ('cl', '04:15'),
#               ('de',
#                '[IND 103-105] Sabonis Jump Shot: Made (25 PTS) Assist: Brogdon (9 AST)')]),
#  OrderedDict([('evt', 652),
#               ('cl', '04:02'),
#               ('de', '[DET] Team Timeout : Regular')]),
#  OrderedDict([('evt', 654),
#               ('cl', '04:02'),
#               ('de', '[DET] Brown Substitution replaced by Kennard')]),
#  OrderedDict([('evt', 656),
#               ('cl', '03:54'),
#               ('de', '[DET] Maker 3pt Shot: Missed')]),
#  OrderedDict([('evt', 657),
#               ('cl', '03:50'),
#               ('de', '[IND] Lamb Rebound (Off:1 Def:2)')]),
#  OrderedDict([('evt', 658),
#               ('cl', '03:46'),
#               ('de',
#                '[IND] Warren Foul: Offensive Charge (3 PF) (B Taylor)')]),
#  OrderedDict([('evt', 660),
#               ('cl', '03:46'),
#               ('de',
#                '[IND] Warren Turnover : Offensive Foul Turnover (1 TO)')]),
#  OrderedDict([('evt', 661),
#               ('cl', '03:46'),
#               ('de', '[IND] Warren Substitution replaced by Sumner')]),
#  OrderedDict([('evt', 662),
#               ('cl', '03:46'),
#               ('de', '[DET] Maker Substitution replaced by Brown')]),
#  OrderedDict([('evt', 665),
#               ('cl', '03:38'),
#               ('de', '[DET] Rose Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 666),
#               ('cl', '03:33'),
#               ('de', '[IND] Lamb Rebound (Off:1 Def:3)')]),
#  OrderedDict([('evt', 667),
#               ('cl', '03:28'),
#               ('de', '[IND] Turner 3pt Shot: Missed')]),
#  OrderedDict([('evt', 668),
#               ('cl', '03:25'),
#               ('de', '[IND] Turner Rebound (Off:2 Def:6)')]),
#  OrderedDict([('evt', 669),
#               ('cl', '03:23'),
#               ('de', '[IND] Turner Driving Layup Shot: Missed')]),
#  OrderedDict([('evt', 671),
#               ('cl', '03:21'),
#               ('de', '[DET] Brown Rebound (Off:1 Def:2)')]),
#  OrderedDict([('evt', 672),
#               ('cl', '03:01'),
#               ('de',
#                '[DET 108-103] Snell 3pt Shot: Made (10 PTS) Assist: Rose (7 AST)')]),
#  OrderedDict([('evt', 674),
#               ('cl', '02:46'),
#               ('de', '[IND] Brogdon Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 675),
#               ('cl', '02:41'),
#               ('de', '[DET] Brown Rebound (Off:1 Def:3)')]),
#  OrderedDict([('evt', 676),
#               ('cl', '02:26'),
#               ('de', '[DET] Rose Driving Layup Shot: Missed')]),
#  OrderedDict([('evt', 677),
#               ('cl', '02:23'),
#               ('de', '[IND] Turner Rebound (Off:2 Def:7)')]),
#  OrderedDict([('evt', 678),
#               ('cl', '02:12'),
#               ('de', '[IND] Sabonis 3pt Shot: Missed')]),
#  OrderedDict([('evt', 679),
#               ('cl', '02:09'),
#               ('de', '[DET] Kennard Rebound (Off:0 Def:3)')]),
#  OrderedDict([('evt', 680),
#               ('cl', '01:50'),
#               ('de',
#                '[DET 110-103] Drummond Turnaround Hook Shot: Made (30 PTS) Assist: Rose (8 AST)')]),
#  OrderedDict([('evt', 682),
#               ('cl', '01:50'),
#               ('de', '[IND] Team Timeout : Regular')]),
#  OrderedDict([('evt', 683),
#               ('cl', '01:41'),
#               ('de', '[IND] Sabonis Hook Shot: Missed')]),
#  OrderedDict([('evt', 684),
#               ('cl', '01:38'),
#               ('de', '[DET] Drummond Rebound (Off:7 Def:16)')]),
#  OrderedDict([('evt', 685),
#               ('cl', '01:24'),
#               ('de',
#                '[DET 113-103] Kennard 3pt Shot: Made (27 PTS) Assist: Rose (9 AST)')]),
#  OrderedDict([('evt', 687),
#               ('cl', '01:12'),
#               ('de',
#                '[IND 105-113] Lamb Driving Floating Jump Shot: Made (10 PTS) Assist: Brogdon (10 AST)')]),
#  OrderedDict([('evt', 689),
#               ('cl', '00:53.4'),
#               ('de',
#                '[IND] Sumner Foul: Personal (4 PF) (2 FTA) (B Nansel)')]),
#  OrderedDict([('evt', 691),
#               ('cl', '00:53.4'),
#               ('de', '[DET 114-105] Kennard Free Throw 1 of 2 (28 PTS)')]),
#  OrderedDict([('evt', 692),
#               ('cl', '00:53.4'),
#               ('de', '[IND] Sumner Substitution replaced by McDermott')]),
#  OrderedDict([('evt', 694),
#               ('cl', '00:53.4'),
#               ('de', '[DET 115-105] Kennard Free Throw 2 of 2 (29 PTS)')]),
#  OrderedDict([('evt', 695),
#               ('cl', '00:47.8'),
#               ('de', '[IND 108-115] Brogdon 3pt Shot: Made (22 PTS)')]),
#  OrderedDict([('evt', 696),
#               ('cl', '00:45.8'),
#               ('de',
#                '[IND] Brogdon Foul: Personal Take (1 PF) (2 FTA) (M Davis)')]),
#  OrderedDict([('evt', 698),
#               ('cl', '00:45.8'),
#               ('de', '[DET 116-108] Drummond Free Throw 1 of 2 (31 PTS)')]),
#  OrderedDict([('evt', 699),
#               ('cl', '00:45.8'),
#               ('de', '[DET 117-108] Drummond Free Throw 2 of 2 (32 PTS)')]),
#  OrderedDict([('evt', 700),
#               ('cl', '00:38.3'),
#               ('de',
#                '[IND 110-117] Sabonis Cutting Dunk Shot: Made (27 PTS) Assist: Brogdon (11 AST)')]),
#  OrderedDict([('evt', 702),
#               ('cl', '00:36.4'),
#               ('de',
#                '[IND] Lamb Foul: Personal Take (4 PF) (2 FTA) (M Davis)')]),
#  OrderedDict([('evt', 704),
#               ('cl', '00:36.4'),
#               ('de', '[DET 118-110] Kennard Free Throw 1 of 2 (30 PTS)')]),
#  OrderedDict([('evt', 705),
#               ('cl', '00:36.4'),
#               ('de', '[DET] Kennard Free Throw 2 of 2 Missed')]),
#  OrderedDict([('evt', 706), ('cl', '00:35.3'), ('de', '[IND] Team Rebound')]),
#  OrderedDict([('evt', 707),
#               ('cl', '00:35.3'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 708),
#               ('cl', '00:35.3'),
#               ('de', '[IND] Team Timeout : Regular')]),
#  OrderedDict([('evt', 709),
#               ('cl', '00:35.3'),
#               ('de', '[IND] McDermott Substitution replaced by Holiday')]),
#  OrderedDict([('evt', 710),
#               ('cl', '00:35.3'),
#               ('de', '[DET] Kennard Substitution replaced by Galloway')]),
#  OrderedDict([('evt', 713),
#               ('cl', '00:33.5'),
#               ('de', '[IND] Holiday 3pt Shot: Missed')]),
#  OrderedDict([('evt', 714),
#               ('cl', '00:29.3'),
#               ('de', '[DET] Galloway Rebound (Off:1 Def:2)')]),
#  OrderedDict([('evt', 715),
#               ('cl', '00:26.6'),
#               ('de',
#                '[IND] Brogdon Foul: Personal Take (2 PF) (2 FTA) (B Nansel)')]),
#  OrderedDict([('evt', 717),
#               ('cl', '00:26.6'),
#               ('de', '[DET 119-110] Brown Free Throw 1 of 2 (7 PTS)')]),
#  OrderedDict([('evt', 718),
#               ('cl', '00:26.6'),
#               ('de', '[DET] Brown Free Throw 2 of 2 Missed')]),
#  OrderedDict([('evt', 719),
#               ('cl', '00:25.3'),
#               ('de', '[IND] Sabonis Rebound (Off:5 Def:8)')]),
#  OrderedDict([('evt', 720),
#               ('cl', '00:17.1'),
#               ('de', '[IND] Brogdon 3pt Shot: Missed')]),
#  OrderedDict([('evt', 721),
#               ('cl', '00:13.5'),
#               ('de', '[DET] Galloway Rebound (Off:1 Def:3)')]),
#  OrderedDict([('evt', 722), ('cl', '00:00.0'), ('de', 'End Period')]),
#  OrderedDict([('evt', 723), ('cl', '00:00.0'), ('de', 'Game End')])]

# %%
scrap_data_list = scrap_multi_web()
len(scrap_data_list)
# Out:
# 5490

# %%
scrap_data_list
# Out:
# [OrderedDict([('evt', 2), ('cl', '12:00'), ('de', 'Start Period')]),
#  OrderedDict([('evt', 4),
#               ('cl', '11:56'),
#               ('de', '[ATL] Dedmon Violation:Jump Ball (K Mauer)')]),
#  OrderedDict([('evt', 5),
#               ('cl', '11:48'),
#               ('de', '[NYK] Harkless Driving Layup Shot: Missed')]),
#  OrderedDict([('evt', 6),
#               ('cl', '11:45'),
#               ('de', '[ATL] Dedmon Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 7),
#               ('cl', '11:39'),
#               ('de', '[ATL] Dedmon 3pt Shot: Missed')]),
#  OrderedDict([('evt', 8), ('cl', '11:36'), ('de', '[ATL] Team Rebound')]),
#  OrderedDict([('evt', 9), ('cl', '11:36'), ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 10),
#               ('cl', '11:30'),
#               ('de', '[ATL] Young Driving Floating Bank Jump Shot: Missed')]),
#  OrderedDict([('evt', 11),
#               ('cl', '11:26'),
#               ('de', '[NYK] Harkless Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 12),
#               ('cl', '11:21'),
#               ('de', '[NYK] Barrett 3pt Shot: Missed')]),
#  OrderedDict([('evt', 13),
#               ('cl', '11:19'),
#               ('de', '[ATL] Dedmon Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 14),
#               ('cl', '11:16'),
#               ('de', '[ATL] Hunter 3pt Shot: Missed')]),
#  OrderedDict([('evt', 15),
#               ('cl', '11:16'),
#               ('de', '[NYK] Randle Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 16),
#               ('cl', '10:56'),
#               ('de', '[NYK] Randle Driving Floating Jump Shot: Missed')]),
#  OrderedDict([('evt', 17),
#               ('cl', '10:52'),
#               ('de', '[ATL] Collins Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 18),
#               ('cl', '10:45'),
#               ('de', '[ATL] Collins 3pt Shot: Missed')]),
#  OrderedDict([('evt', 19),
#               ('cl', '10:40'),
#               ('de', '[NYK] Payton Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 20),
#               ('cl', '10:37'),
#               ('de',
#                '[NYK 2-0] Randle Running Layup Shot: Made (2 PTS) Assist: Payton (1 AST)')]),
#  OrderedDict([('evt', 22),
#               ('cl', '10:20'),
#               ('de', '[NYK] Harkless Foul: Personal (1 PF) (D Collins)')]),
#  OrderedDict([('evt', 24),
#               ('cl', '10:10'),
#               ('de', '[ATL 2-2] Young Pullup Jump shot: Made (2 PTS)')]),
#  OrderedDict([('evt', 26),
#               ('cl', '09:53'),
#               ('de',
#                '[NYK 4-2] Randle Jump Shot: Made (4 PTS) Assist: Barrett (1 AST)')]),
#  OrderedDict([('evt', 28),
#               ('cl', '09:40'),
#               ('de', '[ATL] Dedmon 3pt Shot: Missed')]),
#  OrderedDict([('evt', 29),
#               ('cl', '09:36'),
#               ('de', '[NYK] Randle Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 30),
#               ('cl', '09:26'),
#               ('de', '[NYK 6-2] Gibson Driving Layup Shot: Made (2 PTS)')]),
#  OrderedDict([('evt', 32),
#               ('cl', '09:13'),
#               ('de',
#                '[ATL 4-6] Huerter Driving Floating Jump Shot: Made (2 PTS)')]),
#  OrderedDict([('evt', 33),
#               ('cl', '09:05'),
#               ('de', '[ATL] Huerter Foul: Personal (1 PF) (L Wood)')]),
#  OrderedDict([('evt', 35),
#               ('cl', '09:00'),
#               ('de',
#                '[NYK] Payton Turnover : Bad Pass (1 TO) Steal:Collins (1 ST)')]),
#  OrderedDict([('evt', 37),
#               ('cl', '08:56'),
#               ('de', '[ATL] Huerter 3pt Shot: Missed')]),
#  OrderedDict([('evt', 38),
#               ('cl', '08:52'),
#               ('de', '[NYK] Randle Rebound (Off:0 Def:3)')]),
#  OrderedDict([('evt', 39),
#               ('cl', '08:45'),
#               ('de',
#                '[NYK 9-4] Gibson 3pt Shot: Made (5 PTS) Assist: Payton (2 AST)')]),
#  OrderedDict([('evt', 41),
#               ('cl', '08:24'),
#               ('de',
#                '[ATL] Young Turnover : Bad Pass (1 TO) Steal:Payton (1 ST)')]),
#  OrderedDict([('evt', 43),
#               ('cl', '08:20'),
#               ('de', '[NYK] Barrett Running Layup Shot: Missed')]),
#  OrderedDict([('evt', 44),
#               ('cl', '08:19'),
#               ('de', '[NYK] Harkless Rebound (Off:1 Def:1)')]),
#  OrderedDict([('evt', 45),
#               ('cl', '08:19'),
#               ('de', '[NYK 11-4] Harkless Tip Dunk Shot: Made (2 PTS)')]),
#  OrderedDict([('evt', 46),
#               ('cl', '08:19'),
#               ('de', '[ATL] Team Timeout : Regular')]),
#  OrderedDict([('evt', 47),
#               ('cl', '08:07'),
#               ('de', '[ATL] Huerter 3pt Shot: Missed')]),
#  OrderedDict([('evt', 48),
#               ('cl', '08:04'),
#               ('de', '[ATL] Dedmon Rebound (Off:1 Def:2)')]),
#  OrderedDict([('evt', 49),
#               ('cl', '08:04'),
#               ('de', '[ATL] Dedmon Tip Layup Shot: Missed')]),
#  OrderedDict([('evt', 50),
#               ('cl', '08:03'),
#               ('de', '[NYK] Randle Rebound (Off:0 Def:4)')]),
#  OrderedDict([('evt', 51),
#               ('cl', '07:56'),
#               ('de',
#                '[NYK 13-4] Randle Cutting Layup Shot: Made (6 PTS) Assist: Harkless (1 AST)')]),
#  OrderedDict([('evt', 53),
#               ('cl', '07:43'),
#               ('de', '[ATL 6-13] Hunter Pullup Jump shot: Made (2 PTS)')]),
#  OrderedDict([('evt', 54),
#               ('cl', '07:19'),
#               ('de', '[NYK] Barrett 3pt Shot: Missed')]),
#  OrderedDict([('evt', 55),
#               ('cl', '07:17'),
#               ('de', '[ATL] Collins Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 56),
#               ('cl', '07:09'),
#               ('de',
#                '[ATL] Young Turnover : Bad Pass (2 TO) Steal:Gibson (1 ST)')]),
#  OrderedDict([('evt', 58),
#               ('cl', '07:06'),
#               ('de',
#                '[NYK 15-6] Harkless Running Layup Shot: Made (4 PTS) Assist: Gibson (1 AST)')]),
#  OrderedDict([('evt', 60),
#               ('cl', '07:06'),
#               ('de',
#                '[ATL] Hunter Foul: Shooting (1 PF) (1 FTA) (D Collins)')]),
#  OrderedDict([('evt', 62),
#               ('cl', '07:06'),
#               ('de', '[NYK 16-6] Harkless Free Throw 1 of 1 (5 PTS)')]),
#  OrderedDict([('evt', 63),
#               ('cl', '06:46'),
#               ('de', '[ATL] Young 3pt Shot: Missed')]),
#  OrderedDict([('evt', 64),
#               ('cl', '06:42'),
#               ('de', '[ATL] Collins Rebound (Off:1 Def:2)')]),
#  OrderedDict([('evt', 65),
#               ('cl', '06:39'),
#               ('de', '[ATL] Collins Floating Jump shot: Missed')]),
#  OrderedDict([('evt', 66),
#               ('cl', '06:37'),
#               ('de', '[NYK] Harkless Rebound (Off:1 Def:2)')]),
#  OrderedDict([('evt', 67),
#               ('cl', '06:28'),
#               ('de', '[NYK] Randle Turnaround Fadeaway shot: Missed')]),
#  OrderedDict([('evt', 68),
#               ('cl', '06:24'),
#               ('de', '[ATL] Hunter Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 69),
#               ('cl', '06:15'),
#               ('de',
#                '[ATL 9-16] Hunter 3pt Shot: Made (5 PTS) Assist: Huerter (1 AST)')]),
#  OrderedDict([('evt', 71),
#               ('cl', '06:02'),
#               ('de', '[NYK] Payton Driving Reverse Layup Shot: Missed')]),
#  OrderedDict([('evt', 72),
#               ('cl', '06:00'),
#               ('de', '[ATL] Dedmon Rebound (Off:1 Def:3)')]),
#  OrderedDict([('evt', 73),
#               ('cl', '05:55'),
#               ('de', '[ATL] Young 3pt Shot: Missed')]),
#  OrderedDict([('evt', 74),
#               ('cl', '05:50'),
#               ('de', '[NYK] Randle Rebound (Off:0 Def:5)')]),
#  OrderedDict([('evt', 75),
#               ('cl', '05:46'),
#               ('de',
#                '[NYK] Payton Turnover : Out of Bounds - Bad Pass Turnover (2 TO)')]),
#  OrderedDict([('evt', 76),
#               ('cl', '05:46'),
#               ('de', '[ATL] Huerter Substitution replaced by Reddish')]),
#  OrderedDict([('evt', 77),
#               ('cl', '05:46'),
#               ('de', '[NYK] Gibson Substitution replaced by Robinson')]),
#  OrderedDict([('evt', 80),
#               ('cl', '05:46'),
#               ('de', '[ATL] Team Violation : Delay Of Game (K Mauer)')]),
#  OrderedDict([('evt', 81),
#               ('cl', '05:34'),
#               ('de', '[ATL] Hunter Jump Shot: Missed')]),
#  OrderedDict([('evt', 82),
#               ('cl', '05:31'),
#               ('de', '[NYK] Payton Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 83),
#               ('cl', '05:25'),
#               ('de',
#                '[NYK 18-9] Harkless Step Back Jump shot: Made (7 PTS)')]),
#  OrderedDict([('evt', 84),
#               ('cl', '05:12'),
#               ('de', '[ATL] Young Driving Floating Jump Shot: Missed')]),
#  OrderedDict([('evt', 85),
#               ('cl', '05:08'),
#               ('de', '[ATL] Young Rebound (Off:1 Def:0)')]),
#  OrderedDict([('evt', 86),
#               ('cl', '05:08'),
#               ('de', '[ATL] Young Tip Layup Shot: Missed')]),
#  OrderedDict([('evt', 87),
#               ('cl', '05:08'),
#               ('de', '[ATL] Young Rebound (Off:2 Def:0)')]),
#  OrderedDict([('evt', 88),
#               ('cl', '05:05'),
#               ('de',
#                '[ATL 11-18] Dedmon Cutting Layup Shot: Made (2 PTS) Assist: Young (1 AST)')]),
#  OrderedDict([('evt', 90),
#               ('cl', '04:59'),
#               ('de', '[ATL] Reddish Foul: Shooting (1 PF) (2 FTA) (L Wood)')]),
#  OrderedDict([('evt', 92),
#               ('cl', '04:59'),
#               ('de', '[NYK 19-11] Barrett Free Throw 1 of 2 (1 PTS)')]),
#  OrderedDict([('evt', 93),
#               ('cl', '04:59'),
#               ('de', '[ATL] Young Substitution replaced by Teague')]),
#  OrderedDict([('evt', 94),
#               ('cl', '04:59'),
#               ('de', '[ATL] Dedmon Substitution replaced by Fernando')]),
#  OrderedDict([('evt', 97),
#               ('cl', '04:59'),
#               ('de', '[NYK 20-11] Barrett Free Throw 2 of 2 (2 PTS)')]),
#  OrderedDict([('evt', 98),
#               ('cl', '04:48'),
#               ('de', '[ATL] Reddish 3pt Shot: Missed')]),
#  OrderedDict([('evt', 99),
#               ('cl', '04:44'),
#               ('de', '[NYK] Harkless Rebound (Off:1 Def:3)')]),
#  OrderedDict([('evt', 100),
#               ('cl', '04:35'),
#               ('de', '[NYK] Randle 3pt Shot: Missed')]),
#  OrderedDict([('evt', 101),
#               ('cl', '04:33'),
#               ('de', '[ATL] Hunter Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 102),
#               ('cl', '04:27'),
#               ('de', '[ATL] Hunter Driving Layup Shot: Missed')]),
#  OrderedDict([('evt', 104),
#               ('cl', '04:22'),
#               ('de', '[NYK] Payton Rebound (Off:0 Def:3)')]),
#  OrderedDict([('evt', 105),
#               ('cl', '04:21'),
#               ('de',
#                '[NYK 22-11] Robinson Alley Oop Dunk Shot: Made (2 PTS) Assist: Payton (3 AST)')]),
#  OrderedDict([('evt', 107),
#               ('cl', '04:21'),
#               ('de', '[ATL] Team Timeout : Regular')]),
#  OrderedDict([('evt', 108),
#               ('cl', '04:21'),
#               ('de', '[ATL] Hunter Substitution replaced by Graham')]),
#  OrderedDict([('evt', 110),
#               ('cl', '04:00'),
#               ('de', '[ATL] Collins Jump Shot: Missed')]),
#  OrderedDict([('evt', 111),
#               ('cl', '03:56'),
#               ('de', '[NYK] Randle Rebound (Off:0 Def:6)')]),
#  OrderedDict([('evt', 112),
#               ('cl', '03:47'),
#               ('de', '[ATL] Teague Foul: Shooting (1 PF) (2 FTA) (K Mauer)')]),
#  OrderedDict([('evt', 114),
#               ('cl', '03:47'),
#               ('de', '[NYK 23-11] Payton Free Throw 1 of 2 (1 PTS)')]),
#  OrderedDict([('evt', 115),
#               ('cl', '03:47'),
#               ('de', '[ATL] Collins Substitution replaced by Carter')]),
#  OrderedDict([('evt', 117),
#               ('cl', '03:47'),
#               ('de', '[NYK 24-11] Payton Free Throw 2 of 2 (2 PTS)')]),
#  OrderedDict([('evt', 118),
#               ('cl', '03:38'),
#               ('de', '[ATL] Carter 3pt Shot: Missed')]),
#  OrderedDict([('evt', 119),
#               ('cl', '03:34'),
#               ('de', '[ATL] Teague Rebound (Off:1 Def:0)')]),
#  OrderedDict([('evt', 120),
#               ('cl', '03:30'),
#               ('de', '[ATL] Graham 3pt Shot: Missed')]),
#  OrderedDict([('evt', 121),
#               ('cl', '03:28'),
#               ('de', '[NYK] Barrett Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 122),
#               ('cl', '03:18'),
#               ('de',
#                '[NYK 26-11] Randle Turnaround Fadeaway shot: Made (8 PTS)')]),
#  OrderedDict([('evt', 123),
#               ('cl', '03:04'),
#               ('de', '[ATL 14-26] Teague 3pt Shot: Made (3 PTS)')]),
#  OrderedDict([('evt', 124),
#               ('cl', '02:49'),
#               ('de',
#                '[NYK 28-14] Harkless Driving Layup Shot: Made (9 PTS) Assist: Payton (4 AST)')]),
#  OrderedDict([('evt', 125),
#               ('cl', '02:31'),
#               ('de',
#                '[NYK] Robinson Foul: Shooting (1 PF) (2 FTA) (D Collins)')]),
#  OrderedDict([('evt', 127),
#               ('cl', '02:31'),
#               ('de', '[ATL 15-28] Teague Free Throw 1 of 2 (4 PTS)')]),
#  OrderedDict([('evt', 128),
#               ('cl', '02:31'),
#               ('de', '[NYK] Payton Substitution replaced by Knox II')]),
#  OrderedDict([('evt', 129),
#               ('cl', '02:31'),
#               ('de', '[NYK] Barrett Substitution replaced by Ntilikina')]),
#  OrderedDict([('evt', 132),
#               ('cl', '02:31'),
#               ('de', '[ATL 16-28] Teague Free Throw 2 of 2 (5 PTS)')]),
#  OrderedDict([('evt', 133),
#               ('cl', '02:18'),
#               ('de', '[NYK] Harkless 3pt Shot: Missed')]),
#  OrderedDict([('evt', 134),
#               ('cl', '02:14'),
#               ('de', '[ATL] Graham Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 135),
#               ('cl', '02:08'),
#               ('de',
#                '[ATL 19-28] Graham 3pt Shot: Made (3 PTS) Assist: Fernando (1 AST)')]),
#  OrderedDict([('evt', 137),
#               ('cl', '01:53'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 138),
#               ('cl', '01:53'),
#               ('de', '[NYK] Harkless Substitution replaced by Portis')]),
#  OrderedDict([('evt', 153),
#               ('cl', '01:53'),
#               ('de', '[NYK] Randle Substitution replaced by Ellington')]),
#  OrderedDict([('evt', 142),
#               ('cl', '01:47'),
#               ('de',
#                '[NYK 31-19] Knox II 3pt Shot: Made (3 PTS) Assist: Portis (1 AST)')]),
#  OrderedDict([('evt', 144),
#               ('cl', '01:27'),
#               ('de',
#                '[ATL] Teague Turnover : Out of Bounds - Bad Pass Turnover (1 TO)')]),
#  OrderedDict([('evt', 146),
#               ('cl', '01:20'),
#               ('de', '[ATL] Reddish Violation:Kicked Ball (L Wood)')]),
#  OrderedDict([('evt', 147),
#               ('cl', '01:07'),
#               ('de', '[NYK] Ntilikina 3pt Shot: Missed')]),
#  OrderedDict([('evt', 148),
#               ('cl', '01:03'),
#               ('de', '[ATL] Reddish Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 149),
#               ('cl', '00:53.8'),
#               ('de',
#                '[ATL 21-31] Teague Driving Floating Jump Shot: Made (7 PTS) Assist: Graham (1 AST)')]),
#  OrderedDict([('evt', 151),
#               ('cl', '00:53.8'),
#               ('de',
#                '[NYK] Ellington Foul: Shooting (1 PF) (1 FTA) (L Wood)')]),
#  OrderedDict([('evt', 154),
#               ('cl', '00:53.8'),
#               ('de', '[ATL 22-31] Teague Free Throw 1 of 1 (8 PTS)')]),
#  OrderedDict([('evt', 155),
#               ('cl', '00:34.8'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 156),
#               ('cl', '00:33.0'),
#               ('de', '[NYK] Ellington 3pt Shot: Missed')]),
#  OrderedDict([('evt', 157),
#               ('cl', '00:31.1'),
#               ('de', '[NYK] Ntilikina Rebound (Off:1 Def:0)')]),
#  OrderedDict([('evt', 158),
#               ('cl', '00:31.1'),
#               ('de', '[ATL] Graham Foul: Shooting (1 PF) (2 FTA) (K Mauer)')]),
#  OrderedDict([('evt', 160),
#               ('cl', '00:31.1'),
#               ('de', '[NYK 32-22] Ntilikina Free Throw 1 of 2 (1 PTS)')]),
#  OrderedDict([('evt', 161),
#               ('cl', '00:31.1'),
#               ('de', '[NYK 33-22] Ntilikina Free Throw 2 of 2 (2 PTS)')]),
#  OrderedDict([('evt', 162),
#               ('cl', '00:24.8'),
#               ('de',
#                '[ATL 24-33] Fernando Driving Dunk Shot: Made (2 PTS) Assist: Teague (1 AST)')]),
#  OrderedDict([('evt', 164),
#               ('cl', '00:24.8'),
#               ('de',
#                '[NYK] Robinson Foul: Shooting (2 PF) (1 FTA) (L Wood)')]),
#  OrderedDict([('evt', 166),
#               ('cl', '00:24.8'),
#               ('de', '[ATL] Fernando Free Throw 1 of 1 Missed')]),
#  OrderedDict([('evt', 167),
#               ('cl', '00:22.7'),
#               ('de', '[NYK] Portis Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 168),
#               ('cl', '00:04.3'),
#               ('de', '[NYK] Portis Jump Shot: Missed')]),
#  OrderedDict([('evt', 169),
#               ('cl', '00:04.3'),
#               ('de', '[ATL] Teague Rebound (Off:1 Def:1)')]),
#  OrderedDict([('evt', 171), ('cl', '00:00.0'), ('de', 'End Period')]),
#  OrderedDict([('evt', 176), ('cl', '12:00'), ('de', 'Start Period')]),
#  OrderedDict([('evt', 177),
#               ('cl', '11:40'),
#               ('de',
#                '[NYK 35-24] Portis Turnaround Jump Shot: Made (2 PTS) Assist: Ellington (1 AST)')]),
#  OrderedDict([('evt', 179),
#               ('cl', '11:24'),
#               ('de', '[NYK] Ntilikina Foul: Personal (1 PF) (L Wood)')]),
#  OrderedDict([('evt', 181),
#               ('cl', '11:18'),
#               ('de', '[ATL] Reddish Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 182), ('cl', '11:18'), ('de', '[ATL] Team Rebound')]),
#  OrderedDict([('evt', 183),
#               ('cl', '11:18'),
#               ('de', '[NYK] Knox II Foul: Loose Ball (1 PF) (K Mauer)')]),
#  OrderedDict([('evt', 185),
#               ('cl', '11:02'),
#               ('de',
#                '[ATL 26-35] Teague Driving Finger Roll Layup Shot: Made (10 PTS)')]),
#  OrderedDict([('evt', 186),
#               ('cl', '10:49'),
#               ('de', '[ATL] Carter Foul: Personal (1 PF) (L Wood)')]),
#  OrderedDict([('evt', 188),
#               ('cl', '10:42'),
#               ('de', '[NYK 38-26] Ntilikina 3pt Shot: Made (5 PTS)')]),
#  OrderedDict([('evt', 189),
#               ('cl', '10:24'),
#               ('de', '[ATL] Reddish Driving Layup Shot: Missed')]),
#  OrderedDict([('evt', 190),
#               ('cl', '10:19'),
#               ('de', '[NYK] Ntilikina Rebound (Off:1 Def:1)')]),
#  OrderedDict([('evt', 191),
#               ('cl', '10:14'),
#               ('de', '[NYK] Ntilikina Driving Layup Shot: Missed')]),
#  OrderedDict([('evt', 192),
#               ('cl', '10:11'),
#               ('de', '[ATL] Carter Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 193),
#               ('cl', '09:55'),
#               ('de', '[ATL] Carter Turnaround Jump Shot: Missed')]),
#  OrderedDict([('evt', 194),
#               ('cl', '09:52'),
#               ('de', '[NYK] Gibson Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 195),
#               ('cl', '09:44'),
#               ('de', '[NYK] Gibson Turnaround Jump Shot: Missed')]),
#  OrderedDict([('evt', 196),
#               ('cl', '09:41'),
#               ('de', '[ATL] Huerter Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 197),
#               ('cl', '09:26'),
#               ('de', '[ATL] Teague Driving Layup Shot: Missed')]),
#  OrderedDict([('evt', 199),
#               ('cl', '09:22'),
#               ('de', '[NYK] Ntilikina Rebound (Off:1 Def:2)')]),
#  OrderedDict([('evt', 200),
#               ('cl', '09:22'),
#               ('de',
#                '[ATL] Carter Foul: Shooting (2 PF) (2 FTA) (D Collins)')]),
#  OrderedDict([('evt', 203),
#               ('cl', '09:22'),
#               ('de', '[NYK 39-26] Knox II Free Throw 1 of 2 (4 PTS)')]),
#  OrderedDict([('evt', 204),
#               ('cl', '09:22'),
#               ('de', '[ATL] Teague Substitution replaced by Young')]),
#  OrderedDict([('evt', 205),
#               ('cl', '09:22'),
#               ('de', '[ATL] Carter Substitution replaced by Collins')]),
#  OrderedDict([('evt', 209),
#               ('cl', '09:22'),
#               ('de', '[NYK 40-26] Knox II Free Throw 2 of 2 (5 PTS)')]),
#  OrderedDict([('evt', 210),
#               ('cl', '09:06'),
#               ('de', '[ATL] Reddish 3pt Shot: Missed')]),
#  OrderedDict([('evt', 211),
#               ('cl', '09:03'),
#               ('de', '[NYK] Ntilikina Rebound (Off:1 Def:3)')]),
#  OrderedDict([('evt', 212),
#               ('cl', '09:00'),
#               ('de', '[NYK] Knox II Dunk Shot: Missed')]),
#  OrderedDict([('evt', 214),
#               ('cl', '08:55'),
#               ('de', '[ATL] Fernando Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 215),
#               ('cl', '08:49'),
#               ('de',
#                '[ATL] Collins Turnover : Lost Ball (1 TO) Steal:Gibson (2 ST)')]),
#  OrderedDict([('evt', 217),
#               ('cl', '08:45'),
#               ('de', '[NYK 43-26] Knox II 3pt Shot: Made (8 PTS)')]),
#  OrderedDict([('evt', 219),
#               ('cl', '08:23'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 220),
#               ('cl', '08:20'),
#               ('de',
#                '[ATL 28-43] Reddish Layup Shot: Made (2 PTS) Assist: Huerter (2 AST)')]),
#  OrderedDict([('evt', 222),
#               ('cl', '08:08'),
#               ('de', '[NYK] Ntilikina Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 223),
#               ('cl', '08:04'),
#               ('de', '[ATL] Reddish Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 224),
#               ('cl', '07:58'),
#               ('de', '[ATL] Collins 3pt Shot: Missed')]),
#  OrderedDict([('evt', 225),
#               ('cl', '07:56'),
#               ('de', '[NYK] Knox II Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 226),
#               ('cl', '07:49'),
#               ('de', '[NYK] Portis Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 227),
#               ('cl', '07:44'),
#               ('de', '[ATL] Reddish Rebound (Off:0 Def:3)')]),
#  OrderedDict([('evt', 228),
#               ('cl', '07:30'),
#               ('de', '[ATL] Fernando Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 229),
#               ('cl', '07:26'),
#               ('de', '[NYK] Knox II Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 230),
#               ('cl', '07:13'),
#               ('de', '[NYK] Ntilikina 3pt Shot: Missed')]),
#  OrderedDict([('evt', 231),
#               ('cl', '07:08'),
#               ('de', '[ATL] Collins Rebound (Off:1 Def:3)')]),
#  OrderedDict([('evt', 232),
#               ('cl', '07:04'),
#               ('de',
#                '[ATL 30-43] Collins Running Dunk Shot: Made (2 PTS) Assist: Huerter (3 AST)')]),
#  OrderedDict([('evt', 234),
#               ('cl', '07:03'),
#               ('de', '[NYK] Team Timeout : Regular')]),
#  OrderedDict([('evt', 235),
#               ('cl', '07:03'),
#               ('de', '[ATL] Reddish Substitution replaced by Hunter')]),
#  OrderedDict([('evt', 236),
#               ('cl', '07:03'),
#               ('de', '[ATL] Fernando Substitution replaced by Dedmon')]),
#  OrderedDict([('evt', 237),
#               ('cl', '07:03'),
#               ('de', '[NYK] Ellington Substitution replaced by Harkless')]),
#  OrderedDict([('evt', 238),
#               ('cl', '07:03'),
#               ('de', '[NYK] Gibson Substitution replaced by Robinson')]),
#  OrderedDict([('evt', 243),
#               ('cl', '06:53'),
#               ('de',
#                '[NYK 45-30] Robinson Dunk Shot: Made (4 PTS) Assist: Portis (2 AST)')]),
#  OrderedDict([('evt', 245),
#               ('cl', '06:38'),
#               ('de', '[ATL] Young Driving Floating Jump Shot: Missed')]),
#  OrderedDict([('evt', 246),
#               ('cl', '06:34'),
#               ('de', '[NYK] Robinson Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 247),
#               ('cl', '06:29'),
#               ('de', '[NYK] Portis Turnover : Traveling (1 TO)')]),
#  OrderedDict([('evt', 248),
#               ('cl', '06:04'),
#               ('de', '[ATL] Collins Driving Floating Jump Shot: Missed')]),
#  OrderedDict([('evt', 249), ('cl', '06:04'), ('de', '[NYK] Team Rebound')]),
#  OrderedDict([('evt', 250),
#               ('cl', '06:04'),
#               ('de', '[NYK] Portis Substitution replaced by Randle')]),
#  OrderedDict([('evt', 252),
#               ('cl', '05:41'),
#               ('de',
#                '[NYK] Harkless Turnover : Bad Pass (1 TO) Steal:Collins (2 ST)')]),
#  OrderedDict([('evt', 254),
#               ('cl', '05:37'),
#               ('de',
#                '[ATL 32-45] Huerter Running Layup Shot: Made (4 PTS) Assist: Young (2 AST)')]),
#  OrderedDict([('evt', 256),
#               ('cl', '05:22'),
#               ('de',
#                '[NYK 47-32] Harkless Dunk Shot: Made (11 PTS) Assist: Ntilikina (1 AST)')]),
#  OrderedDict([('evt', 258),
#               ('cl', '05:03'),
#               ('de', '[ATL] Huerter Step Back Jump shot: Missed')]),
#  OrderedDict([('evt', 259),
#               ('cl', '05:00'),
#               ('de', '[NYK] Knox II Rebound (Off:0 Def:3)')]),
#  OrderedDict([('evt', 260),
#               ('cl', '04:46'),
#               ('de',
#                '[NYK 49-32] Robinson Dunk Shot: Made (6 PTS) Assist: Ntilikina (2 AST)')]),
#  OrderedDict([('evt', 262),
#               ('cl', '04:35'),
#               ('de',
#                '[ATL 34-49] Young Driving Floating Bank Jump Shot: Made (4 PTS)')]),
#  OrderedDict([('evt', 263),
#               ('cl', '04:20'),
#               ('de',
#                '[NYK 52-34] Knox II 3pt Shot: Made (11 PTS) Assist: Harkless (2 AST)')]),
#  OrderedDict([('evt', 264),
#               ('cl', '04:08'),
#               ('de',
#                '[ATL 36-52] Young Driving Floating Jump Shot: Made (6 PTS)')]),
#  OrderedDict([('evt', 265),
#               ('cl', '04:08'),
#               ('de',
#                '[NYK] Harkless Foul: Shooting (2 PF) (1 FTA) (D Collins)')]),
#  OrderedDict([('evt', 267),
#               ('cl', '04:08'),
#               ('de', '[NYK] Knox II Substitution replaced by Barrett')]),
#  OrderedDict([('evt', 269),
#               ('cl', '04:08'),
#               ('de', '[ATL] Young Free Throw 1 of 1 Missed')]),
#  OrderedDict([('evt', 270),
#               ('cl', '04:05'),
#               ('de', '[NYK] Randle Rebound (Off:0 Def:7)')]),
#  OrderedDict([('evt', 272),
#               ('cl', '03:59'),
#               ('de', '[ATL] Young Foul: Shooting (1 PF) (2 FTA) (L Wood)')]),
#  OrderedDict([('evt', 274),
#               ('cl', '03:59'),
#               ('de', '[NYK] Ntilikina Free Throw 1 of 2 Missed')]),
#  OrderedDict([('evt', 275), ('cl', '03:59'), ('de', '[NYK] Team Rebound')]),
#  OrderedDict([('evt', 276),
#               ('cl', '03:59'),
#               ('de', '[ATL] Huerter Substitution replaced by Teague')]),
#  OrderedDict([('evt', 278),
#               ('cl', '03:59'),
#               ('de', '[NYK 53-36] Ntilikina Free Throw 2 of 2 (6 PTS)')]),
#  OrderedDict([('evt', 279),
#               ('cl', '03:55'),
#               ('de', '[NYK] Ntilikina Foul: Personal (2 PF) (D Collins)')]),
#  OrderedDict([('evt', 281),
#               ('cl', '03:55'),
#               ('de', '[NYK] Ntilikina Substitution replaced by Payton')]),
#  OrderedDict([('evt', 283),
#               ('cl', '03:52'),
#               ('de',
#                '[ATL 39-53] Collins 3pt Shot: Made (5 PTS) Assist: Dedmon (1 AST)')]),
#  OrderedDict([('evt', 285),
#               ('cl', '03:29'),
#               ('de',
#                '[NYK 55-39] Randle Step Back Jump shot: Made (10 PTS) Assist: Payton (5 AST)')]),
#  OrderedDict([('evt', 287),
#               ('cl', '03:09'),
#               ('de', '[ATL] Young Driving Finger Roll Layup Shot: Missed')]),
#  OrderedDict([('evt', 288),
#               ('cl', '03:06'),
#               ('de', '[ATL] Dedmon Rebound (Off:2 Def:3)')]),
#  OrderedDict([('evt', 289),
#               ('cl', '03:05'),
#               ('de', '[ATL] Dedmon Putback Layup Shot: Missed')]),
#  OrderedDict([('evt', 290),
#               ('cl', '03:05'),
#               ('de', '[NYK] Harkless Rebound (Off:1 Def:4)')]),
#  OrderedDict([('evt', 291),
#               ('cl', '02:57'),
#               ('de', '[NYK] Randle Driving Floating Jump Shot: Missed')]),
#  OrderedDict([('evt', 292),
#               ('cl', '02:52'),
#               ('de', '[NYK] Robinson Rebound (Off:1 Def:1)')]),
#  OrderedDict([('evt', 293),
#               ('cl', '02:52'),
#               ('de', '[NYK 57-39] Robinson Tip Layup Shot: Made (8 PTS)')]),
#  OrderedDict([('evt', 294),
#               ('cl', '02:42'),
#               ('de', '[ATL] Hunter Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 295),
#               ('cl', '02:40'),
#               ('de', '[NYK] Barrett Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 296),
#               ('cl', '02:30'),
#               ('de', '[NYK] Randle Step Back Jump shot: Missed')]),
#  OrderedDict([('evt', 297),
#               ('cl', '02:26'),
#               ('de', '[NYK] Robinson Rebound (Off:2 Def:1)')]),
#  OrderedDict([('evt', 298),
#               ('cl', '02:21'),
#               ('de', '[NYK 59-39] Payton Fadeaway Jump Shot: Made (4 PTS)')]),
#  OrderedDict([('evt', 299),
#               ('cl', '02:21'),
#               ('de', '[ATL] Team Timeout : Regular')]),
#  OrderedDict([('evt', 300),
#               ('cl', '02:21'),
#               ('de', '[ATL] Dedmon Substitution replaced by Reddish')]),
#  OrderedDict([('evt', 301),
#               ('cl', '02:21'),
#               ('de', '[NYK] Robinson Substitution replaced by Portis')]),
#  OrderedDict([('evt', 304),
#               ('cl', '02:09'),
#               ('de', '[ATL 42-59] Young 3pt Shot: Made (9 PTS)')]),
#  OrderedDict([('evt', 305),
#               ('cl', '01:50'),
#               ('de',
#                '[NYK 61-42] Barrett Driving Dunk Shot: Made (4 PTS) Assist: Randle (1 AST)')]),
#  OrderedDict([('evt', 307),
#               ('cl', '01:40'),
#               ('de',
#                '[ATL 45-61] Hunter 3pt Shot: Made (8 PTS) Assist: Young (3 AST)')]),
#  OrderedDict([('evt', 309),
#               ('cl', '01:25'),
#               ('de',
#                '[NYK 63-45] Barrett Driving Floating Bank Jump Shot: Made (6 PTS)')]),
#  OrderedDict([('evt', 310),
#               ('cl', '01:07'),
#               ('de', '[ATL] Collins 3pt Shot: Missed')]),
#  OrderedDict([('evt', 311),
#               ('cl', '01:04'),
#               ('de', '[NYK] Payton Rebound (Off:0 Def:4)')]),
#  OrderedDict([('evt', 312),
#               ('cl', '00:48.3'),
#               ('de',
#                '[NYK 65-45] Portis Turnaround Jump Shot: Made (4 PTS) Assist: Payton (6 AST)')]),
#  OrderedDict([('evt', 313),
#               ('cl', '00:34.1'),
#               ('de',
#                '[ATL] Reddish Turnover : Bad Pass (1 TO) Steal:Harkless (1 ST)')]),
#  OrderedDict([('evt', 315),
#               ('cl', '00:32.2'),
#               ('de',
#                '[NYK 67-45] Randle Running Layup Shot: Made (12 PTS) Assist: Harkless (3 AST)')]),
#  OrderedDict([('evt', 317),
#               ('cl', '00:27.0'),
#               ('de',
#                '[ATL 47-67] Collins Reverse Layup Shot: Made (7 PTS) Assist: Teague (2 AST)')]),
#  OrderedDict([('evt', 319),
#               ('cl', '00:27.0'),
#               ('de', '[NYK] Randle Foul: Shooting (1 PF) (1 FTA) (L Wood)')]),
#  OrderedDict([('evt', 321),
#               ('cl', '00:27.0'),
#               ('de', '[ATL] Teague Substitution replaced by Graham')]),
#  OrderedDict([('evt', 322),
#               ('cl', '00:27.0'),
#               ('de', '[ATL] Young Substitution replaced by Carter')]),
#  OrderedDict([('evt', 325),
#               ('cl', '00:27.0'),
#               ('de', '[ATL 48-67] Collins Free Throw 1 of 1 (8 PTS)')]),
#  OrderedDict([('evt', 327),
#               ('cl', '00:09.8'),
#               ('de', '[ATL] Carter Foul: Personal (3 PF) (K Mauer)')]),
#  OrderedDict([('evt', 329),
#               ('cl', '00:04.7'),
#               ('de',
#                '[NYK] Payton Turnover : Lost Ball (3 TO) Steal:Reddish (1 ST)')]),
#  OrderedDict([('evt', 331),
#               ('cl', '00:02.3'),
#               ('de', '[ATL 50-67] Reddish Running Dunk Shot: Made (4 PTS)')]),
#  OrderedDict([('evt', 332),
#               ('cl', '00:00.0'),
#               ('de', '[NYK] Harkless 3pt Shot: Missed')]),
#  OrderedDict([('evt', 333), ('cl', '00:00.0'), ('de', '[NYK] Team Rebound')]),
#  OrderedDict([('evt', 334), ('cl', '00:00.0'), ('de', 'End Period')]),
#  OrderedDict([('evt', 344), ('cl', '12:00'), ('de', 'Start Period')]),
#  OrderedDict([('evt', 345),
#               ('cl', '11:45'),
#               ('de', '[NYK] Barrett Driving Layup Shot: Missed')]),
#  OrderedDict([('evt', 346),
#               ('cl', '11:42'),
#               ('de', '[ATL] Dedmon Rebound (Off:2 Def:4)')]),
#  OrderedDict([('evt', 347),
#               ('cl', '11:33'),
#               ('de', '[ATL] Collins Cutting Layup Shot: Missed')]),
#  OrderedDict([('evt', 349),
#               ('cl', '11:29'),
#               ('de', '[ATL] Collins Rebound (Off:2 Def:3)')]),
#  OrderedDict([('evt', 350),
#               ('cl', '11:27'),
#               ('de',
#                '[ATL 52-67] Collins Layup Shot: Made (10 PTS) Assist: Huerter (4 AST)')]),
#  OrderedDict([('evt', 352),
#               ('cl', '11:15'),
#               ('de',
#                '[NYK] Randle Turnover : Bad Pass (1 TO) Steal:Dedmon (1 ST)')]),
#  OrderedDict([('evt', 354),
#               ('cl', '11:11'),
#               ('de', '[ATL] Huerter 3pt Shot: Missed')]),
#  OrderedDict([('evt', 355),
#               ('cl', '11:06'),
#               ('de', '[ATL] Dedmon Rebound (Off:3 Def:4)')]),
#  OrderedDict([('evt', 356),
#               ('cl', '11:02'),
#               ('de', '[ATL] Collins 3pt Shot: Missed')]),
#  OrderedDict([('evt', 357),
#               ('cl', '10:58'),
#               ('de', '[NYK] Gibson Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 358),
#               ('cl', '10:44'),
#               ('de',
#                '[NYK 70-52] Randle 3pt Shot: Made (15 PTS) Assist: Payton (7 AST)')]),
#  OrderedDict([('evt', 360),
#               ('cl', '10:24'),
#               ('de',
#                '[ATL 54-70] Collins Driving Reverse Dunk Shot: Made (12 PTS) Assist: Young (4 AST)')]),
#  OrderedDict([('evt', 362),
#               ('cl', '10:21'),
#               ('de', '[NYK] Team Timeout : Regular')]),
#  OrderedDict([('evt', 363),
#               ('cl', '09:56'),
#               ('de',
#                '[NYK 72-54] Harkless Driving Dunk Shot: Made (13 PTS) Assist: Barrett (2 AST)')]),
#  OrderedDict([('evt', 365),
#               ('cl', '09:46'),
#               ('de',
#                '[ATL 57-72] Young 3pt Shot: Made (12 PTS) Assist: Hunter (1 AST)')]),
#  OrderedDict([('evt', 367),
#               ('cl', '09:31'),
#               ('de', '[NYK] Harkless Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 368),
#               ('cl', '09:27'),
#               ('de', '[ATL] Dedmon Rebound (Off:3 Def:5)')]),
#  OrderedDict([('evt', 369),
#               ('cl', '09:23'),
#               ('de', '[NYK] Gibson Foul: Shooting (1 PF) (2 FTA) (L Wood)')]),
#  OrderedDict([('evt', 371),
#               ('cl', '09:23'),
#               ('de', '[ATL] Young Free Throw 1 of 2 Missed')]),
#  OrderedDict([('evt', 372), ('cl', '09:23'), ('de', '[ATL] Team Rebound')]),
#  OrderedDict([('evt', 373),
#               ('cl', '09:23'),
#               ('de', '[ATL 58-72] Young Free Throw 2 of 2 (13 PTS)')]),
#  OrderedDict([('evt', 374),
#               ('cl', '09:10'),
#               ('de',
#                '[NYK] Barrett Turnover : Bad Pass (1 TO) Steal:Huerter (1 ST)')]),
#  OrderedDict([('evt', 376),
#               ('cl', '09:05'),
#               ('de', '[ATL] Collins Cutting Dunk Shot: Missed')]),
#  OrderedDict([('evt', 378),
#               ('cl', '09:00'),
#               ('de', '[ATL] Collins Rebound (Off:3 Def:3)')]),
#  OrderedDict([('evt', 379),
#               ('cl', '09:00'),
#               ('de',
#                '[ATL] Collins Turnover : Bad Pass (2 TO) Steal:Payton (2 ST)')]),
#  OrderedDict([('evt', 381),
#               ('cl', '09:00'),
#               ('de', '[ATL] Dedmon Foul: Shooting (1 PF) (2 FTA) (L Wood)')]),
#  OrderedDict([('evt', 383),
#               ('cl', '09:00'),
#               ('de', '[NYK 73-58] Barrett Free Throw 1 of 2 (7 PTS)')]),
#  OrderedDict([('evt', 384),
#               ('cl', '09:00'),
#               ('de', '[NYK 74-58] Barrett Free Throw 2 of 2 (8 PTS)')]),
#  OrderedDict([('evt', 385),
#               ('cl', '08:45'),
#               ('de', '[ATL] Dedmon 3pt Shot: Missed')]),
#  OrderedDict([('evt', 387), ('cl', '08:43'), ('de', '[NYK] Team Rebound')]),
#  OrderedDict([('evt', 388),
#               ('cl', '08:43'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 389),
#               ('cl', '08:34'),
#               ('de',
#                '[NYK 76-58] Gibson Jump Shot: Made (7 PTS) Assist: Payton (8 AST)')]),
#  OrderedDict([('evt', 391),
#               ('cl', '08:20'),
#               ('de', '[ATL] Young Driving Layup Shot: Missed')]),
#  OrderedDict([('evt', 393),
#               ('cl', '08:17'),
#               ('de', '[NYK] Randle Rebound (Off:0 Def:8)')]),
#  OrderedDict([('evt', 394),
#               ('cl', '08:14'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 395),
#               ('cl', '08:09'),
#               ('de', '[NYK 78-58] Payton Step Back Jump shot: Made (6 PTS)')]),
#  OrderedDict([('evt', 396),
#               ('cl', '07:50'),
#               ('de', '[NYK] Gibson Foul: Shooting (2 PF) (2 FTA) (L Wood)')]),
#  OrderedDict([('evt', 398),
#               ('cl', '07:50'),
#               ('de', '[ATL 59-78] Collins Free Throw 1 of 2 (13 PTS)')]),
#  OrderedDict([('evt', 399),
#               ('cl', '07:50'),
#               ('de', '[ATL] Dedmon Substitution replaced by Reddish')]),
#  OrderedDict([('evt', 401),
#               ('cl', '07:50'),
#               ('de', '[ATL 60-78] Collins Free Throw 2 of 2 (14 PTS)')]),
#  OrderedDict([('evt', 402),
#               ('cl', '07:31'),
#               ('de',
#                '[NYK 80-60] Gibson Cutting Dunk Shot: Made (9 PTS) Assist: Harkless (4 AST)')]),
#  OrderedDict([('evt', 404),
#               ('cl', '07:16'),
#               ('de', '[ATL] Collins Layup Shot: Missed')]),
#  OrderedDict([('evt', 405),
#               ('cl', '07:14'),
#               ('de', '[NYK] Gibson Rebound (Off:0 Def:3)')]),
#  OrderedDict([('evt', 406),
#               ('cl', '07:10'),
#               ('de',
#                '[NYK 82-60] Barrett Dunk Shot: Made (10 PTS) Assist: Payton (9 AST)')]),
#  OrderedDict([('evt', 408),
#               ('cl', '07:10'),
#               ('de', '[ATL] Team Timeout : Regular')]),
#  OrderedDict([('evt', 409),
#               ('cl', '07:10'),
#               ('de', '[ATL] Huerter Substitution replaced by Teague')]),
#  OrderedDict([('evt', 410),
#               ('cl', '07:10'),
#               ('de', '[ATL] Young Substitution replaced by Fernando')]),
#  OrderedDict([('evt', 411),
#               ('cl', '07:10'),
#               ('de', '[ATL] Hunter Substitution replaced by Carter')]),
#  OrderedDict([('evt', 412),
#               ('cl', '07:10'),
#               ('de', '[ATL] Collins Substitution replaced by Graham')]),
#  OrderedDict([('evt', 417),
#               ('cl', '07:01'),
#               ('de',
#                '[ATL 62-82] Reddish Step Back Jump shot: Made (6 PTS)')]),
#  OrderedDict([('evt', 418),
#               ('cl', '06:41'),
#               ('de', '[NYK] Payton Step Back Jump shot: Missed')]),
#  OrderedDict([('evt', 419),
#               ('cl', '06:37'),
#               ('de', '[ATL] Teague Rebound (Off:1 Def:2)')]),
#  OrderedDict([('evt', 420),
#               ('cl', '06:33'),
#               ('de', '[ATL] Graham 3pt Shot: Missed')]),
#  OrderedDict([('evt', 421), ('cl', '06:31'), ('de', '[ATL] Team Rebound')]),
#  OrderedDict([('evt', 422),
#               ('cl', '06:31'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 423),
#               ('cl', '06:28'),
#               ('de', '[ATL] Reddish Cutting Layup Shot: Missed')]),
#  OrderedDict([('evt', 425),
#               ('cl', '06:25'),
#               ('de', '[NYK] Harkless Rebound (Off:1 Def:5)')]),
#  OrderedDict([('evt', 426),
#               ('cl', '06:20'),
#               ('de', '[NYK] Barrett Turnover : Traveling (2 TO)')]),
#  OrderedDict([('evt', 427),
#               ('cl', '06:04'),
#               ('de',
#                '[ATL 64-82] Teague Driving Floating Jump Shot: Made (12 PTS)')]),
#  OrderedDict([('evt', 428),
#               ('cl', '06:04'),
#               ('de', '[NYK] Payton Foul: Shooting (1 PF) (1 FTA) (K Mauer)')]),
#  OrderedDict([('evt', 430),
#               ('cl', '06:04'),
#               ('de', '[NYK] Gibson Substitution replaced by Robinson')]),
#  OrderedDict([('evt', 432),
#               ('cl', '06:04'),
#               ('de', '[ATL 65-82] Teague Free Throw 1 of 1 (13 PTS)')]),
#  OrderedDict([('evt', 433),
#               ('cl', '05:45'),
#               ('de', '[NYK] Randle 3pt Shot: Missed')]),
#  OrderedDict([('evt', 434),
#               ('cl', '05:41'),
#               ('de', '[ATL] Reddish Rebound (Off:0 Def:4)')]),
#  OrderedDict([('evt', 435),
#               ('cl', '05:36'),
#               ('de',
#                '[ATL] Reddish Turnover : Bad Pass (2 TO) Steal:Payton (3 ST)')]),
#  OrderedDict([('evt', 437),
#               ('cl', '05:34'),
#               ('de',
#                '[NYK 84-65] Barrett Running Layup Shot: Made (12 PTS) Assist: Payton (10 AST)')]),
#  OrderedDict([('evt', 439),
#               ('cl', '05:34'),
#               ('de', '[ATL] Carter Foul: Shooting (4 PF) (1 FTA) (K Mauer)')]),
#  OrderedDict([('evt', 441),
#               ('cl', '05:34'),
#               ('de', '[NYK 85-65] Barrett Free Throw 1 of 1 (13 PTS)')]),
#  OrderedDict([('evt', 442),
#               ('cl', '05:13'),
#               ('de',
#                '[ATL 67-85] Reddish Driving Floating Bank Jump Shot: Made (8 PTS) Assist: Graham (2 AST)')]),
#  OrderedDict([('evt', 444),
#               ('cl', '04:58'),
#               ('de',
#                '[NYK] Payton Turnover : Out of Bounds - Bad Pass Turnover (4 TO)')]),
#  OrderedDict([('evt', 445),
#               ('cl', '04:49'),
#               ('de', '[ATL] Reddish Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 446),
#               ('cl', '04:46'),
#               ('de', '[NYK] Barrett Rebound (Off:0 Def:3)')]),
#  OrderedDict([('evt', 447),
#               ('cl', '04:27'),
#               ('de',
#                '[NYK 87-67] Robinson Dunk Shot: Made (10 PTS) Assist: Randle (2 AST)')]),
#  OrderedDict([('evt', 449),
#               ('cl', '04:15'),
#               ('de', '[ATL 69-87] Teague Driving Layup Shot: Made (15 PTS)')]),
#  OrderedDict([('evt', 450),
#               ('cl', '04:04'),
#               ('de',
#                '[NYK 89-69] Randle Cutting Dunk Shot: Made (17 PTS) Assist: Payton (11 AST)')]),
#  OrderedDict([('evt', 452),
#               ('cl', '03:49'),
#               ('de', '[ATL] Fernando Dunk Shot: Missed')]),
#  OrderedDict([('evt', 454),
#               ('cl', '03:48'),
#               ('de', '[ATL] Fernando Rebound (Off:1 Def:1)')]),
#  OrderedDict([('evt', 455),
#               ('cl', '03:48'),
#               ('de', '[NYK] Randle Foul: Personal (2 PF) (D Collins)')]),
#  OrderedDict([('evt', 457),
#               ('cl', '03:37'),
#               ('de', '[ATL 71-89] Carter Reverse Layup Shot: Made (2 PTS)')]),
#  OrderedDict([('evt', 458),
#               ('cl', '03:22'),
#               ('de',
#                '[NYK 91-71] Barrett Driving Floating Bank Jump Shot: Made (15 PTS)')]),
#  OrderedDict([('evt', 459),
#               ('cl', '03:22'),
#               ('de', '[ATL] Teague Foul: Shooting (2 PF) (1 FTA) (K Mauer)')]),
#  OrderedDict([('evt', 461),
#               ('cl', '03:22'),
#               ('de', '[NYK] Payton Substitution replaced by Ntilikina')]),
#  OrderedDict([('evt', 463),
#               ('cl', '03:22'),
#               ('de', '[NYK 92-71] Barrett Free Throw 1 of 1 (16 PTS)')]),
#  OrderedDict([('evt', 464),
#               ('cl', '03:09'),
#               ('de',
#                '[ATL] Reddish Turnover : Lost Ball (3 TO) Steal:Barrett (1 ST)')]),
#  OrderedDict([('evt', 466),
#               ('cl', '02:49'),
#               ('de',
#                '[NYK] Randle Turnover : Bad Pass (2 TO) Steal:Reddish (2 ST)')]),
#  OrderedDict([('evt', 468),
#               ('cl', '02:40'),
#               ('de', '[ATL] Carter Fadeaway Jump Shot: Missed')]),
#  OrderedDict([('evt', 469),
#               ('cl', '02:33'),
#               ('de', '[ATL] Graham Rebound (Off:1 Def:1)')]),
#  OrderedDict([('evt', 470),
#               ('cl', '02:33'),
#               ('de', '[ATL 73-92] Graham Tip Dunk Shot: Made (5 PTS)')]),
#  OrderedDict([('evt', 471),
#               ('cl', '02:23'),
#               ('de', '[ATL] Graham Foul: Personal (2 PF) (K Mauer)')]),
#  OrderedDict([('evt', 473),
#               ('cl', '02:23'),
#               ('de', '[NYK] Barrett Substitution replaced by Portis')]),
#  OrderedDict([('evt', 474),
#               ('cl', '02:23'),
#               ('de', '[NYK] Randle Substitution replaced by Knox II')]),
#  OrderedDict([('evt', 477),
#               ('cl', '02:10'),
#               ('de', '[NYK] Ntilikina Fadeaway Jump Shot: Missed')]),
#  OrderedDict([('evt', 478),
#               ('cl', '02:06'),
#               ('de', '[ATL] Graham Rebound (Off:1 Def:2)')]),
#  OrderedDict([('evt', 479),
#               ('cl', '02:01'),
#               ('de',
#                '[ATL] Graham Turnover : Bad Pass (1 TO) Steal:Robinson (1 ST)')]),
#  OrderedDict([('evt', 481),
#               ('cl', '01:42'),
#               ('de', '[NYK] Portis Jump Shot: Missed')]),
#  OrderedDict([('evt', 482),
#               ('cl', '01:42'),
#               ('de', '[NYK] Robinson Rebound (Off:3 Def:1)')]),
#  OrderedDict([('evt', 483),
#               ('cl', '01:42'),
#               ('de', '[ATL] Graham Foul: Personal (3 PF) (2 FTA) (L Wood)')]),
#  OrderedDict([('evt', 485),
#               ('cl', '01:42'),
#               ('de', '[NYK] Robinson Free Throw 1 of 2 Missed')]),
#  OrderedDict([('evt', 486), ('cl', '01:42'), ('de', '[NYK] Team Rebound')]),
#  OrderedDict([('evt', 487),
#               ('cl', '01:42'),
#               ('de', '[ATL] Carter Substitution replaced by Dedmon')]),
#  OrderedDict([('evt', 488),
#               ('cl', '01:42'),
#               ('de', '[ATL] Fernando Substitution replaced by Collins')]),
#  OrderedDict([('evt', 489),
#               ('cl', '01:42'),
#               ('de', '[NYK] Harkless Substitution replaced by Ellington')]),
#  OrderedDict([('evt', 493),
#               ('cl', '01:42'),
#               ('de', '[NYK 93-73] Robinson Free Throw 2 of 2 (11 PTS)')]),
#  OrderedDict([('evt', 494),
#               ('cl', '01:34'),
#               ('de',
#                '[ATL] Teague Turnover : Bad Pass (2 TO) Steal:Knox II (1 ST)')]),
#  OrderedDict([('evt', 496),
#               ('cl', '01:16'),
#               ('de', '[NYK] Knox II Step Back Jump shot: Missed')]),
#  OrderedDict([('evt', 497),
#               ('cl', '01:11'),
#               ('de', '[NYK] Robinson Rebound (Off:4 Def:1)')]),
#  OrderedDict([('evt', 498),
#               ('cl', '01:09'),
#               ('de', '[NYK] Ellington 3pt Shot: Missed')]),
#  OrderedDict([('evt', 499),
#               ('cl', '01:07'),
#               ('de', '[ATL] Dedmon Rebound (Off:3 Def:6)')]),
#  OrderedDict([('evt', 500),
#               ('cl', '00:56.5'),
#               ('de', '[ATL] Collins 3pt Shot: Missed')]),
#  OrderedDict([('evt', 501),
#               ('cl', '00:53.4'),
#               ('de', '[NYK] Ellington Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 502),
#               ('cl', '00:39.5'),
#               ('de',
#                '[NYK 96-73] Portis 3pt Shot: Made (7 PTS) Assist: Ellington (2 AST)')]),
#  OrderedDict([('evt', 504),
#               ('cl', '00:34.4'),
#               ('de',
#                '[ATL 76-96] Reddish 3pt Shot: Made (11 PTS) Assist: Teague (3 AST)')]),
#  OrderedDict([('evt', 506),
#               ('cl', '00:25.7'),
#               ('de', '[NYK] Portis 3pt Shot: Missed')]),
#  OrderedDict([('evt', 507),
#               ('cl', '00:22.4'),
#               ('de', '[ATL] Collins Rebound (Off:3 Def:4)')]),
#  OrderedDict([('evt', 508),
#               ('cl', '00:04.2'),
#               ('de', '[ATL] Teague Step Back Jump shot: Missed')]),
#  OrderedDict([('evt', 509),
#               ('cl', '00:01.1'),
#               ('de', '[ATL] Dedmon Rebound (Off:4 Def:6)')]),
#  OrderedDict([('evt', 512),
#               ('cl', '00:01.1'),
#               ('de', '[ATL 78-96] Dedmon Tip Layup Shot: Made (4 PTS)')]),
#  OrderedDict([('evt', 513), ('cl', '00:00.0'), ('de', 'End Period')]),
#  OrderedDict([('evt', 520), ('cl', '12:00'), ('de', 'Start Period')]),
#  OrderedDict([('evt', 521),
#               ('cl', '11:44'),
#               ('de', '[ATL 80-96] Huerter Pullup Jump shot: Made (6 PTS)')]),
#  OrderedDict([('evt', 522),
# ...
#               ('cl', '02:33'),
#               ('de', '[ATL] Graham Rebound (Off:1 Def:1)')]),
#  OrderedDict([('evt', 470),
#               ('cl', '02:33'),
#               ('de', '[ATL 73-92] Graham Tip Dunk Shot: Made (5 PTS)')]),
#  OrderedDict([('evt', 471),
#               ('cl', '02:23'),
#               ('de', '[ATL] Graham Foul: Personal (2 PF) (K Mauer)')]),
#  OrderedDict([('evt', 473),
#               ('cl', '02:23'),
#               ('de', '[NYK] Barrett Substitution replaced by Portis')]),
#  OrderedDict([('evt', 474),
#               ('cl', '02:23'),
#               ('de', '[NYK] Randle Substitution replaced by Knox II')]),
#  OrderedDict([('evt', 477),
#               ('cl', '02:10'),
#               ('de', '[NYK] Ntilikina Fadeaway Jump Shot: Missed')]),
#  OrderedDict([('evt', 478),
#               ('cl', '02:06'),
#               ('de', '[ATL] Graham Rebound (Off:1 Def:2)')]),
#  OrderedDict([('evt', 479),
#               ('cl', '02:01'),
#               ('de',
#                '[ATL] Graham Turnover : Bad Pass (1 TO) Steal:Robinson (1 ST)')]),
#  OrderedDict([('evt', 481),
#               ('cl', '01:42'),
#               ('de', '[NYK] Portis Jump Shot: Missed')]),
#  OrderedDict([('evt', 482),
#               ('cl', '01:42'),
#               ('de', '[NYK] Robinson Rebound (Off:3 Def:1)')]),
#  OrderedDict([('evt', 483),
#               ('cl', '01:42'),
#               ('de', '[ATL] Graham Foul: Personal (3 PF) (2 FTA) (L Wood)')]),
#  OrderedDict([('evt', 485),
#               ('cl', '01:42'),
#               ('de', '[NYK] Robinson Free Throw 1 of 2 Missed')]),
#  OrderedDict([('evt', 486), ('cl', '01:42'), ('de', '[NYK] Team Rebound')]),
#  OrderedDict([('evt', 487),
#               ('cl', '01:42'),
#               ('de', '[ATL] Carter Substitution replaced by Dedmon')]),
#  OrderedDict([('evt', 488),
#               ('cl', '01:42'),
#               ('de', '[ATL] Fernando Substitution replaced by Collins')]),
#  OrderedDict([('evt', 489),
#               ('cl', '01:42'),
#               ('de', '[NYK] Harkless Substitution replaced by Ellington')]),
#  OrderedDict([('evt', 493),
#               ('cl', '01:42'),
#               ('de', '[NYK 93-73] Robinson Free Throw 2 of 2 (11 PTS)')]),
#  OrderedDict([('evt', 494),
#               ('cl', '01:34'),
#               ('de',
#                '[ATL] Teague Turnover : Bad Pass (2 TO) Steal:Knox II (1 ST)')]),
#  OrderedDict([('evt', 496),
#               ('cl', '01:16'),
#               ('de', '[NYK] Knox II Step Back Jump shot: Missed')]),
#  OrderedDict([('evt', 497),
#               ('cl', '01:11'),
#               ('de', '[NYK] Robinson Rebound (Off:4 Def:1)')]),
#  OrderedDict([('evt', 498),
#               ('cl', '01:09'),
#               ('de', '[NYK] Ellington 3pt Shot: Missed')]),
#  OrderedDict([('evt', 499),
#               ('cl', '01:07'),
#               ('de', '[ATL] Dedmon Rebound (Off:3 Def:6)')]),
#  OrderedDict([('evt', 500),
#               ('cl', '00:56.5'),
#               ('de', '[ATL] Collins 3pt Shot: Missed')]),
#  OrderedDict([('evt', 501),
#               ('cl', '00:53.4'),
#               ('de', '[NYK] Ellington Rebound (Off:0 Def:1)')]),
#  OrderedDict([('evt', 502),
#               ('cl', '00:39.5'),
#               ('de',
#                '[NYK 96-73] Portis 3pt Shot: Made (7 PTS) Assist: Ellington (2 AST)')]),
#  OrderedDict([('evt', 504),
#               ('cl', '00:34.4'),
#               ('de',
#                '[ATL 76-96] Reddish 3pt Shot: Made (11 PTS) Assist: Teague (3 AST)')]),
#  OrderedDict([('evt', 506),
#               ('cl', '00:25.7'),
#               ('de', '[NYK] Portis 3pt Shot: Missed')]),
#  OrderedDict([('evt', 507),
#               ('cl', '00:22.4'),
#               ('de', '[ATL] Collins Rebound (Off:3 Def:4)')]),
#  OrderedDict([('evt', 508),
#               ('cl', '00:04.2'),
#               ('de', '[ATL] Teague Step Back Jump shot: Missed')]),
#  OrderedDict([('evt', 509),
#               ('cl', '00:01.1'),
#               ('de', '[ATL] Dedmon Rebound (Off:4 Def:6)')]),
#  OrderedDict([('evt', 512),
#               ('cl', '00:01.1'),
#               ('de', '[ATL 78-96] Dedmon Tip Layup Shot: Made (4 PTS)')]),
#  OrderedDict([('evt', 513), ('cl', '00:00.0'), ('de', 'End Period')]),
#  OrderedDict([('evt', 520), ('cl', '12:00'), ('de', 'Start Period')]),
#  OrderedDict([('evt', 521),
#               ('cl', '11:44'),
#               ('de', '[ATL 80-96] Huerter Pullup Jump shot: Made (6 PTS)')]),
#  OrderedDict([('evt', 522),
#               ('cl', '11:27'),
#               ('de', '[NYK] Ellington 3pt Shot: Missed')]),
#  OrderedDict([('evt', 523),
#               ('cl', '11:25'),
#               ('de', '[ATL] Collins Rebound (Off:3 Def:5)')]),
#  OrderedDict([('evt', 524),
#               ('cl', '11:19'),
#               ('de', '[ATL] Huerter 3pt Shot: Missed')]),
#  OrderedDict([('evt', 526),
#               ('cl', '11:12'),
#               ('de', '[NYK] Ellington Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 527),
#               ('cl', '11:09'),
#               ('de',
#                '[ATL] Dedmon Foul: Shooting (2 PF) (2 FTA) (D Collins)')]),
#  OrderedDict([('evt', 529),
#               ('cl', '11:09'),
#               ('de', '[NYK] Knox II Free Throw 1 of 2 Missed')]),
#  OrderedDict([('evt', 530), ('cl', '11:09'), ('de', '[NYK] Team Rebound')]),
#  OrderedDict([('evt', 531),
#               ('cl', '11:09'),
#               ('de', '[NYK] Ellington Substitution replaced by Barrett')]),
#  OrderedDict([('evt', 533),
#               ('cl', '11:09'),
#               ('de', '[NYK 97-80] Knox II Free Throw 2 of 2 (12 PTS)')]),
#  OrderedDict([('evt', 534),
#               ('cl', '11:01'),
#               ('de',
#                '[ATL 82-97] Young Driving Floating Bank Jump Shot: Made (15 PTS) Assist: Huerter (5 AST)')]),
#  OrderedDict([('evt', 535),
#               ('cl', '11:01'),
#               ('de',
#                '[NYK] Ntilikina Foul: Shooting (3 PF) (1 FTA) (D Collins)')]),
#  OrderedDict([('evt', 537),
#               ('cl', '11:01'),
#               ('de', '[ATL 83-97] Young Free Throw 1 of 1 (16 PTS)')]),
#  OrderedDict([('evt', 539),
#               ('cl', '10:45'),
#               ('de', '[NYK] Knox II Floating Jump shot: Missed')]),
#  OrderedDict([('evt', 540), ('cl', '10:42'), ('de', '[ATL] Team Rebound')]),
#  OrderedDict([('evt', 541),
#               ('cl', '10:42'),
#               ('de', '[NYK] Knox II Foul: Loose Ball (2 PF) (K Mauer)')]),
#  OrderedDict([('evt', 543),
#               ('cl', '10:32'),
#               ('de',
#                '[ATL] Young Turnover : Bad Pass (3 TO) Steal:Knox II (2 ST)')]),
#  OrderedDict([('evt', 545),
#               ('cl', '10:13'),
#               ('de',
#                '[NYK 99-83] Barrett Step Back Bank Jump Shot: Made (18 PTS)')]),
#  OrderedDict([('evt', 546),
#               ('cl', '09:58'),
#               ('de', '[ATL] Hunter Driving Floating Jump Shot: Missed')]),
#  OrderedDict([('evt', 547), ('cl', '09:56'), ('de', '[ATL] Team Rebound')]),
#  OrderedDict([('evt', 548),
#               ('cl', '09:56'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 549),
#               ('cl', '09:48'),
#               ('de', '[ATL] Young 3pt Shot: Missed')]),
#  OrderedDict([('evt', 550),
#               ('cl', '09:44'),
#               ('de', '[NYK] Barrett Rebound (Off:0 Def:4)')]),
#  OrderedDict([('evt', 551),
#               ('cl', '09:28'),
#               ('de', '[ATL] Young Foul: Personal (2 PF) (L Wood)')]),
#  OrderedDict([('evt', 553),
#               ('cl', '09:23'),
#               ('de', '[NYK] Ntilikina Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 554),
#               ('cl', '09:14'),
#               ('de', '[ATL] Dedmon Rebound (Off:4 Def:7)')]),
#  OrderedDict([('evt', 555),
#               ('cl', '09:12'),
#               ('de',
#                '[ATL 85-99] Collins Driving Layup Shot: Made (16 PTS) Assist: Young (5 AST)')]),
#  OrderedDict([('evt', 557),
#               ('cl', '09:12'),
#               ('de', '[NYK] Portis Foul: Shooting (1 PF) (1 FTA) (L Wood)')]),
#  OrderedDict([('evt', 559),
#               ('cl', '09:12'),
#               ('de', '[ATL] Collins Free Throw 1 of 1 Missed')]),
#  OrderedDict([('evt', 560),
#               ('cl', '09:09'),
#               ('de', '[NYK] Portis Rebound (Off:0 Def:2)')]),
#  OrderedDict([('evt', 561),
#               ('cl', '08:59'),
#               ('de', '[NYK 101-85] Barrett Pullup Jump shot: Made (20 PTS)')]),
#  OrderedDict([('evt', 562),
#               ('cl', '08:51'),
#               ('de',
#                '[NYK] Ntilikina Foul: Shooting (4 PF) (2 FTA) (K Mauer)')]),
#  OrderedDict([('evt', 564),
#               ('cl', '08:51'),
#               ('de', '[ATL 86-101] Young Free Throw 1 of 2 (17 PTS)')]),
#  OrderedDict([('evt', 565),
#               ('cl', '08:51'),
#               ('de', '[NYK] Robinson Substitution replaced by Gibson')]),
#  OrderedDict([('evt', 567),
#               ('cl', '08:51'),
#               ('de', '[ATL 87-101] Young Free Throw 2 of 2 (18 PTS)')]),
#  OrderedDict([('evt', 568),
#               ('cl', '08:36'),
#               ('de', '[NYK] Knox II Pullup Jump shot: Missed')]),
#  OrderedDict([('evt', 569),
#               ('cl', '08:32'),
#               ('de', '[ATL] Collins Rebound (Off:3 Def:6)')]),
#  OrderedDict([('evt', 570),
#               ('cl', '08:26'),
#               ('de', '[ATL 90-101] Young 3pt Shot: Made (21 PTS)')]),
#  OrderedDict([('evt', 571),
#               ('cl', '08:25'),
#               ('de', '[NYK] Team Timeout : Regular')]),
#  OrderedDict([('evt', 572),
#               ('cl', '08:25'),
#               ('de', '[ATL] Huerter Substitution replaced by Reddish')]),
#  OrderedDict([('evt', 573),
#               ('cl', '08:25'),
#               ('de', '[NYK] Knox II Substitution replaced by Harkless')]),
#  OrderedDict([('evt', 576),
#               ('cl', '08:06'),
#               ('de', '[NYK] Gibson 3pt Shot: Missed')]),
#  OrderedDict([('evt', 577), ('cl', '08:04'), ('de', '[ATL] Team Rebound')]),
#  OrderedDict([('evt', 578),
#               ('cl', '08:04'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 579),
#               ('cl', '07:53'),
#               ('de',
#                '[NYK] Gibson Foul: Defense 3 Second (3 PF) (1 FTA) (L Wood)')]),
#  OrderedDict([('evt', 580),
#               ('cl', '07:53'),
#               ('de', '[ATL 91-101] Young Free Throw Technical (22 PTS)')]),
#  OrderedDict([('evt', 581),
#               ('cl', '07:48'),
#               ('de',
#                '[ATL] Dedmon Turnover : Out of Bounds - Bad Pass Turnover (1 TO)')]),
#  OrderedDict([('evt', 582),
#               ('cl', '07:35'),
#               ('de', '[ATL] Reddish Foul: Personal (2 PF) (D Collins)')]),
#  OrderedDict([('evt', 584),
#               ('cl', '07:35'),
#               ('de', '[NYK] Portis Substitution replaced by Randle')]),
#  OrderedDict([('evt', 585),
#               ('cl', '07:35'),
#               ('de', '[NYK] Ntilikina Substitution replaced by Payton')]),
#  OrderedDict([('evt', 588),
#               ('cl', '07:29'),
#               ('de', '[NYK] Randle Jump Shot: Missed')]),
#  OrderedDict([('evt', 589),
#               ('cl', '07:25'),
#               ('de', '[ATL] Hunter Rebound (Off:0 Def:3)')]),
#  OrderedDict([('evt', 590),
#               ('cl', '07:11'),
#               ('de',
#                '[ATL] Young Turnover : Lost Ball (4 TO) Steal:Randle (1 ST)')]),
#  OrderedDict([('evt', 592),
#               ('cl', '06:52'),
#               ('de',
#                '[NYK 103-91] Payton Driving Floating Jump Shot: Made (8 PTS)')]),
#  OrderedDict([('evt', 593),
#               ('cl', '06:44'),
#               ('de',
#                '[ATL 94-103] Hunter 3pt Shot: Made (11 PTS) Assist: Young (6 AST)')]),
#  OrderedDict([('evt', 595),
#               ('cl', '06:22'),
#               ('de', '[ATL] Dedmon Foul: Shooting (3 PF) (2 FTA) (K Mauer)')]),
#  OrderedDict([('evt', 597),
#               ('cl', '06:22'),
#               ('de', '[NYK 104-94] Payton Free Throw 1 of 2 (9 PTS)')]),
#  OrderedDict([('evt', 598),
#               ('cl', '06:22'),
#               ('de', '[NYK] Gibson Substitution replaced by Robinson')]),
#  OrderedDict([('evt', 600),
#               ('cl', '06:22'),
#               ('de', '[NYK] Payton Free Throw 2 of 2 Missed')]),
#  OrderedDict([('evt', 601),
#               ('cl', '06:20'),
#               ('de', '[ATL] Collins Rebound (Off:3 Def:7)')]),
#  OrderedDict([('evt', 602),
#               ('cl', '06:09'),
#               ('de', '[ATL] Hunter 3pt Shot: Missed')]),
#  OrderedDict([('evt', 603),
#               ('cl', '06:05'),
#               ('de', '[NYK] Payton Rebound (Off:0 Def:5)')]),
#  OrderedDict([('evt', 604),
#               ('cl', '06:01'),
#               ('de',
#                '[NYK 107-94] Barrett 3pt Shot: Made (23 PTS) Assist: Harkless (5 AST)')]),
#  OrderedDict([('evt', 606),
#               ('cl', '05:48'),
#               ('de',
#                '[ATL 96-107] Young Driving Floating Jump Shot: Made (24 PTS)')]),
#  OrderedDict([('evt', 666),
#               ('cl', '05:24'),
#               ('de', '[NYK] Payton Driving Floating Jump Shot: Missed')]),
#  OrderedDict([('evt', 667),
#               ('cl', '05:24'),
#               ('de', '[ATL] Dedmon Rebound (Off:4 Def:8)')]),
#  OrderedDict([('evt', 609),
#               ('cl', '05:17'),
#               ('de',
#                '[ATL] Hunter Turnover : Bad Pass (1 TO) Steal:Barrett (2 ST)')]),
#  OrderedDict([('evt', 611),
#               ('cl', '04:59'),
#               ('de',
#                '[NYK 109-96] Payton Driving Floating Jump Shot: Made (11 PTS)')]),
#  OrderedDict([('evt', 612),
#               ('cl', '04:57'),
#               ('de', '[ATL] Team Timeout : Regular')]),
#  OrderedDict([('evt', 613),
#               ('cl', '04:57'),
#               ('de', '[ATL] Dedmon Substitution replaced by Huerter')]),
#  OrderedDict([('evt', 615),
#               ('cl', '04:50'),
#               ('de', '[ATL 99-109] Young 3pt Shot: Made (27 PTS)')]),
#  OrderedDict([('evt', 616),
#               ('cl', '04:33'),
#               ('de', '[ATL] Collins Foul: Shooting (1 PF) (2 FTA) (L Wood)')]),
#  OrderedDict([('evt', 618),
#               ('cl', '04:33'),
#               ('de', '[NYK] Robinson Free Throw 1 of 2 Missed')]),
#  OrderedDict([('evt', 619), ('cl', '04:33'), ('de', '[NYK] Team Rebound')]),
#  OrderedDict([('evt', 620),
#               ('cl', '04:33'),
#               ('de', '[NYK] Robinson Free Throw 2 of 2 Missed')]),
#  OrderedDict([('evt', 621),
#               ('cl', '04:30'),
#               ('de', '[ATL] Hunter Rebound (Off:0 Def:4)')]),
#  OrderedDict([('evt', 622),
#               ('cl', '04:27'),
#               ('de',
#                '[NYK] Robinson Foul: Shooting (3 PF) (2 FTA) (K Mauer)')]),
#  OrderedDict([('evt', 624),
#               ('cl', '04:27'),
#               ('de', '[ATL 100-109] Young Free Throw 1 of 2 (28 PTS)')]),
#  OrderedDict([('evt', 625),
#               ('cl', '04:27'),
#               ('de', '[ATL 101-109] Young Free Throw 2 of 2 (29 PTS)')]),
#  OrderedDict([('evt', 626),
#               ('cl', '04:21'),
#               ('de', '[ATL] Huerter Foul: Personal (2 PF) (2 FTA) (L Wood)')]),
#  OrderedDict([('evt', 628),
#               ('cl', '04:21'),
#               ('de', '[NYK] Robinson Free Throw 1 of 2 Missed')]),
#  OrderedDict([('evt', 629), ('cl', '04:21'), ('de', '[NYK] Team Rebound')]),
#  OrderedDict([('evt', 630),
#               ('cl', '04:21'),
#               ('de', '[NYK] Robinson Free Throw 2 of 2 Missed')]),
#  OrderedDict([('evt', 631),
#               ('cl', '04:18'),
#               ('de', '[ATL] Reddish Rebound (Off:0 Def:5)')]),
#  OrderedDict([('evt', 632),
#               ('cl', '04:13'),
#               ('de',
#                '[ATL 103-109] Collins Alley Oop Dunk Shot: Made (18 PTS) Assist: Young (7 AST)')]),
#  OrderedDict([('evt', 634),
#               ('cl', '04:13'),
#               ('de', '[NYK] Team Timeout : Regular')]),
#  OrderedDict([('evt', 635),
#               ('cl', '04:13'),
#               ('de', '[NYK] Robinson Substitution replaced by Ntilikina')]),
#  OrderedDict([('evt', 637),
#               ('cl', '04:00'),
#               ('de',
#                '[NYK 111-103] Randle Step Back Jump shot: Made (19 PTS)')]),
#  OrderedDict([('evt', 638),
#               ('cl', '03:51'),
#               ('de', 'Stoppage: Out-of-Bounds')]),
#  OrderedDict([('evt', 639),
#               ('cl', '03:47'),
#               ('de', '[ATL] Collins Turnover : Traveling (3 TO)')]),
#  ...]

# %%
for i in range(0, 1500):
    if i>999:
        gameid = str(i)
    elif i>99:
        gameid = '0'+str(i)
    elif i>9:
        gameid = '00'+str(i)
    else:
        gameid = '000'+str(i)
    print(gameid)
# Out:
# 0000
# 0001
# 0002
# 0003
# 0004
# 0005
# 0006
# 0007
# 0008
# 0009
# 0930
# 0931
# 0932
# 0933
# 0934
# 0935
# 0936
# 0937
# 0938
# 0939
# 0940
# 0941
# 0942
# 0943
# 0944
# 0945
# 0946
# 0947
# 0948
# 0949
# 0950
# 0951
# 0952
# 0953
# 0954
# 0955
# 0956
# 0957
# 0958
# 0959
# 0960
# 0961
# 0962
# 0963
# 0964
# 0965
# 0966
# 0967
# 0968
# 0969
# 0970
# 0971
# 0972
# 0973
# 0974
# 0975
# 0976
# 0977
# 0978
# 0979
# 0980
# 0981
# 0982
# 0983
# 0984
# 0985
# 0986
# 0987
# 0988
# 0989
# 0990
# 0991
# 0992
# 0993
# 0994
# 0995
# 0996
# 0997
# 0998
# 0999
# 1000
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
# 1009
# 1010
# 1011
# 1012
# 1013
# 1014
# 1015
# 1016
# 1017
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# 1024
# 1025
# 1026
# 1027
# 1028
# 1029
# 1030
# 1031
# 1032
# 1033
# 1034
# 1035
# 1036
# 1037
# 1038
# 1039
# 1040
# 1041
# 1042
# 1043
# 1044
# 1045
# 1046
# 1047
# 1048
# 1049
# 1050
# 1051
# 1052
# 1053
# 1054
# 1055
# 1056
# 1057
# 1058
# 1059
# 1060
# 1061
# 1062
# 1063
# 1064
# 1065
# 1066
# 1067
# 1068
# 1069
# 1070
# 1071
# 1072
# 1073
# 1074
# 1075
# 1076
# 1077
# 1078
# 1079
# 1080
# 1081
# 1082
# 1083
# 1084
# 1085
# 1086
# 1087
# 1088
# 1089
# 1090
# 1091
# 1092
# 1093
# 1094
# 1095
# 1096
# 1097
# 1098
# 1099
# 1100
# 1101
# 1102
# 1103
# 1104
# 1105
# 1106
# 1107
# 1108
# 1109
# 1110
# 1111
# 1112
# 1113
# 1114
# 1115
# 1116
# 1117
# 1118
# 1119
# 1120
# 1121
# 1122
# 1123
# 1124
# 1125
# 1126
# 1127
# 1128
# 1129
# 1130
# 1131
# 1132
# 1133
# 1134
# 1135
# 1136
# 1137
# 1138
# 1139
# 1140
# 1141
# 1142
# 1143
# 1144
# 1145
# 1146
# 1147
# 1148
# 1149
# 1150
# 1151
# 1152
# 1153
# 1154
# 1155
# 1156
# 1157
# 1158
# 1159
# 1160
# 1161
# 1162
# 1163
# 1164
# 1165
# 1166
# 1167
# 1168
# 1169
# 1170
# 1171
# 1172
# 1173
# 1174
# 1175
# 1176
# 1177
# 1178
# 1179
# 1180
# 1181
# 1182
# 1183
# 1184
# 1185
# 1186
# 1187
# 1188
# 1189
# 1190
# 1191
# 1192
# 1193
# 1194
# 1195
# 1196
# 1197
# 1198
# 1199
# 1200
# 1201
# 1202
# 1203
# 1204
# 1205
# 1206
# 1207
# 1208
# 1209
# 1210
# 1211
# 1212
# 1213
# 1214
# 1215
# 1216
# 1217
# 1218
# 1219
# 1220
# 1221
# 1222
# 1223
# 1224
# 1225
# 1226
# 1227
# 1228
# 1229
# 1230
# 1231
# 1232
# 1233
# 1234
# 1235
# 1236
# 1237
# 1238
# 1239
# 1240
# 1241
# 1242
# 1243
# 1244
# 1245
# 1246
# 1247
# 1248
# 1249
# 1250
# 1251
# 1252
# 1253
# 1254
# 1255
# 1256
# 1257
# 1258
# 1259
# 1260
# 1261
# 1262
# 1263
# 1264
# 1265
# 1266
# 1267
# 1268
# 1269
# 1270
# 1271
# 1272
# 1273
# 1274
# 1275
# 1276
# 1277
# 1278
# 1279
# 1280
# 1281
# 1282
# 1283
# 1284
# 1285
# 1286
# 1287
# 1288
# 1289
# 1290
# 1291
# 1292
# 1293
# 1294
# 1295
# 1296
# 1297
# 1298
# 1299
# 1300
# 1301
# 1302
# 1303
# 1304
# 1305
# 1306
# 1307
# 1308
# 1309
# 1310
# 1311
# 1312
# 1313
# 1314
# 1315
# 1316
# 1317
# 1318
# 1319
# 1320
# 1321
# 1322
# 1323
# 1324
# 1325
# 1326
# 1327
# 1328
# 1329
# 1330
# 1331
# 1332
# 1333
# 1334
# 1335
# 1336
# 1337
# 1338
# 1339
# 1340
# 1341
# 1342
# 1343
# 1344
# 1345
# 1346
# 1347
# 1348
# 1349
# 1350
# 1351
# 1352
# 1353
# 1354
# 1355
# 1356
# 1357
# 1358
# 1359
# 1360
# 1361
# 1362
# 1363
# 1364
# 1365
# 1366
# 1367
# 1368
# 1369
# 1370
# 1371
# 1372
# 1373
# 1374
# 1375
# 1376
# 1377
# 1378
# 1379
# 1380
# 1381
# 1382
# 1383
# 1384
# 1385
# 1386
# 1387
# 1388
# 1389
# 1390
# 1391
# 1392
# 1393
# 1394
# 1395
# 1396
# 1397
# 1398
# 1399
# 1400
# 1401
# 1402
# 1403
# 1404
# 1405
# 1406
# 1407
# 1408
# 1409
# 1410
# 1411
# 1412
# 1413
# 1414
# 1415
# 1416
# 1417
# 1418
# 1419
# 1420
# 1421
# 1422
# 1423
# 1424
# 1425
# 1426
# 1427
# 1428
# 1429
# 1430
# 1431
# 1432
# 1433
# 1434
# 1435
# 1436
# 1437
# 1438
# 1439
# 1440
# 1441
# 1442
# 1443
# 1444
# 1445
# 1446
# 1447
# 1448
# 1449
# 1450
# 1451
# 1452
# 1453
# 1454
# 1455
# 1456
# 1457
# 1458
# 1459
# 1460
# 1461
# 1462
# 1463
# 1464
# 1465
# 1466
# 1467
# 1468
# 1469
# 1470
# 1471
# 1472
# 1473
# 1474
# 1475
# 1476
# 1477
# 1478
# 1479
# 1480
# 1481
# 1482
# 1483
# 1484
# 1485
# 1486
# 1487
# 1488
# 1489
# 1490
# 1491
# 1492
# 1493
# 1494
# 1495
# 1496
# 1497
# 1498
# 1499

# %%
scraped_data = scrap_nba_detailed_info()

    

len(scraped_data)
type(scraped_data)

scraped_data_1 = {'20110304':scraped_data}
scraped_data_1['20110304']
for i,j in scraped_data_1.items():
    print(i, j)
# Out:
# 20110304 [OrderedDict([('evt', 2), ('cl', '12:00'), ('de', 'Start Period')]), OrderedDict([('evt', 4), ('cl', '11:56'), ('de', '[ATL] Dedmon Violation:Jump Ball (K Mauer)')]), OrderedDict([('evt', 5), ('cl', '11:48'), ('de', '[NYK] Harkless Driving Layup Shot: Missed')]), OrderedDict([('evt', 6), ('cl', '11:45'), ('de', '[ATL] Dedmon Rebound (Off:0 Def:1)')]), OrderedDict([('evt', 7), ('cl', '11:39'), ('de', '[ATL] Dedmon 3pt Shot: Missed')]), OrderedDict([('evt', 8), ('cl', '11:36'), ('de', '[ATL] Team Rebound')]), OrderedDict([('evt', 9), ('cl', '11:36'), ('de', 'Stoppage: Out-of-Bounds')]), OrderedDict([('evt', 10), ('cl', '11:30'), ('de', '[ATL] Young Driving Floating Bank Jump Shot: Missed')]), OrderedDict([('evt', 11), ('cl', '11:26'), ('de', '[NYK] Harkless Rebound (Off:0 Def:1)')]), OrderedDict([('evt', 12), ('cl', '11:21'), ('de', '[NYK] Barrett 3pt Shot: Missed')]), OrderedDict([('evt', 13), ('cl', '11:19'), ('de', '[ATL] Dedmon Rebound (Off:0 Def:2)')]), OrderedDict([('evt', 14), ('cl', '11:16'), ('de', '[ATL] Hunter 3pt Shot: Missed')]), OrderedDict([('evt', 15), ('cl', '11:16'), ('de', '[NYK] Randle Rebound (Off:0 Def:1)')]), OrderedDict([('evt', 16), ('cl', '10:56'), ('de', '[NYK] Randle Driving Floating Jump Shot: Missed')]), OrderedDict([('evt', 17), ('cl', '10:52'), ('de', '[ATL] Collins Rebound (Off:0 Def:1)')]), OrderedDict([('evt', 18), ('cl', '10:45'), ('de', '[ATL] Collins 3pt Shot: Missed')]), OrderedDict([('evt', 19), ('cl', '10:40'), ('de', '[NYK] Payton Rebound (Off:0 Def:1)')]), OrderedDict([('evt', 20), ('cl', '10:37'), ('de', '[NYK 2-0] Randle Running Layup Shot: Made (2 PTS) Assist: Payton (1 AST)')]), OrderedDict([('evt', 22), ('cl', '10:20'), ('de', '[NYK] Harkless Foul: Personal (1 PF) (D Collins)')]), OrderedDict([('evt', 24), ('cl', '10:10'), ('de', '[ATL 2-2] Young Pullup Jump shot: Made (2 PTS)')]), OrderedDict([('evt', 26), ('cl', '09:53'), ('de', '[NYK 4-2] Randle Jump Shot: Made (4 PTS) Assist: Barrett (1 AST)')]), OrderedDict([('evt', 28), ('cl', '09:40'), ('de', '[ATL] Dedmon 3pt Shot: Missed')]), OrderedDict([('evt', 29), ('cl', '09:36'), ('de', '[NYK] Randle Rebound (Off:0 Def:2)')]), OrderedDict([('evt', 30), ('cl', '09:26'), ('de', '[NYK 6-2] Gibson Driving Layup Shot: Made (2 PTS)')]), OrderedDict([('evt', 32), ('cl', '09:13'), ('de', '[ATL 4-6] Huerter Driving Floating Jump Shot: Made (2 PTS)')]), OrderedDict([('evt', 33), ('cl', '09:05'), ('de', '[ATL] Huerter Foul: Personal (1 PF) (L Wood)')]), OrderedDict([('evt', 35), ('cl', '09:00'), ('de', '[NYK] Payton Turnover : Bad Pass (1 TO) Steal:Collins (1 ST)')]), OrderedDict([('evt', 37), ('cl', '08:56'), ('de', '[ATL] Huerter 3pt Shot: Missed')]), OrderedDict([('evt', 38), ('cl', '08:52'), ('de', '[NYK] Randle Rebound (Off:0 Def:3)')]), OrderedDict([('evt', 39), ('cl', '08:45'), ('de', '[NYK 9-4] Gibson 3pt Shot: Made (5 PTS) Assist: Payton (2 AST)')]), OrderedDict([('evt', 41), ('cl', '08:24'), ('de', '[ATL] Young Turnover : Bad Pass (1 TO) Steal:Payton (1 ST)')]), OrderedDict([('evt', 43), ('cl', '08:20'), ('de', '[NYK] Barrett Running Layup Shot: Missed')]), OrderedDict([('evt', 44), ('cl', '08:19'), ('de', '[NYK] Harkless Rebound (Off:1 Def:1)')]), OrderedDict([('evt', 45), ('cl', '08:19'), ('de', '[NYK 11-4] Harkless Tip Dunk Shot: Made (2 PTS)')]), OrderedDict([('evt', 46), ('cl', '08:19'), ('de', '[ATL] Team Timeout : Regular')]), OrderedDict([('evt', 47), ('cl', '08:07'), ('de', '[ATL] Huerter 3pt Shot: Missed')]), OrderedDict([('evt', 48), ('cl', '08:04'), ('de', '[ATL] Dedmon Rebound (Off:1 Def:2)')]), OrderedDict([('evt', 49), ('cl', '08:04'), ('de', '[ATL] Dedmon Tip Layup Shot: Missed')]), OrderedDict([('evt', 50), ('cl', '08:03'), ('de', '[NYK] Randle Rebound (Off:0 Def:4)')]), OrderedDict([('evt', 51), ('cl', '07:56'), ('de', '[NYK 13-4] Randle Cutting Layup Shot: Made (6 PTS) Assist: Harkless (1 AST)')]), OrderedDict([('evt', 53), ('cl', '07:43'), ('de', '[ATL 6-13] Hunter Pullup Jump shot: Made (2 PTS)')]), Ordere ...

# %%
df = pd.DataFrame(scraped_data)
df
# Out:
#      evt       cl                                                 de
# 0      2    12:00                                       Start Period
# 1      4    11:56         [ATL] Dedmon Violation:Jump Ball (K Mauer)
# 2      5    11:48          [NYK] Harkless Driving Layup Shot: Missed
# 3      6    11:45                 [ATL] Dedmon Rebound (Off:0 Def:1)
# 517  733    01:04  [ATL 126-131] Collins Driving Layup Shot: Made...
# 518  735  00:55.9  [NYK] Payton Turnover : Out of Bounds - Bad Pa...
# 519  736  00:50.3                       [ATL] Young 3pt Shot: Missed
# 520  737  00:46.9                [NYK] Barrett Rebound (Off:0 Def:5)
# 521  738  00:44.7                       [NYK] Team Timeout : Regular
# 522  739  00:44.7  [NYK] Robinson Substitution replaced by Ntilikina
# 523  741  00:43.6  [ATL] Huerter Foul: Personal Take (3 PF) (2 FT...
# 524  743  00:43.6  [NYK 132-126] Ntilikina Free Throw 1 of 2 (7 PTS)
# 525  744  00:43.6  [NYK 133-126] Ntilikina Free Throw 2 of 2 (8 PTS)
# 526  745  00:33.8  [ATL] Young Turnover : Bad Pass (6 TO) Steal:N...
# 527  747  00:26.2  [ATL] Collins Foul: Personal Take (2 PF) (2 FT...
# 528  749  00:26.2  [NYK 134-126] Harkless Free Throw 1 of 2 (14 PTS)
# 529  750  00:26.2            [NYK] Harkless Free Throw 2 of 2 Missed
# 530  751  00:24.8               [ATL] Collins Rebound (Off:4 Def:11)
# 531  752  00:24.8                       [ATL] Team Timeout : Regular
# 532  753  00:24.8  [NYK] Ntilikina Substitution replaced by Robinson
# 533  755  00:20.4  [NYK] Barrett Foul: Shooting (1 PF) (2 FTA) (D...
# 534  757  00:20.4    [ATL 127-134] Hunter Free Throw 1 of 2 (14 PTS)
# 535  758  00:20.4  [NYK] Robinson Substitution replaced by Ntilikina
# 536  760  00:20.4    [ATL 128-134] Hunter Free Throw 2 of 2 (15 PTS)
# 537  761  00:20.4                       [NYK] Team Timeout : Regular
# 538  762  00:20.4        [ATL] Young Substitution replaced by Graham
# 539  764  00:19.5  [ATL] Graham Foul: Personal Take (4 PF) (2 FTA...
# 540  766  00:19.5                       [ATL] Team Timeout : Regular
# 541  767  00:19.5        Instant Replay - Challenge - Support Ruling
# 542  768  00:19.5    [NYK 135-128] Randle Free Throw 1 of 2 (32 PTS)
# 543  769  00:19.5        [ATL] Hunter Substitution replaced by Young
# 544  770  00:19.5       [ATL] Graham Substitution replaced by Carter
# 545  773  00:19.5    [NYK 136-128] Randle Free Throw 2 of 2 (33 PTS)
# 546  774  00:13.4  [ATL 131-136] Carter 3pt Shot: Made (5 PTS) As...
# 547  776  00:00.0                                         End Period
# 548  777  00:00.0                                           Game End

# %%
# CSVFILE = OUTPUTS_DIR.joinpath('nba_detailed_info.csv')
# df.to_csv(CSVFILE, index=False, quoting=csv.QUOTE_ALL)

# %%
print(gameid)
# Out:
# 0009

# %%
https://stats.nba.com/stats/boxscoresummaryv2?GameID=0021001227

# %%
#To get date, team_name, game id

url_2 = 'https://stats.nba.com/stats/scoreboardV2?DayOffset=0&LeagueID=00&gameDate=04%2F13%2F2011'
headers = {
    'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.42 Safari/537.36',
    'x-nba-stats-origin': 'stats',
}

r2 = requests.get(url_2, headers=headers, timeout=15)

# %%
r2.json()
# Out:
# {'resource': 'scoreboardV2',
#  'parameters': {'GameDate': '04/13/2011', 'LeagueID': '00', 'DayOffset': '0'},
#  'resultSets': [{'name': 'GameHeader',
#    'headers': ['GAME_DATE_EST',
#     'GAME_SEQUENCE',
#     'GAME_ID',
#     'GAME_STATUS_ID',
#     'GAME_STATUS_TEXT',
#     'GAMECODE',
#     'HOME_TEAM_ID',
#     'VISITOR_TEAM_ID',
#     'SEASON',
#     'LIVE_PERIOD',
#     'LIVE_PC_TIME',
#     'NATL_TV_BROADCASTER_ABBREVIATION',
#     'HOME_TV_BROADCASTER_ABBREVIATION',
#     'AWAY_TV_BROADCASTER_ABBREVIATION',
#     'LIVE_PERIOD_TIME_BCAST',
#     'ARENA_NAME',
#     'WH_STATUS'],
#    'rowSet': [['2011-04-13T00:00:00',
#      1,
#      '0021001216',
#      3,
#      'Final',
#      '20110413/NYKBOS',
#      1610612738,
#      1610612752,
#      '2010',
#      4,
#      ' ',
#      None,
#      'NBCSB',
#      'MSG',
#      'Q4   - ',
#      'TD Garden',
#      1],
#     ['2011-04-13T00:00:00',
#      2,
#      '0021001217',
#      3,
#      'Final',
#      '20110413/ATLCHA',
#      1610612766,
#      1610612737,
#      '2010',
#      4,
#      ' ',
#      None,
#      None,
#      'FSSE-ATL',
#      'Q4   - ',
#      'Spectrum Center',
#      1],
#     ['2011-04-13T00:00:00',
#      3,
#      '0021001218',
#      3,
#      'Final',
#      '20110413/WASCLE',
#      1610612739,
#      1610612764,
#      '2010',
#      4,
#      ' ',
#      None,
#      'FSO',
#      'NBCSWA',
#      'Q4   - ',
#      'Quicken Loans Arena',
#      1],
#     ['2011-04-13T00:00:00',
#      4,
#      '0021001219',
#      3,
#      'Final',
#      '20110413/INDORL',
#      1610612753,
#      1610612754,
#      '2010',
#      4,
#      ' ',
#      None,
#      'FSFL',
#      'FSIND',
#      'Q4   - ',
#      'Amway Center',
#      1],
#     ['2011-04-13T00:00:00',
#      5,
#      '0021001220',
#      3,
#      'Final',
#      '20110413/DETPHI',
#      1610612755,
#      1610612765,
#      '2010',
#      4,
#      ' ',
#      None,
#      'NBCSP',
#      'FSD+',
#      'Q4   - ',
#      'Wells Fargo Center',
#      1],
#     ['2011-04-13T00:00:00',
#      6,
#      '0021001221',
#      3,
#      'Final',
#      '20110413/MIATOR',
#      1610612761,
#      1610612748,
#      '2010',
#      4,
#      ' ',
#      None,
#      'SN1',
#      'FSSUN',
#      'Q4   - ',
#      'Air Canada Centre',
#      1],
#     ['2011-04-13T00:00:00',
#      7,
#      '0021001222',
#      3,
#      'Final',
#      '20110413/NJNCHI',
#      1610612741,
#      1610612751,
#      '2010',
#      4,
#      ' ',
#      None,
#      'NBCSCH',
#      None,
#      'Q4   - ',
#      'United Center',
#      1],
#     ['2011-04-13T00:00:00',
#      8,
#      '0021001223',
#      3,
#      'Final',
#      '20110413/NOHDAL',
#      1610612742,
#      1610612740,
#      '2010',
#      4,
#      ' ',
#      'ESPN',
#      'FSSW-DAL',
#      None,
#      'Q4   - ESPN',
#      'American Airlines Center',
#      1],
#     ['2011-04-13T00:00:00',
#      9,
#      '0021001224',
#      3,
#      'Final',
#      '20110413/HOUMIN',
#      1610612750,
#      1610612745,
#      '2010',
#      4,
#      ' ',
#      None,
#      'FSNTH',
#      'FSH',
#      'Q4   - ',
#      'Target Center',
#      1],
#     ['2011-04-13T00:00:00',
#      10,
#      '0021001225',
#      3,
#      'Final',
#      '20110413/MILOKC',
#      1610612760,
#      1610612749,
#      '2010',
#      5,
#      ' ',
#      None,
#      'FSOK',
#      'FSWIS',
#      'Q5   - ',
#      'Chesapeake Energy Arena',
#      1],
#     ['2011-04-13T00:00:00',
#      11,
#      '0021001226',
#      3,
#      'Final',
#      '20110413/DENUTA',
#      1610612762,
#      1610612743,
#      '2010',
#      4,
#      ' ',
#      None,
#      'ROOT-RM',
#      'ALT',
#      'Q4   - ',
#      'EnergySolutions Arena',
#      1],
#     ['2011-04-13T00:00:00',
#      12,
#      '0021001227',
#      3,
#      'Final',
#      '20110413/PORGSW',
#      1610612744,
#      1610612757,
#      '2010',
#      4,
#      ' ',
#      None,
#      'CSN-BA+',
#      'NBCSNW',
#      'Q4   - ',
#      'ORACLE Arena',
#      1],
#     ['2011-04-13T00:00:00',
#      13,
#      '0021001228',
#      3,
#      'Final',
#      '20110413/MEMLAC',
#      1610612746,
#      1610612763,
#      '2010',
#      4,
#      ' ',
#      'ESPN',
#      'FSW',
#      None,
#      'Q4   - ESPN',
#      'Staples Center',
#      1],
#     ['2011-04-13T00:00:00',
#      14,
#      '0021001229',
#      3,
#      'Final',
#      '20110413/SASPHX',
#      1610612756,
#      1610612759,
#      '2010',
#      4,
#      ' ',
#      None,
#      'FSA',
#      'KENS',
#      'Q4   - ',
#      'US Airways Center',
#      1],
#     ['2011-04-13T00:00:00',
#      15,
#      '0021001230',
#      3,
#      'Final',
#      '20110413/LALSAC',
#      1610612758,
#      1610612747,
#      '2010',
#      5,
#      ' ',
#      None,
#      'NBCSCA',
#      'KCAL-LAL',
#      'Q5   - ',
#      'Sleep Train Arena',
#      1]]},
#   {'name': 'LineScore',
#    'headers': ['GAME_DATE_EST',
#     'GAME_SEQUENCE',
#     'GAME_ID',
#     'TEAM_ID',
#     'TEAM_ABBREVIATION',
#     'TEAM_CITY_NAME',
#     'TEAM_NAME',
#     'TEAM_WINS_LOSSES',
#     'PTS_QTR1',
#     'PTS_QTR2',
#     'PTS_QTR3',
#     'PTS_QTR4',
#     'PTS_OT1',
#     'PTS_OT2',
#     'PTS_OT3',
#     'PTS_OT4',
#     'PTS_OT5',
#     'PTS_OT6',
#     'PTS_OT7',
#     'PTS_OT8',
#     'PTS_OT9',
#     'PTS_OT10',
#     'PTS',
#     'FG_PCT',
#     'FT_PCT',
#     'FG3_PCT',
#     'AST',
#     'REB',
#     'TOV'],
#    'rowSet': [['2011-04-13T00:00:00',
#      1,
#      '0021001216',
#      1610612752,
#      'NYK',
#      'New York',
#      'Knicks',
#      '42-40',
#      28,
#      29,
#      27,
#      18,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      102,
#      0.459,
#      0.81,
#      0.304,
#      22,
#      37,
#      16],
#     ['2011-04-13T00:00:00',
#      1,
#      '0021001216',
#      1610612738,
#      'BOS',
#      'Boston',
#      'Celtics',
#      '56-26',
#      27,
#      34,
#      25,
#      26,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      112,
#      0.565,
#      0.615,
#      0.471,
#      19,
#      40,
#      15],
#     ['2011-04-13T00:00:00',
#      2,
#      '0021001217',
#      1610612737,
#      'ATL',
#      'Atlanta',
#      'Hawks',
#      '44-38',
#      18,
#      25,
#      23,
#      19,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      85,
#      0.43,
#      0.8,
#      0.125,
#      16,
#      37,
#      14],
#     ['2011-04-13T00:00:00',
#      2,
#      '0021001217',
#      1610612766,
#      'CHA',
#      'Charlotte',
#      'Bobcats',
#      '34-48',
#      29,
#      32,
#      13,
#      22,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      96,
#      0.5,
#      0.813,
#      0.3,
#      27,
#      37,
#      8],
#     ['2011-04-13T00:00:00',
#      3,
#      '0021001218',
#      1610612764,
#      'WAS',
#      'Washington',
#      'Wizards',
#      '23-59',
#      35,
#      15,
#      24,
#      19,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      93,
#      0.433,
#      0.733,
#      0.333,
#      24,
#      44,
#      16],
#     ['2011-04-13T00:00:00',
#      3,
#      '0021001218',
#      1610612739,
#      'CLE',
#      'Cleveland',
#      'Cavaliers',
#      '19-63',
#      23,
#      24,
#      24,
#      29,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      100,
#      0.422,
#      0.862,
#      0.238,
#      23,
#      40,
#      13],
#     ['2011-04-13T00:00:00',
#      4,
#      '0021001219',
#      1610612754,
#      'IND',
#      'Indiana',
#      'Pacers',
#      '37-45',
#      14,
#      15,
#      26,
#      19,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      74,
#      0.307,
#      0.688,
#      0.36,
#      16,
#      35,
#      17],
#     ['2011-04-13T00:00:00',
#      4,
#      '0021001219',
#      1610612753,
#      'ORL',
#      'Orlando',
#      'Magic',
#      '52-30',
#      28,
#      25,
#      18,
#      21,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      92,
#      0.438,
#      0.8,
#      0.308,
#      17,
#      55,
#      28],
#     ['2011-04-13T00:00:00',
#      5,
#      '0021001220',
#      1610612765,
#      'DET',
#      'Detroit',
#      'Pistons',
#      '30-52',
#      29,
#      23,
#      31,
#      21,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      104,
#      0.487,
#      0.774,
#      0.353,
#      26,
#      41,
#      11],
#     ['2011-04-13T00:00:00',
#      5,
#      '0021001220',
#      1610612755,
#      'PHI',
#      'Philadelphia',
#      '76ers',
#      '41-41',
#      24,
#      32,
#      21,
#      23,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      100,
#      0.429,
#      0.875,
#      0.333,
#      27,
#      40,
#      8],
#     ['2011-04-13T00:00:00',
#      6,
#      '0021001221',
#      1610612748,
#      'MIA',
#      'Miami',
#      'Heat',
#      '58-24',
#      29,
#      21,
#      20,
#      27,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      97,
#      0.457,
#      0.714,
#      0.5,
#      20,
#      40,
#      14],
#     ['2011-04-13T00:00:00',
#      6,
#      '0021001221',
#      1610612761,
#      'TOR',
#      'Toronto',
#      'Raptors',
#      '22-60',
#      20,
#      31,
#      18,
#      10,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      79,
#      0.438,
#      0.647,
#      0.125,
#      16,
#      33,
#      17],
#     ['2011-04-13T00:00:00',
#      7,
#      '0021001222',
#      1610612751,
#      'NJN',
#      'New Jersey',
#      'Nets',
#      '24-58',
#      20,
#      23,
#      25,
#      24,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      92,
#      0.45,
#      0.875,
#      0.4,
#      21,
#      35,
#      11],
#     ['2011-04-13T00:00:00',
#      7,
#      '0021001222',
#      1610612741,
#      'CHI',
#      'Chicago',
#      'Bulls',
#      '62-20',
#      26,
#      24,
#      18,
#      29,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      97,
#      0.43,
#      0.815,
#      0.333,
#      23,
#      45,
#      13],
#     ['2011-04-13T00:00:00',
#      8,
#      '0021001223',
#      1610612740,
#      'NOH',
#      'New Orleans',
#      'Hornets',
#      '46-36',
#      27,
#      34,
#      13,
#      15,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      89,
#      0.43,
#      0.882,
#      0.429,
#      23,
#      35,
#      13],
#     ['2011-04-13T00:00:00',
#      8,
#      '0021001223',
#      1610612742,
#      'DAL',
#      'Dallas',
#      'Mavericks',
#      '57-25',
#      28,
#      30,
#      28,
#      35,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      121,
#      0.548,
#      0.824,
#      0.464,
#      32,
#      42,
#      14],
#     ['2011-04-13T00:00:00',
#      9,
#      '0021001224',
#      1610612745,
#      'HOU',
#      'Houston',
#      'Rockets',
#      '43-39',
#      32,
#      37,
#      21,
#      31,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      121,
#      0.5,
#      0.781,
#      0.387,
#      32,
#      48,
#      15],
#     ['2011-04-13T00:00:00',
#      9,
#      '0021001224',
#      1610612750,
#      'MIN',
#      'Minnesota',
#      'Timberwolves',
#      '17-65',
#      30,
#      22,
#      37,
#      13,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      102,
#      0.446,
#      0.762,
#      0.308,
#      20,
#      42,
#      15],
#     ['2011-04-13T00:00:00',
#      10,
#      '0021001225',
#      1610612749,
#      'MIL',
#      'Milwaukee',
#      'Bucks',
#      '35-47',
#      16,
#      30,
#      18,
#      32,
#      14,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      110,
#      0.455,
#      0.852,
#      0.389,
#      22,
#      34,
#      13],
#     ['2011-04-13T00:00:00',
#      10,
#      '0021001225',
#      1610612760,
#      'OKC',
#      'Oklahoma City',
#      'Thunder',
#      '55-27',
#      21,
#      22,
#      31,
#      22,
#      10,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      106,
#      0.477,
#      0.778,
#      0.4,
#      26,
#      52,
#      23],
#     ['2011-04-13T00:00:00',
#      11,
#      '0021001226',
#      1610612743,
#      'DEN',
#      'Denver',
#      'Nuggets',
#      '50-32',
#      31,
#      27,
#      20,
#      25,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      103,
#      0.506,
#      0.846,
#      0.214,
#      15,
#      37,
#      15],
#     ['2011-04-13T00:00:00',
#      11,
#      '0021001226',
#      1610612762,
#      'UTA',
#      'Utah',
#      'Jazz',
#      '39-43',
#      29,
#      32,
#      21,
#      25,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      107,
#      0.506,
#      0.808,
#      0.533,
#      25,
#      37,
#      14],
#     ['2011-04-13T00:00:00',
#      12,
#      '0021001227',
#      1610612757,
#      'POR',
#      'Portland',
#      'Trail Blazers',
#      '48-34',
#      28,
#      17,
#      24,
#      17,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      86,
#      0.337,
#      0.76,
#      0.423,
#      18,
#      48,
#      19],
#     ['2011-04-13T00:00:00',
#      12,
#      '0021001227',
#      1610612744,
#      'GSW',
#      'Golden State',
#      'Warriors',
#      '36-46',
#      30,
#      21,
#      34,
#      25,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      110,
#      0.511,
#      0.667,
#      0.435,
#      33,
#      41,
#      11],
#     ['2011-04-13T00:00:00',
#      13,
#      '0021001228',
#      1610612763,
#      'MEM',
#      'Memphis',
#      'Grizzlies',
#      '46-36',
#      20,
#      17,
#      37,
#      29,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      103,
#      0.429,
#      0.857,
#      0.467,
#      25,
#      39,
#      21],
#     ['2011-04-13T00:00:00',
#      13,
#      '0021001228',
#      1610612746,
#      'LAC',
#      'Los Angeles',
#      'Clippers',
#      '32-50',
#      34,
#      32,
#      26,
#      18,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      110,
#      0.543,
#      0.704,
#      0.2,
#      36,
#      37,
#      17],
#     ['2011-04-13T00:00:00',
#      14,
#      '0021001229',
#      1610612759,
#      'SAS',
#      'San Antonio',
#      'Spurs',
#      '61-21',
#      27,
#      26,
#      21,
#      29,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      103,
#      0.427,
#      0.757,
#      0.238,
#      19,
#      51,
#      8],
#     ['2011-04-13T00:00:00',
#      14,
#      '0021001229',
#      1610612756,
#      'PHX',
#      'Phoenix',
#      'Suns',
#      '40-42',
#      43,
#      18,
#      24,
#      21,
#      0,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      106,
#      0.402,
#      0.828,
#      0.421,
#      23,
#      46,
#      6],
#     ['2011-04-13T00:00:00',
#      15,
#      '0021001230',
#      1610612747,
#      'LAL',
#      'Los Angeles',
#      'Lakers',
#      '57-25',
#      31,
#      25,
#      32,
#      11,
#      17,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      116,
#      0.495,
#      0.909,
#      0.375,
#      30,
#      43,
#      10],
#     ['2011-04-13T00:00:00',
#      15,
#      '0021001230',
#      1610612758,
#      'SAC',
#      'Sacramento',
#      'Kings',
#      '24-58',
#      26,
#      22,
#      22,
#      29,
#      9,
#      0,
#      0,
#      0,
#      None,
#      None,
#      None,
#      None,
#      None,
#      None,
#      108,
#      0.455,
#      0.579,
#      0.292,
#      24,
#      53,
#      12]]},
#   {'name': 'SeriesStandings',
#    'headers': ['GAME_ID',
#     'HOME_TEAM_ID',
#     'VISITOR_TEAM_ID',
#     'GAME_DATE_EST',
#     'HOME_TEAM_WINS',
#     'HOME_TEAM_LOSSES',
#     'SERIES_LEADER'],
#    'rowSet': [['0021001216',
#      1610612738,
#      1610612752,
#      '2011-04-13T00:00:00',
#      4,
#      0,
#      'Boston'],
#     ['0021001218',
#      1610612739,
#      1610612764,
#      '2011-04-13T00:00:00',
#      2,
#      2,
#      'Tied'],
#     ['0021001222',
#      1610612741,
#      1610612751,
#      '2011-04-13T00:00:00',
#      3,
#      1,
#      'Chicago'],
#     ['0021001223',
#      1610612742,
#      1610612740,
#      '2011-04-13T00:00:00',
#      2,
#      2,
#      'Tied'],
#     ['0021001227',
#      1610612744,
#      1610612757,
#      '2011-04-13T00:00:00',
#      3,
#      1,
#      'Golden State'],
#     ['0021001228',
#      1610612746,
#      1610612763,
#      '2011-04-13T00:00:00',
#      2,
#      2,
#      'Tied'],
#     ['0021001224',
#      1610612750,
#      1610612745,
#      '2011-04-13T00:00:00',
#      1,
#      3,
#      'Houston'],
#     ['0021001219',
#      1610612753,
#      1610612754,
#      '2011-04-13T00:00:00',
#      3,
#      0,
#      'Orlando'],
#     ['0021001220',
#      1610612755,
#      1610612765,
#      '2011-04-13T00:00:00',
#      1,
#      2,
#      'Detroit'],
#     ['0021001229',
#      1610612756,
#      1610612759,
#      '2011-04-13T00:00:00',
#      1,
#      3,
#      'San Antonio'],
#     ['0021001230',
#      1610612758,
#      1610612747,
#      '2011-04-13T00:00:00',
#      1,
#      3,
#      'L.A. Lakers'],
#     ['0021001225',
#      1610612760,
#      1610612749,
#      '2011-04-13T00:00:00',
#      1,
#      1,
#      'Tied'],
#     ['0021001221',
#      1610612761,
#      1610612748,
#      '2011-04-13T00:00:00',
#      0,
#      4,
#      'Miami'],
#     ['0021001226',
#      1610612762,
#      1610612743,
#      '2011-04-13T00:00:00',
#      2,
#      2,
#      'Tied'],
#     ['0021001217',
#      1610612766,
#      1610612737,
#      '2011-04-13T00:00:00',
#      2,
#      2,
#      'Tied']]},
#   {'name': 'LastMeeting',
#    'headers': ['GAME_ID',
#     'LAST_GAME_ID',
#     'LAST_GAME_DATE_EST',
#     'LAST_GAME_HOME_TEAM_ID',
#     'LAST_GAME_HOME_TEAM_CITY',
#     'LAST_GAME_HOME_TEAM_NAME',
#     'LAST_GAME_HOME_TEAM_ABBREVIATION',
#     'LAST_GAME_HOME_TEAM_POINTS',
#     'LAST_GAME_VISITOR_TEAM_ID',
#     'LAST_GAME_VISITOR_TEAM_CITY',
#     'LAST_GAME_VISITOR_TEAM_NAME',
#     'LAST_GAME_VISITOR_TEAM_CITY1',
#     'LAST_GAME_VISITOR_TEAM_POINTS'],
#    'rowSet': [['0021001216',
#      '0021001046',
#      '2011-03-21T00:00:00',
#      1610612738,
#      'Boston',
#      'Celtics',
#      'BOS',
#      96,
#      1610612752,
#      'New York',
#      'Knicks',
#      'NYK',
#      86],
#     ['0021001217',
#      '0021000796',
#      '2011-02-12T00:00:00',
#      1610612766,
#      'Charlotte',
#      'Bobcats',
#      'CHA',
#      88,
#      1610612737,
#      'Atlanta',
#      'Hawks',
#      'ATL',
#      86],
#     ['0021001218',
#      '0021001123',
#      '2011-04-01T00:00:00',
#      1610612739,
#      'Cleveland',
#      'Cavaliers',
#      'CLE',
#      107,
#      1610612764,
#      'Washington',
#      'Wizards',
#      'WAS',
#      115],
#     ['0021001219',
#      '0021000668',
#      '2011-01-26T00:00:00',
#      1610612753,
#      'Orlando',
#      'Magic',
#      'ORL',
#      111,
#      1610612754,
#      'Indiana',
#      'Pacers',
#      'IND',
#      96],
#     ['0021001220',
#      '0021000863',
#      '2011-02-25T00:00:00',
#      1610612755,
#      'Philadelphia',
#      '76ers',
#      'PHI',
#      110,
#      1610612765,
#      'Detroit',
#      'Pistons',
#      'DET',
#      94],
#     ['0021001221',
#      '0021000825',
#      '2011-02-16T00:00:00',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      95,
#      1610612748,
#      'Miami',
#      'Heat',
#      'MIA',
#      103],
#     ['0021001222',
#      '0021001014',
#      '2011-03-17T00:00:00',
#      1610612741,
#      'Chicago',
#      'Bulls',
#      'CHI',
#      84,
#      1610612751,
#      'New Jersey',
#      'Nets',
#      'NJN',
#      73],
#     ['0021001223',
#      '0021000961',
#      '2011-03-09T00:00:00',
#      1610612742,
#      'Dallas',
#      'Mavericks',
#      'DAL',
#      92,
#      1610612740,
#      'New Orleans',
#      'Hornets',
#      'NOH',
#      93],
#     ['0021001224',
#      '0021000772',
#      '2011-02-08T00:00:00',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      112,
#      1610612745,
#      'Houston',
#      'Rockets',
#      'HOU',
#      108],
#     ['0021001225',
#      '0021000186',
#      '2010-11-20T00:00:00',
#      1610612760,
#      'Oklahoma City',
#      'Thunder',
#      'OKC',
#      82,
#      1610612749,
#      'Milwaukee',
#      'Bucks',
#      'MIL',
#      81],
#     ['0021001226',
#      '0021000913',
#      '2011-03-03T00:00:00',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      101,
#      1610612743,
#      'Denver',
#      'Nuggets',
#      'DEN',
#      103],
#     ['0021001227',
#      '0021001160',
#      '2011-04-05T00:00:00',
#      1610612744,
#      'Golden State',
#      'Warriors',
#      'GSW',
#      108,
#      1610612757,
#      'Portland',
#      'Trail Blazers',
#      'POR',
#      87],
#     ['0021001228',
#      '0021001157',
#      '2011-04-05T00:00:00',
#      1610612746,
#      'Los Angeles',
#      'Clippers',
#      'LAC',
#      82,
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      81],
#     ['0021001229',
#      '0021001138',
#      '2011-04-03T00:00:00',
#      1610612756,
#      'Phoenix',
#      'Suns',
#      'PHX',
#      97,
#      1610612759,
#      'San Antonio',
#      'Spurs',
#      'SAS',
#      114],
#     ['0021001230',
#      '0021000692',
#      '2011-01-28T00:00:00',
#      1610612758,
#      'Sacramento',
#      'Kings',
#      'SAC',
#      100,
#      1610612747,
#      'Los Angeles',
#      'Lakers',
#      'LAL',
#      95]]},
#   {'name': 'EastConfStandingsByDay',
#    'headers': ['TEAM_ID',
#     'LEAGUE_ID',
#     'SEASON_ID',
#     'STANDINGSDATE',
#     'CONFERENCE',
#     'TEAM',
#     'G',
#     'W',
#     'L',
#     'W_PCT',
#     'HOME_RECORD',
#     'ROAD_RECORD'],
#    'rowSet': [[1610612741,
#      '00',
#      '22010',
#      '04/13/2011',
#      'East',
#      'Chicago',
#      82,
#      62,
#      20,
#      0.756,
#      '36-5',
#      '26-15'],
#     [1610612748,
#      '00',
#      '22010',
#      '04/13/2011',
#      'East',
#      'Miami',
#      82,
#      58,
#      24,
#      0.707,
#      '30-11',
#      '28-13'],
#     [1610612738,
#      '00',
#      '22010',
#      '04/13/2011',
#      'East',
#      'Boston',
#      82,
#      56,
#      26,
#      0.683,
#      '33-8',
#      '23-18'],
#     [1610612753,
#      '00',
#      '22010',
#      '04/13/2011',
#      'East',
#      'Orlando',
#      82,
#      52,
#      30,
#      0.634,
#      '29-12',
#      '23-18'],
#     [1610612737,
#      '00',
#      '22010',
#      '04/13/2011',
#      'East',
#      'Atlanta',
#      82,
#      44,
#      38,
#      0.537,
#      '24-17',
#      '20-21'],
#     [1610612752,
#      '00',
#      '22010',
#      '04/13/2011',
#      'East',
#      'New York',
#      82,
#      42,
#      40,
#      0.512,
#      '23-18',
#      '19-22'],
#     [1610612755,
#      '00',
#      '22010',
#      '04/13/2011',
#      'East',
#      'Philadelphia',
#      82,
#      41,
#      41,
#      0.5,
#      '26-15',
#      '15-26'],
#     [1610612754,
#      '00',
#      '22010',
#      '04/13/2011',
#      'East',
#      'Indiana',
#      82,
#      37,
#      45,
#      0.451,
#      '24-17',
#      '13-28'],
#     [1610612749,
#      '00',
#      '22010',
#      '04/13/2011',
#      'East',
#      'Milwaukee',
#      82,
#      35,
#      47,
#      0.427,
#      '22-19',
#      '13-28'],
#     [1610612766,
#      '00',
#      '22010',
#      '04/13/2011',
#      'East',
#      'Charlotte',
#      82,
#      34,
#      48,
#      0.415,
#      '21-20',
#      '13-28'],
#     [1610612765,
#      '00',
#      '22010',
#      '04/13/2011',
#      'East',
#      'Detroit',
#      82,
#      30,
#      52,
#      0.366,
#      '21-20',
#      '9-32'],
#     [1610612751,
#      '00',
#      '22010',
#      '04/13/2011',
#      'East',
#      'New Jersey',
#      82,
#      24,
#      58,
#      0.293,
#      '19-22',
#      '5-36'],
#     [1610612764,
#      '00',
#      '22010',
#      '04/13/2011',
#      'East',
#      'Washington',
#      82,
#      23,
#      59,
#      0.28,
#      '20-21',
#      '3-38'],
#     [1610612761,
#      '00',
#      '22010',
#      '04/13/2011',
#      'East',
#      'Toronto',
#      82,
#      22,
#      60,
#      0.268,
#      '16-25',
#      '6-35'],
#     [1610612739,
#      '00',
#      '22010',
#      '04/13/2011',
#      'East',
#      'Cleveland',
#      82,
#      19,
#      63,
#      0.232,
#      '12-29',
#      '7-34']]},
#   {'name': 'WestConfStandingsByDay',
#    'headers': ['TEAM_ID',
#     'LEAGUE_ID',
#     'SEASON_ID',
#     'STANDINGSDATE',
#     'CONFERENCE',
#     'TEAM',
#     'G',
#     'W',
#     'L',
#     'W_PCT',
#     'HOME_RECORD',
#     'ROAD_RECORD'],
#    'rowSet': [[1610612759,
#      '00',
#      '22010',
#      '04/13/2011',
#      'West',
#      'San Antonio',
#      82,
#      61,
#      21,
#      0.744,
#      '36-5',
#      '25-16'],
#     [1610612742,
#      '00',
#      '22010',
#      '04/13/2011',
#      'West',
#      'Dallas',
#      82,
#      57,
#      25,
#      0.695,
#      '29-12',
#      '28-13'],
#     [1610612747,
#      '00',
#      '22010',
#      '04/13/2011',
#      'West',
#      'L.A. Lakers',
#      82,
#      57,
#      25,
#      0.695,
#      '30-11',
#      '27-14'],
#     [1610612760,
#      '00',
#      '22010',
#      '04/13/2011',
#      'West',
#      'Oklahoma City',
#      82,
#      55,
#      27,
#      0.671,
#      '30-11',
#      '25-16'],
#     [1610612743,
#      '00',
#      '22010',
#      '04/13/2011',
#      'West',
#      'Denver',
#      82,
#      50,
#      32,
#      0.61,
#      '33-8',
#      '17-24'],
#     [1610612757,
#      '00',
#      '22010',
#      '04/13/2011',
#      'West',
#      'Portland',
#      82,
#      48,
#      34,
#      0.585,
#      '30-11',
#      '18-23'],
#     [1610612763,
#      '00',
#      '22010',
#      '04/13/2011',
#      'West',
#      'Memphis',
#      82,
#      46,
#      36,
#      0.561,
#      '30-11',
#      '16-25'],
#     [1610612740,
#      '00',
#      '22010',
#      '04/13/2011',
#      'West',
#      'New Orleans',
#      82,
#      46,
#      36,
#      0.561,
#      '28-13',
#      '18-23'],
#     [1610612745,
#      '00',
#      '22010',
#      '04/13/2011',
#      'West',
#      'Houston',
#      82,
#      43,
#      39,
#      0.524,
#      '25-16',
#      '18-23'],
#     [1610612756,
#      '00',
#      '22010',
#      '04/13/2011',
#      'West',
#      'Phoenix',
#      82,
#      40,
#      42,
#      0.488,
#      '23-18',
#      '17-24'],
#     [1610612762,
#      '00',
#      '22010',
#      '04/13/2011',
#      'West',
#      'Utah',
#      82,
#      39,
#      43,
#      0.476,
#      '21-20',
#      '18-23'],
#     [1610612744,
#      '00',
#      '22010',
#      '04/13/2011',
#      'West',
#      'Golden State',
#      82,
#      36,
#      46,
#      0.439,
#      '26-15',
#      '10-31'],
#     [1610612746,
#      '00',
#      '22010',
#      '04/13/2011',
#      'West',
#      'L.A. Clippers',
#      82,
#      32,
#      50,
#      0.39,
#      '23-18',
#      '9-32'],
#     [1610612758,
#      '00',
#      '22010',
#      '04/13/2011',
#      'West',
#      'Sacramento',
#      82,
#      24,
#      58,
#      0.293,
#      '11-30',
#      '13-28'],
#     [1610612750,
#      '00',
#      '22010',
#      '04/13/2011',
#      'West',
#      'Minnesota',
#      82,
#      17,
#      65,
#      0.207,
#      '12-29',
#      '5-36']]},
#   {'name': 'Available',
#    'headers': ['GAME_ID', 'PT_AVAILABLE'],
#    'rowSet': [['0021001228', 0],
#     ['0021001224', 0],
#     ['0021001229', 0],
#     ['0021001218', 0],
#     ['0021001216', 0],
#     ['0021001223', 0],
#     ['0021001222', 0],
#     ['0021001227', 0],
#     ['0021001217', 0],
#     ['0021001230', 0],
#     ['0021001221', 0],
#     ['0021001225', 0],
#     ['0021001226', 0],
#     ['0021001220', 0],
#     ['0021001219', 0]]},
#   {'name': 'TeamLeaders',
#    'headers': ['GAME_ID',
#     'TEAM_ID',
#     'TEAM_CITY',
#     'TEAM_NICKNAME',
#     'TEAM_ABBREVIATION',
#     'PTS_PLAYER_ID',
#     'PTS_PLAYER_NAME',
#     'PTS',
#     'REB_PLAYER_ID',
#     'REB_PLAYER_NAME',
#     'REB',
#     'AST_PLAYER_ID',
#     'AST_PLAYER_NAME',
#     'AST'],
#    'rowSet': [['0021001216',
#      1610612738,
#      'Boston',
#      'Celtics',
#      'BOS',
#      202340,
#      'Avery Bradley',
#      20,
#      201145,
#      'Jeff Green',
#      8,
#      101144,
#      'Von Wafer',
#      5],
#     ['0021001216',
#      1610612752,
#      'New York',
#      'Knicks',
#      'NYK',
#      202361,
#      'Landry Fields',
#      16,
#      201974,
#      'Derrick Brown',
#      7,
#      1853,
#      'Anthony Carter',
#      6],
#     ['0021001217',
#      1610612737,
#      'Atlanta',
#      'Hawks',
#      'ATL',
#      2694,
#      'Josh Powell',
#      16,
#      2585,
#      'Zaza Pachulia',
#      10,
#      2037,
#      'Jamal Crawford',
#      2],
#     ['0021001217',
#      1610612766,
#      'Charlotte',
#      'Bobcats',
#      'CHA',
#      201945,
#      'Gerald Henderson',
#      20,
#      2198,
#      'Kwame Brown',
#      8,
#      2564,
#      'Boris Diaw',
#      9],
#     ['0021001218',
#      1610612739,
#      'Cleveland',
#      'Cavaliers',
#      'CLE',
#      201196,
#      'Ramon Sessions',
#      27,
#      201581,
#      'JJ Hickson',
#      13,
#      202412,
#      'Manny Harris',
#      5],
#     ['0021001218',
#      1610612764,
#      'Washington',
#      'Wizards',
#      'WAS',
#      101154,
#      'Andray Blatche',
#      20,
#      201146,
#      'Yi Jianlian',
#      12,
#      202348,
#      'Jordan Crawford',
#      6],
#     ['0021001219',
#      1610612753,
#      'Orlando',
#      'Magic',
#      'ORL',
#      201583,
#      'Ryan Anderson',
#      14,
#      2730,
#      'Dwight Howard',
#      13,
#      2768,
#      'Chris Duhon',
#      5],
#     ['0021001219',
#      1610612754,
#      'Indiana',
#      'Pacers',
#      'IND',
#      2399,
#      'Mike Dunleavy',
#      16,
#      200780,
#      'Solomon Jones',
#      6,
#      201985,
#      'AJ Price',
#      7],
#     ['0021001220',
#      1610612755,
#      'Philadelphia',
#      '76ers',
#      'PHI',
#      201950,
#      'Jrue Holiday',
#      21,
#      1882,
#      'Elton Brand',
#      8,
#      201950,
#      'Jrue Holiday',
#      7],
#     ['0021001220',
#      1610612765,
#      'Detroit',
#      'Pistons',
#      'DET',
#      201155,
#      'Rodney Stuckey',
#      29,
#      202328,
#      'Greg Monroe',
#      13,
#      201155,
#      'Rodney Stuckey',
#      8],
#     ['0021001221',
#      1610612748,
#      'Miami',
#      'Heat',
#      'MIA',
#      2067,
#      'Eddie House',
#      35,
#      2048,
#      'Jamaal Magloire',
#      19,
#      201596,
#      'Mario Chalmers',
#      13],
#     ['0021001221',
#      1610612761,
#      'Toronto',
#      'Raptors',
#      'TOR',
#      201573,
#      'Jerryd Bayless',
#      21,
#      202334,
#      'Ed Davis',
#      8,
#      201949,
#      'James Johnson',
#      6],
#     ['0021001222',
#      1610612741,
#      'Chicago',
#      'Bulls',
#      'CHI',
#      2594,
#      'Kyle Korver',
#      19,
#      201149,
#      'Joakim Noah',
#      10,
#      201228,
#      'C.J. Watson',
#      6],
#     ['0021001222',
#      1610612751,
#      'New Jersey',
#      'Nets',
#      'NJN',
#      200770,
#      'Jordan Farmar',
#      21,
#      101130,
#      'Johan Petro',
#      8,
#      200770,
#      'Jordan Farmar',
#      12],
#     ['0021001223',
#      1610612740,
#      'New Orleans',
#      'Hornets',
#      'NOH',
#      101127,
#      'Jarrett Jack',
#      22,
#      201189,
#      'Aaron Gray',
#      10,
#      101108,
#      'Chris Paul',
#      8],
#     ['0021001223',
#      1610612742,
#      'Dallas',
#      'Mavericks',
#      'DAL',
#      1717,
#      'Dirk Nowitzki',
#      32,
#      1890,
#      'Shawn Marion',
#      8,
#      467,
#      'Jason Kidd',
#      8],
#     ['0021001224',
#      1610612745,
#      'Houston',
#      'Rockets',
#      'HOU',
#      201978,
#      'Chase Budinger',
#      35,
#      201609,
#      'Goran Dragic',
#      11,
#      201609,
#      'Goran Dragic',
#      11],
#     ['0021001224',
#      1610612750,
#      'Minnesota',
#      'Timberwolves',
#      'MIN',
#      201563,
#      'Michael Beasley',
#      34,
#      201229,
#      'Anthony Tolliver',
#      13,
#      2557,
#      'Luke Ridnour',
#      11],
#     ['0021001225',
#      1610612749,
#      'Milwaukee',
#      'Bucks',
#      'MIL',
#      201943,
#      'Brandon Jennings',
#      16,
#      101141,
#      'Ersan Ilyasova',
#      9,
#      201943,
#      'Brandon Jennings',
#      7],
#     ['0021001225',
#      1610612760,
#      'Oklahoma City',
#      'Thunder',
#      'OKC',
#      201566,
#      'Russell Westbrook',
#      20,
#      1737,
#      'Nazr Mohammed',
#      10,
#      201566,
#      'Russell Westbrook',
#      5],
#     ['0021001226',
#      1610612743,
#      'Denver',
#      'Nuggets',
#      'DEN',
#      201163,
#      'Wilson Chandler',
#      27,
#      2365,
#      'Chris Andersen',
#      10,
#      1733,
#      'Al Harrington',
#      3],
#     ['0021001226',
#      1610612762,
#      'Utah',
#      'Jazz',
#      'UTA',
#      202330,
#      'Gordon Hayward',
#      34,
#      2744,
#      'Al Jefferson',
#      10,
#      2734,
#      'Devin Harris',
#      6],
#     ['0021001227',
#      1610612744,
#      'Golden State',
#      'Warriors',
#      'GSW',
#      202130,
#      'Reggie Williams',
#      28,
#      202327,
#      'Ekpe Udoh',
#      8,
#      201939,
#      'Stephen Curry',
#      9],
#     ['0021001227',
#      1610612757,
#      'Portland',
#      'Trail Blazers',
#      'POR',
#      201988,
#      'Patty Mills',
#      23,
#      2853,
#      'Earl Barron',
#      13,
#      201164,
#      'Rudy Fernandez',
#      5],
#     ['0021001228',
#      1610612746,
#      'Los Angeles',
#      'Clippers',
#      'LAC',
#      201933,
#      'Blake Griffin',
#      31,
#      201599,
#      'DeAndre Jordan',
#      10,
#      201933,
#      'Blake Griffin',
#      10],
#     ['0021001228',
#      1610612763,
#      'Memphis',
#      'Grizzlies',
#      'MEM',
#      201970,
#      'Sam Young',
#      22,
#      201589,
#      'Darrell Arthur',
#      9,
#      201564,
#      'O.J. Mayo',
#      4],
#     ['0021001229',
#      1610612756,
#      'Phoenix',
#      'Suns',
#      'PHX',
#      101162,
#      'Marcin Gortat',
#      21,
#      101162,
#      'Marcin Gortat',
#      13,
#      959,
#      'Steve Nash',
#      10],
#     ['0021001229',
#      1610612759,
#      'San Antonio',
#      'Spurs',
#      'SAS',
#      1495,
#      'Tim Duncan',
#      17,
#      1495,
#      'Tim Duncan',
#      12,
#      2225,
#      'Tony Parker',
#      7],
#     ['0021001230',
#      1610612747,
#      'Los Angeles',
#      'Lakers',
#      'LAL',
#      977,
#      'Kobe Bryant',
#      36,
#      2200,
#      'Pau Gasol',
#      13,
#      1885,
#      'Lamar Odom',
#      7],
#     ['0021001230',
#      1610612758,
#      'Sacramento',
#      'Kings',
#      'SAC',
#      201977,
#      'Marcus Thornton',
#      33,
#      2223,
#      'Samuel Dalembert',
#      18,
#      201936,
#      'Tyreke Evans',
#      7]]},
#   {'name': 'TicketLinks', 'headers': ['GAME_ID', 'LEAG_TIX'], 'rowSet': []},
#   {'name': 'WinProbability', 'headers': [], 'rowSet': []}]}
